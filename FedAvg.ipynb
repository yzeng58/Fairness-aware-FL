# %%
import torch, os, copy, time
from tqdm import tqdm
from torch import nn
from torch.utils.data import DataLoader, Dataset
from load_adult import *
import torch.nn.functional as F
from torch.autograd import Variable
from functools import partial
import pandas as pd

# %%
class logReg(torch.nn.Module):
    # logistic regression 
    def __init__(self, num_features, num_classes):
        super().__init__()
        self.num_classes = num_classes
        self.linear = torch.nn.Linear(num_features, num_classes)

    def forward(self, x):
        logits = self.linear(x.float())
        probas = torch.sigmoid(logits)
        return probas.type(torch.FloatTensor), logits

global_model = logReg(num_features=NUM_FEATURES, num_classes=2)

# %%
def loss_func(option, logits, targets, distance, sensitive, mean_sensitive, larg = 10):
    acc_loss = F.cross_entropy(logits, targets, reduction = 'sum')
    fair_loss = torch.mul(sensitive - sensitive.type(torch.FloatTensor).mean(), distance.T[0])
    fair_loss = torch.mean(torch.mul(fair_loss, fair_loss))
    if option == 'unconstrained':
        return acc_loss, acc_loss, larg*fair_loss
    if option == 'Zafar':
        return acc_loss + larg*fair_loss, acc_loss, larg*fair_loss

# %%
class DatasetSplit(Dataset):
    """An abstract Dataset class wrapped around Pytorch Dataset class.
    """

    def __init__(self, dataset, idxs):
        self.dataset = dataset
        self.idxs = [int(i) for i in idxs]

    def __len__(self):
        return len(self.idxs)

    def __getitem__(self, item):
        feature, label, sensitive = self.dataset[self.idxs[item]]
        return feature, label, sensitive


class LocalUpdate(object):
    def __init__(self, dataset, idxs, batch_size, option, penalty = 0):
        self.trainloader, self.validloader = self.train_val(dataset, list(idxs), batch_size)
        self.option = option
        self.penalty = penalty
            
    def train_val(self, dataset, idxs, batch_size):
        """
        Returns train, validation for a given local training dataset
        and user indexes.
        """
        # split indexes for train, validation, and test (80, 10, 10)
#         idxs_train = idxs[:int(0.8*len(idxs))]
#         idxs_val = idxs[int(0.8*len(idxs)):int(0.9*len(idxs))]
#         idxs_test = idxs[int(0.9*len(idxs)):]
        
        idxs_train = idxs[:int(0.9*len(idxs))]
        idxs_val = idxs[int(0.9*len(idxs)):len(idxs)]

        trainloader = DataLoader(DatasetSplit(dataset, idxs_train),
                                 batch_size=batch_size, shuffle=True)
        validloader = DataLoader(DatasetSplit(dataset, idxs_val),
                                 batch_size=int(len(idxs_val)/10), shuffle=False)
#         testloader = DataLoader(DatasetSplit(dataset, idxs_test),
#                                 batch_size=int(len(idxs_test)/10), shuffle=False)
        return trainloader, validloader

    def update_weights(self, model, global_round, learning_rate, local_epochs, optimizer):
        # Set mode to train model
        model.train()
        epoch_loss = []

        # Set optimizer for the local updates
        if optimizer == 'sgd':
            optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate,
                                        ) # momentum=0.5
        elif optimizer == 'adam':
            optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate,
                                         weight_decay=1e-4)

        for i in range(local_epochs):
            batch_loss = []
            for batch_idx, (features, labels, sensitive) in enumerate(self.trainloader):
                features, labels = features.to(DEVICE), labels.to(DEVICE).type(torch.LongTensor)
                # we need to set the gradients to zero before starting to do backpropragation 
                # because PyTorch accumulates the gradients on subsequent backward passes. 
                # This is convenient while training RNNs
                
                log_probs, logits = model(features)
                loss, acc_loss, fair_loss = loss_func(self.option,
                    logits, labels, logits, sensitive, mean_sensitive, self.penalty)
                    
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                if batch_idx % 50 == 0:
                    print('| Global Round : {} | Local Epoch : {} | [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                        global_round, i, batch_idx * len(features),
                        len(self.trainloader.dataset),
                        100. * batch_idx / len(self.trainloader), loss.item()))
                batch_loss.append(loss.item())
            epoch_loss.append(sum(batch_loss)/len(batch_loss))

        # weight, loss
        return model.state_dict(), sum(epoch_loss) / len(epoch_loss)

    def inference(self, model):
        """ 
        Returns the inference accuracy, 
                                loss, 
                                N(sensitive group, pos), 
                                N(non-sensitive group, pos), 
                                N(sensitive group),
                                N(non-sensitive group)
        """

        model.eval()
        loss, total, correct, fair_loss = 0.0, 0.0, 0.0, 0.0
        sp, nsp, s, n = 0, 0, 0, 0
        for batch_idx, (features, labels, sensitive) in enumerate(self.validloader):
            features, labels = features.to(DEVICE), labels.to(DEVICE).type(torch.LongTensor)
            sensitive = sensitive.to(DEVICE)
            
            # Inference
            outputs, logits = model(features)

            # Prediction
            _, pred_labels = torch.max(outputs, 1)
            pred_labels = pred_labels.view(-1)
            bool_correct = torch.eq(pred_labels, labels)
            correct += torch.sum(bool_correct).item()
            total += len(labels)
            # print(pred_labels)
            bool_sensitive = torch.eq(sensitive, torch.ones(len(labels)))
#             print("In each batch, s: %d, n: %d, sp: %d, nsp: %d" % 
#                   (torch.sum(bool_sensitive).item(), 
#                    torch.sum(torch.logical_not(bool_sensitive)).item(),
#                    torch.sum(torch.mul(pred_labels, bool_sensitive)).item(),
#                    torch.sum(torch.mul(pred_labels, torch.logical_not(bool_sensitive))).item()
#                  ))
            s += torch.sum(bool_sensitive).item()
            n += torch.sum(torch.logical_not(bool_sensitive)).item()
            sp += torch.sum(torch.logical_and(pred_labels, bool_sensitive)).item()
            nsp += torch.sum(torch.logical_and(pred_labels, torch.logical_not(bool_sensitive))).item()
            
            batch_loss, acc_loss, fair_loss = loss_func(self.option, outputs, 
                                                        labels, logits, sensitive, mean_sensitive, self.penalty)
            loss += batch_loss.item()

        accuracy = correct/total
        # print("s: %d, n: %d, sp: %d, nsp: %d" % (s, n, sp, nsp))
        return accuracy, loss, s, n, sp, nsp


def test_inference(model, test_dataset, batch_size):
    """ Returns the test accuracy and loss.
    """

    model.eval()
    loss, total, correct = 0.0, 0.0, 0.0
    sp, nsp, s, n = 0, 0, 0, 0
    
    criterion = nn.NLLLoss().to(DEVICE)
    testloader = DataLoader(test_dataset, batch_size=batch_size,
                            shuffle=False)

    for batch_idx, (features, labels, sensitive) in enumerate(testloader):
        features = features.to(DEVICE)
        labels =  labels.to(DEVICE).type(torch.LongTensor)
        # Inference
        outputs, logits = model(features)
        batch_loss = criterion(outputs, labels)
        loss += batch_loss.item()

        # Prediction
        _, pred_labels = torch.max(outputs, 1)
        pred_labels = pred_labels.view(-1)
        bool_correct = torch.eq(pred_labels, labels)
        correct += torch.sum(bool_correct).item()
        total += len(labels)

        bool_sensitive = torch.eq(sensitive, torch.ones(len(labels)))
        s += torch.sum(bool_sensitive).item()
        n += torch.sum(torch.logical_not(bool_sensitive) ).item()
        sp += torch.sum(torch.logical_and(bool_correct, bool_sensitive)).item()
        nsp += torch.sum(torch.logical_and(bool_correct, torch.logical_not(bool_sensitive))).item()

    accuracy = correct/total
    # |P(Group1, pos) - P(Group2, pos)| = |N(Group1, pos)/N(Group1) - N(Group2, pos)/N(Group2)|
    return accuracy, loss, abs(sp/s-nsp/n)

# %%
def train(model, option = "unconstrained", batch_size = 128,
          num_rounds = 5, learning_rate = 0.01, optimizer = 'adam', local_epochs= 5, num_workers = 4, print_every = 1,
         penalty = 0.0001):
    # Training
    train_loss, train_accuracy = [], []
    val_acc_list, net_list = [], []
    cv_loss, cv_acc = [], []
    val_loss_pre, counter = 0, 0
    start_time = time.time()
    weights = model.state_dict()
    
    client1_loader = DataLoader(dataset = client1_dataset,
                            batch_size = batch_size,
                            num_workers = num_workers)
    
    client2_loader = DataLoader(dataset = client2_dataset,
                            batch_size = batch_size,
                            num_workers = num_workers)
    
    test_loader = DataLoader(dataset = test_dataset,
                            batch_size = batch_size,
                            num_workers = num_workers)
    
    train_loader = DataLoader(dataset = train_dataset,
                        batch_size = batch_size,
                        num_workers = num_workers)

    def average_weights(w):
        """
        Returns the average of the weights.
        """
        w_avg = copy.deepcopy(w[0])
        for key in w_avg.keys():
            for i in range(1, len(w)):
                w_avg[key] += w[i][key]
            w_avg[key] = torch.div(w_avg[key], len(w))
        return w_avg

    for round_ in tqdm(range(num_rounds)):
        local_weights, local_losses = [], []
        print(f'\n | Global Training Round : {round_+1} |\n')

        model.train()
        m = 2 # the number of clients to be chosen in each round_
        idxs_users = np.random.choice(range(2), m, replace=False)

        for idx in idxs_users:
            local_model = LocalUpdate(dataset=train_dataset,
                                        idxs=clients_idx[idx], batch_size = batch_size, option = option, penalty = penalty)
            w, loss = local_model.update_weights(
                model=copy.deepcopy(model), global_round=round_, 
                learning_rate = learning_rate, local_epochs = local_epochs, optimizer = optimizer)
            local_weights.append(copy.deepcopy(w))
            local_losses.append(copy.deepcopy(loss))

        # update global weights
        weights = average_weights(local_weights)
        model.load_state_dict(weights)

        loss_avg = sum(local_losses) / len(local_losses)
        train_loss.append(loss_avg)

        # Calculate avg training accuracy over all users at every round
        list_acc, list_loss = [], []
        s, n, sp, nsp = 0, 0, 0, 0
        model.eval()
        for c in range(2):
            local_model = LocalUpdate(dataset=train_dataset,
                                        idxs=clients_idx[c], batch_size = batch_size, option = option, penalty = penalty)
            acc, loss, s_, n_, sp_, nsp_ = local_model.inference(model=model) # validation dataset inference
            list_acc.append(acc)
            list_loss.append(loss)
            s, n, sp, nsp = s + s_, n + n_, sp + sp_, nsp + nsp_
            print("Client %d: RD = %.2f = |%d/%d-%d/%d|" % (c, abs(sp_/s_-nsp_/n_), sp_, s_, nsp_, n_))
            
        train_accuracy.append(sum(list_acc)/len(list_acc))

        # print global training loss after every 'i' rounds
        if (round_+1) % print_every == 0:
            print(f' \nAvg Training Stats after {round_+1} global rounds:')
            print("Training loss: %.2f | Validation accuracy: %.2f%% | Validation RD: %.2f" % (
                 np.mean(np.array(train_loss)), 
                100*train_accuracy[-1],
                abs(sp/s-nsp/n)
                 ))

    # Test inference after completion of training
    test_acc, test_loss, rd= test_inference(model, test_dataset, batch_size)

    print(f' \n Results after {num_rounds} global rounds of training:')
    print("|---- Avg Train Accuracy: {:.2f}%".format(100*train_accuracy[-1]))
    print("|---- Test Accuracy: {:.2f}%".format(100*test_acc))

    # Compute RD: risk difference - fairness metric
    # |P(Group1, pos) - P(Group2, pos)| = |N(Group1, pos)/N(Group1) - N(Group2, pos)/N(Group2)|
    print("|---- Test RD: {:.2f}".format(rd))

    print('\n Total Run Time: {0:0.4f} sec'.format(time.time()-start_time))

# %%
train(logReg(num_features=NUM_FEATURES, num_classes=2), 
      "Zafar", penalty = 50, optimizer = 'sgd', learning_rate = 0.01,
     num_rounds = 5, local_epochs = 10)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#  | Global Training Round : 1 |
#
# | Global Round : 0 | Local Epoch : 0 | [0/11188 (0%)]	Loss: 97.129074
# | Global Round : 0 | Local Epoch : 0 | [6400/11188 (57%)]	Loss: 88.739372
# | Global Round : 0 | Local Epoch : 1 | [0/11188 (0%)]	Loss: 58.027599
# | Global Round : 0 | Local Epoch : 1 | [6400/11188 (57%)]	Loss: 73.519951
# | Global Round : 0 | Local Epoch : 2 | [0/11188 (0%)]	Loss: 63.784790
# | Global Round : 0 | Local Epoch : 2 | [6400/11188 (57%)]	Loss: 75.687607
# | Global Round : 0 | Local Epoch : 3 | [0/11188 (0%)]	Loss: 51.680065
# | Global Round : 0 | Local Epoch : 3 | [6400/11188 (57%)]	Loss: 74.850227
# | Global Round : 0 | Local Epoch : 4 | [0/11188 (0%)]	Loss: 60.017704
# | Global Round : 0 | Local Epoch : 4 | [6400/11188 (57%)]	Loss: 75.023788
# | Global Round : 0 | Local Epoch : 5 | [0/11188 (0%)]	Loss: 40.387955
# | Global Round : 0 | Local Epoch : 5 | [6400/11188 (57%)]	Loss: 50.170868
# | Global Round : 0 | Local Epoch : 6 | [0/11188 (0%)]	Loss: 53.864670
# | Global Round : 0 | Local Epoch : 6 | [6400/11188 (57%)]	Loss: 70.707001
# | Global Round : 0 | Local Epoch : 7 | [0/11188 (0%)]	Loss: 77.145119
# | Global Round : 0 | Local Epoch : 7 | [6400/11188 (57%)]	Loss: 87.636597
# | Global Round : 0 | Local Epoch : 8 | [0/11188 (0%)]	Loss: 48.997784
# | Global Round : 0 | Local Epoch : 8 | [6400/11188 (57%)]	Loss: 107.260017
# | Global Round : 0 | Local Epoch : 9 | [0/11188 (0%)]	Loss: 63.912033
# | Global Round : 0 | Local Epoch : 9 | [6400/11188 (57%)]	Loss: 114.068871
# | Global Round : 0 | Local Epoch : 0 | [0/18116 (0%)]	Loss: 98.088036
# | Global Round : 0 | Local Epoch : 0 | [6400/18116 (35%)]	Loss: 95.289825
# | Global Round : 0 | Local Epoch : 0 | [12800/18116 (70%)]	Loss: 77.870079
# | Global Round : 0 | Local Epoch : 1 | [0/18116 (0%)]	Loss: 48.414394
# | Global Round : 0 | Local Epoch : 1 | [6400/18116 (35%)]	Loss: 159.764465
# | Global Round : 0 | Local Epoch : 1 | [12800/18116 (70%)]	Loss: 57.173935
# | Global Round : 0 | Local Epoch : 2 | [0/18116 (0%)]	Loss: 30.913012
# | Global Round : 0 | Local Epoch : 2 | [6400/18116 (35%)]	Loss: 24.362934
# | Global Round : 0 | Local Epoch : 2 | [12800/18116 (70%)]	Loss: 84.380501
# | Global Round : 0 | Local Epoch : 3 | [0/18116 (0%)]	Loss: 46.284508
# | Global Round : 0 | Local Epoch : 3 | [6400/18116 (35%)]	Loss: 64.378204
# | Global Round : 0 | Local Epoch : 3 | [12800/18116 (70%)]	Loss: 94.755600
# | Global Round : 0 | Local Epoch : 4 | [0/18116 (0%)]	Loss: 48.771263
# | Global Round : 0 | Local Epoch : 4 | [6400/18116 (35%)]	Loss: 60.414413
# | Global Round : 0 | Local Epoch : 4 | [12800/18116 (70%)]	Loss: 143.476501
# | Global Round : 0 | Local Epoch : 5 | [0/18116 (0%)]	Loss: 34.604496
# | Global Round : 0 | Local Epoch : 5 | [6400/18116 (35%)]	Loss: 55.154663
# | Global Round : 0 | Local Epoch : 5 | [12800/18116 (70%)]	Loss: 89.567863
# | Global Round : 0 | Local Epoch : 6 | [0/18116 (0%)]	Loss: 53.202686
# | Global Round : 0 | Local Epoch : 6 | [6400/18116 (35%)]	Loss: 52.690334
# | Global Round : 0 | Local Epoch : 6 | [12800/18116 (70%)]	Loss: 55.480968
# | Global Round : 0 | Local Epoch : 7 | [0/18116 (0%)]	Loss: 37.404533
# | Global Round : 0 | Local Epoch : 7 | [6400/18116 (35%)]	Loss: 62.226818
# | Global Round : 0 | Local Epoch : 7 | [12800/18116 (70%)]	Loss: 88.869049
# | Global Round : 0 | Local Epoch : 8 | [0/18116 (0%)]	Loss: 42.501511
# | Global Round : 0 | Local Epoch : 8 | [6400/18116 (35%)]	Loss: 56.758282
# | Global Round : 0 | Local Epoch : 8 | [12800/18116 (70%)]	Loss: 49.223980
# | Global Round : 0 | Local Epoch : 9 | [0/18116 (0%)]	Loss: 35.380726
# | Global Round : 0 | Local Epoch : 9 | [6400/18116 (35%)]	Loss: 55.768646
# | Global Round : 0 | Local Epoch : 9 | [12800/18116 (70%)]	Loss: 39.540443
# In client 0, the RD is 0.38 = |140/592-877/1421|.
#  20%|██        | 1/5 [00:08<00:32,  8.15s/it]
# In client 1, the RD is 0.30 = |88/421-423/823|.
#
# Avg Training Stats after 1 global rounds:
# Training loss: 81.70 | Validation accuracy: 75.11% | Validation RD: 0.35
#
#  | Global Training Round : 2 |
#
# | Global Round : 1 | Local Epoch : 0 | [0/11188 (0%)]	Loss: 74.821060
# | Global Round : 1 | Local Epoch : 0 | [6400/11188 (57%)]	Loss: 68.413315
# | Global Round : 1 | Local Epoch : 1 | [0/11188 (0%)]	Loss: 52.999275
# | Global Round : 1 | Local Epoch : 1 | [6400/11188 (57%)]	Loss: 38.131889
# | Global Round : 1 | Local Epoch : 2 | [0/11188 (0%)]	Loss: 56.216457
# | Global Round : 1 | Local Epoch : 2 | [6400/11188 (57%)]	Loss: 50.668480
# | Global Round : 1 | Local Epoch : 3 | [0/11188 (0%)]	Loss: 45.660702
# | Global Round : 1 | Local Epoch : 3 | [6400/11188 (57%)]	Loss: 52.844872
# | Global Round : 1 | Local Epoch : 4 | [0/11188 (0%)]	Loss: 55.896729
# | Global Round : 1 | Local Epoch : 4 | [6400/11188 (57%)]	Loss: 78.781776
# | Global Round : 1 | Local Epoch : 5 | [0/11188 (0%)]	Loss: 51.799438
# | Global Round : 1 | Local Epoch : 5 | [6400/11188 (57%)]	Loss: 44.609287
# | Global Round : 1 | Local Epoch : 6 | [0/11188 (0%)]	Loss: 53.064373
# | Global Round : 1 | Local Epoch : 6 | [6400/11188 (57%)]	Loss: 58.495209
# | Global Round : 1 | Local Epoch : 7 | [0/11188 (0%)]	Loss: 45.167358
# | Global Round : 1 | Local Epoch : 7 | [6400/11188 (57%)]	Loss: 50.997551
# | Global Round : 1 | Local Epoch : 8 | [0/11188 (0%)]	Loss: 56.772511
# | Global Round : 1 | Local Epoch : 8 | [6400/11188 (57%)]	Loss: 57.771523
# | Global Round : 1 | Local Epoch : 9 | [0/11188 (0%)]	Loss: 45.333839
# | Global Round : 1 | Local Epoch : 9 | [6400/11188 (57%)]	Loss: 85.112267
# | Global Round : 1 | Local Epoch : 0 | [0/18116 (0%)]	Loss: 35.536892
# | Global Round : 1 | Local Epoch : 0 | [6400/18116 (35%)]	Loss: 141.072540
# | Global Round : 1 | Local Epoch : 0 | [12800/18116 (70%)]	Loss: 91.145462
# | Global Round : 1 | Local Epoch : 1 | [0/18116 (0%)]	Loss: 39.044327
# | Global Round : 1 | Local Epoch : 1 | [6400/18116 (35%)]	Loss: 95.434227
# | Global Round : 1 | Local Epoch : 1 | [12800/18116 (70%)]	Loss: 89.685760
# | Global Round : 1 | Local Epoch : 2 | [0/18116 (0%)]	Loss: 54.009243
# | Global Round : 1 | Local Epoch : 2 | [6400/18116 (35%)]	Loss: 93.486496
# | Global Round : 1 | Local Epoch : 2 | [12800/18116 (70%)]	Loss: 44.332840
# | Global Round : 1 | Local Epoch : 3 | [0/18116 (0%)]	Loss: 48.056149
# | Global Round : 1 | Local Epoch : 3 | [6400/18116 (35%)]	Loss: 70.521973
# | Global Round : 1 | Local Epoch : 3 | [12800/18116 (70%)]	Loss: 68.614624
# | Global Round : 1 | Local Epoch : 4 | [0/18116 (0%)]	Loss: 35.320141
# | Global Round : 1 | Local Epoch : 4 | [6400/18116 (35%)]	Loss: 100.817520
# | Global Round : 1 | Local Epoch : 4 | [12800/18116 (70%)]	Loss: 71.157928
# | Global Round : 1 | Local Epoch : 5 | [0/18116 (0%)]	Loss: 56.523975
# | Global Round : 1 | Local Epoch : 5 | [6400/18116 (35%)]	Loss: 71.585754
# | Global Round : 1 | Local Epoch : 5 | [12800/18116 (70%)]	Loss: 75.531631
# | Global Round : 1 | Local Epoch : 6 | [0/18116 (0%)]	Loss: 45.782578
# | Global Round : 1 | Local Epoch : 6 | [6400/18116 (35%)]	Loss: 66.575043
# | Global Round : 1 | Local Epoch : 6 | [12800/18116 (70%)]	Loss: 38.456276
# | Global Round : 1 | Local Epoch : 7 | [0/18116 (0%)]	Loss: 39.081375
# | Global Round : 1 | Local Epoch : 7 | [6400/18116 (35%)]	Loss: 110.984131
# | Global Round : 1 | Local Epoch : 7 | [12800/18116 (70%)]	Loss: 79.280754
# | Global Round : 1 | Local Epoch : 8 | [0/18116 (0%)]	Loss: 53.188866
# | Global Round : 1 | Local Epoch : 8 | [6400/18116 (35%)]	Loss: 53.482285
# | Global Round : 1 | Local Epoch : 8 | [12800/18116 (70%)]	Loss: 113.295044
# | Global Round : 1 | Local Epoch : 9 | [0/18116 (0%)]	Loss: 56.419384
# | Global Round : 1 | Local Epoch : 9 | [6400/18116 (35%)]	Loss: 57.679600
# | Global Round : 1 | Local Epoch : 9 | [12800/18116 (70%)]	Loss: 82.219818
# In client 0, the RD is 0.21 = |76/592-487/1421|.
#  40%|████      | 2/5 [00:16<00:24,  8.14s/it]
# In client 1, the RD is 0.18 = |44/421-231/823|.
#
# Avg Training Stats after 2 global rounds:
# Training loss: 76.63 | Validation accuracy: 82.88% | Validation RD: 0.20
#
#  | Global Training Round : 3 |
#
# | Global Round : 2 | Local Epoch : 0 | [0/18116 (0%)]	Loss: 59.690285
# | Global Round : 2 | Local Epoch : 0 | [6400/18116 (35%)]	Loss: 72.011383
# | Global Round : 2 | Local Epoch : 0 | [12800/18116 (70%)]	Loss: 48.918304
# | Global Round : 2 | Local Epoch : 1 | [0/18116 (0%)]	Loss: 52.151093
# | Global Round : 2 | Local Epoch : 1 | [6400/18116 (35%)]	Loss: 149.107239
# | Global Round : 2 | Local Epoch : 1 | [12800/18116 (70%)]	Loss: 98.614044
# | Global Round : 2 | Local Epoch : 2 | [0/18116 (0%)]	Loss: 39.356712
# | Global Round : 2 | Local Epoch : 2 | [6400/18116 (35%)]	Loss: 146.139618
# | Global Round : 2 | Local Epoch : 2 | [12800/18116 (70%)]	Loss: 42.178570
# | Global Round : 2 | Local Epoch : 3 | [0/18116 (0%)]	Loss: 37.914608
# | Global Round : 2 | Local Epoch : 3 | [6400/18116 (35%)]	Loss: 68.632233
# | Global Round : 2 | Local Epoch : 3 | [12800/18116 (70%)]	Loss: 105.329315
# | Global Round : 2 | Local Epoch : 4 | [0/18116 (0%)]	Loss: 52.529430
# | Global Round : 2 | Local Epoch : 4 | [6400/18116 (35%)]	Loss: 43.857479
# | Global Round : 2 | Local Epoch : 4 | [12800/18116 (70%)]	Loss: 147.092667
# | Global Round : 2 | Local Epoch : 5 | [0/18116 (0%)]	Loss: 45.074829
# | Global Round : 2 | Local Epoch : 5 | [6400/18116 (35%)]	Loss: 76.998764
# | Global Round : 2 | Local Epoch : 5 | [12800/18116 (70%)]	Loss: 49.109997
# | Global Round : 2 | Local Epoch : 6 | [0/18116 (0%)]	Loss: 36.890823
# | Global Round : 2 | Local Epoch : 6 | [6400/18116 (35%)]	Loss: 75.179916
# | Global Round : 2 | Local Epoch : 6 | [12800/18116 (70%)]	Loss: 96.450363
# | Global Round : 2 | Local Epoch : 7 | [0/18116 (0%)]	Loss: 47.650890
# | Global Round : 2 | Local Epoch : 7 | [6400/18116 (35%)]	Loss: 58.250805
# | Global Round : 2 | Local Epoch : 7 | [12800/18116 (70%)]	Loss: 110.648941
# | Global Round : 2 | Local Epoch : 8 | [0/18116 (0%)]	Loss: 40.660206
# | Global Round : 2 | Local Epoch : 8 | [6400/18116 (35%)]	Loss: 55.180538
# | Global Round : 2 | Local Epoch : 8 | [12800/18116 (70%)]	Loss: 51.512520
# | Global Round : 2 | Local Epoch : 9 | [0/18116 (0%)]	Loss: 66.353287
# | Global Round : 2 | Local Epoch : 9 | [6400/18116 (35%)]	Loss: 51.812714
# | Global Round : 2 | Local Epoch : 9 | [12800/18116 (70%)]	Loss: 70.045319
# | Global Round : 2 | Local Epoch : 0 | [0/11188 (0%)]	Loss: 56.783043
# | Global Round : 2 | Local Epoch : 0 | [6400/11188 (57%)]	Loss: 53.826298
# | Global Round : 2 | Local Epoch : 1 | [0/11188 (0%)]	Loss: 45.775803
# | Global Round : 2 | Local Epoch : 1 | [6400/11188 (57%)]	Loss: 58.359493
# | Global Round : 2 | Local Epoch : 2 | [0/11188 (0%)]	Loss: 52.673756
# | Global Round : 2 | Local Epoch : 2 | [6400/11188 (57%)]	Loss: 92.093544
# | Global Round : 2 | Local Epoch : 3 | [0/11188 (0%)]	Loss: 48.020672
# | Global Round : 2 | Local Epoch : 3 | [6400/11188 (57%)]	Loss: 52.119778
# | Global Round : 2 | Local Epoch : 4 | [0/11188 (0%)]	Loss: 48.854614
# | Global Round : 2 | Local Epoch : 4 | [6400/11188 (57%)]	Loss: 61.902184
# | Global Round : 2 | Local Epoch : 5 | [0/11188 (0%)]	Loss: 45.619896
# | Global Round : 2 | Local Epoch : 5 | [6400/11188 (57%)]	Loss: 118.712929
# | Global Round : 2 | Local Epoch : 6 | [0/11188 (0%)]	Loss: 51.937500
# | Global Round : 2 | Local Epoch : 6 | [6400/11188 (57%)]	Loss: 43.593868
# | Global Round : 2 | Local Epoch : 7 | [0/11188 (0%)]	Loss: 46.984524
# | Global Round : 2 | Local Epoch : 7 | [6400/11188 (57%)]	Loss: 77.558372
# | Global Round : 2 | Local Epoch : 8 | [0/11188 (0%)]	Loss: 43.967041
# | Global Round : 2 | Local Epoch : 8 | [6400/11188 (57%)]	Loss: 72.770325
# | Global Round : 2 | Local Epoch : 9 | [0/11188 (0%)]	Loss: 55.309082
# | Global Round : 2 | Local Epoch : 9 | [6400/11188 (57%)]	Loss: 51.951122
#  60%|██████    | 3/5 [00:24<00:16,  8.08s/it]
# In client 0, the RD is 0.24 = |98/592-579/1421|.
# In client 1, the RD is 0.23 = |57/421-303/823|.
#
# Avg Training Stats after 3 global rounds:
# Training loss: 73.63 | Validation accuracy: 82.65% | Validation RD: 0.24
#
#  | Global Training Round : 4 |
#
# | Global Round : 3 | Local Epoch : 0 | [0/11188 (0%)]	Loss: 42.475834
# | Global Round : 3 | Local Epoch : 0 | [6400/11188 (57%)]	Loss: 67.931946
# | Global Round : 3 | Local Epoch : 1 | [0/11188 (0%)]	Loss: 39.536667
# | Global Round : 3 | Local Epoch : 1 | [6400/11188 (57%)]	Loss: 69.762161
# | Global Round : 3 | Local Epoch : 2 | [0/11188 (0%)]	Loss: 54.083927
# | Global Round : 3 | Local Epoch : 2 | [6400/11188 (57%)]	Loss: 39.197651
# | Global Round : 3 | Local Epoch : 3 | [0/11188 (0%)]	Loss: 41.307663
# | Global Round : 3 | Local Epoch : 3 | [6400/11188 (57%)]	Loss: 55.150444
# | Global Round : 3 | Local Epoch : 4 | [0/11188 (0%)]	Loss: 62.792068
# | Global Round : 3 | Local Epoch : 4 | [6400/11188 (57%)]	Loss: 73.305267
# | Global Round : 3 | Local Epoch : 5 | [0/11188 (0%)]	Loss: 63.506817
# | Global Round : 3 | Local Epoch : 5 | [6400/11188 (57%)]	Loss: 57.705238
# | Global Round : 3 | Local Epoch : 6 | [0/11188 (0%)]	Loss: 56.515770
# | Global Round : 3 | Local Epoch : 6 | [6400/11188 (57%)]	Loss: 42.933571
# | Global Round : 3 | Local Epoch : 7 | [0/11188 (0%)]	Loss: 52.393600
# | Global Round : 3 | Local Epoch : 7 | [6400/11188 (57%)]	Loss: 55.708553
# | Global Round : 3 | Local Epoch : 8 | [0/11188 (0%)]	Loss: 57.756763
# | Global Round : 3 | Local Epoch : 8 | [6400/11188 (57%)]	Loss: 42.749187
# | Global Round : 3 | Local Epoch : 9 | [0/11188 (0%)]	Loss: 53.637402
# | Global Round : 3 | Local Epoch : 9 | [6400/11188 (57%)]	Loss: 68.624451
# | Global Round : 3 | Local Epoch : 0 | [0/18116 (0%)]	Loss: 39.426472
# | Global Round : 3 | Local Epoch : 0 | [6400/18116 (35%)]	Loss: 39.495693
# | Global Round : 3 | Local Epoch : 0 | [12800/18116 (70%)]	Loss: 93.122559
# | Global Round : 3 | Local Epoch : 1 | [0/18116 (0%)]	Loss: 49.462891
# | Global Round : 3 | Local Epoch : 1 | [6400/18116 (35%)]	Loss: 28.644646
# | Global Round : 3 | Local Epoch : 1 | [12800/18116 (70%)]	Loss: 55.423557
# | Global Round : 3 | Local Epoch : 2 | [0/18116 (0%)]	Loss: 33.924416
# | Global Round : 3 | Local Epoch : 2 | [6400/18116 (35%)]	Loss: 80.226494
# | Global Round : 3 | Local Epoch : 2 | [12800/18116 (70%)]	Loss: 69.109299
# | Global Round : 3 | Local Epoch : 3 | [0/18116 (0%)]	Loss: 32.380135
# | Global Round : 3 | Local Epoch : 3 | [6400/18116 (35%)]	Loss: 82.210190
# | Global Round : 3 | Local Epoch : 3 | [12800/18116 (70%)]	Loss: 72.091751
# | Global Round : 3 | Local Epoch : 4 | [0/18116 (0%)]	Loss: 47.459568
# | Global Round : 3 | Local Epoch : 4 | [6400/18116 (35%)]	Loss: 43.404251
# | Global Round : 3 | Local Epoch : 4 | [12800/18116 (70%)]	Loss: 84.179390
# | Global Round : 3 | Local Epoch : 5 | [0/18116 (0%)]	Loss: 47.204185
# | Global Round : 3 | Local Epoch : 5 | [6400/18116 (35%)]	Loss: 121.637634
# | Global Round : 3 | Local Epoch : 5 | [12800/18116 (70%)]	Loss: 52.777859
# | Global Round : 3 | Local Epoch : 6 | [0/18116 (0%)]	Loss: 53.150143
# | Global Round : 3 | Local Epoch : 6 | [6400/18116 (35%)]	Loss: 48.094990
# | Global Round : 3 | Local Epoch : 6 | [12800/18116 (70%)]	Loss: 39.618126
# | Global Round : 3 | Local Epoch : 7 | [0/18116 (0%)]	Loss: 39.322639
# | Global Round : 3 | Local Epoch : 7 | [6400/18116 (35%)]	Loss: 35.949448
# | Global Round : 3 | Local Epoch : 7 | [12800/18116 (70%)]	Loss: 60.561394
# | Global Round : 3 | Local Epoch : 8 | [0/18116 (0%)]	Loss: 45.793541
# | Global Round : 3 | Local Epoch : 8 | [6400/18116 (35%)]	Loss: 103.603386
# | Global Round : 3 | Local Epoch : 8 | [12800/18116 (70%)]	Loss: 53.477566
# | Global Round : 3 | Local Epoch : 9 | [0/18116 (0%)]	Loss: 53.699974
# | Global Round : 3 | Local Epoch : 9 | [6400/18116 (35%)]	Loss: 100.947594
# | Global Round : 3 | Local Epoch : 9 | [12800/18116 (70%)]	Loss: 84.237503
# In client 0, the RD is 0.26 = |80/592-563/1421|.
#  80%|████████  | 4/5 [00:32<00:08,  8.07s/it]
# In client 1, the RD is 0.25 = |46/421-296/823|.
#
# Avg Training Stats after 4 global rounds:
# Training loss: 72.13 | Validation accuracy: 83.13% | Validation RD: 0.26
#
#  | Global Training Round : 5 |
#
# | Global Round : 4 | Local Epoch : 0 | [0/11188 (0%)]	Loss: 41.820972
# | Global Round : 4 | Local Epoch : 0 | [6400/11188 (57%)]	Loss: 58.578114
# | Global Round : 4 | Local Epoch : 1 | [0/11188 (0%)]	Loss: 52.752613
# | Global Round : 4 | Local Epoch : 1 | [6400/11188 (57%)]	Loss: 65.227402
# | Global Round : 4 | Local Epoch : 2 | [0/11188 (0%)]	Loss: 41.261173
# | Global Round : 4 | Local Epoch : 2 | [6400/11188 (57%)]	Loss: 54.598175
# | Global Round : 4 | Local Epoch : 3 | [0/11188 (0%)]	Loss: 49.818287
# | Global Round : 4 | Local Epoch : 3 | [6400/11188 (57%)]	Loss: 87.625832
# | Global Round : 4 | Local Epoch : 4 | [0/11188 (0%)]	Loss: 55.013706
# | Global Round : 4 | Local Epoch : 4 | [6400/11188 (57%)]	Loss: 44.190445
# | Global Round : 4 | Local Epoch : 5 | [0/11188 (0%)]	Loss: 56.730701
# | Global Round : 4 | Local Epoch : 5 | [6400/11188 (57%)]	Loss: 44.391773
# | Global Round : 4 | Local Epoch : 6 | [0/11188 (0%)]	Loss: 55.510426
# | Global Round : 4 | Local Epoch : 6 | [6400/11188 (57%)]	Loss: 66.437317
# | Global Round : 4 | Local Epoch : 7 | [0/11188 (0%)]	Loss: 50.939125
# | Global Round : 4 | Local Epoch : 7 | [6400/11188 (57%)]	Loss: 59.893547
# | Global Round : 4 | Local Epoch : 8 | [0/11188 (0%)]	Loss: 42.480869
# | Global Round : 4 | Local Epoch : 8 | [6400/11188 (57%)]	Loss: 64.873260
# | Global Round : 4 | Local Epoch : 9 | [0/11188 (0%)]	Loss: 58.769352
# | Global Round : 4 | Local Epoch : 9 | [6400/11188 (57%)]	Loss: 51.928299
# | Global Round : 4 | Local Epoch : 0 | [0/18116 (0%)]	Loss: 48.069996
# | Global Round : 4 | Local Epoch : 0 | [6400/18116 (35%)]	Loss: 47.488205
# | Global Round : 4 | Local Epoch : 0 | [12800/18116 (70%)]	Loss: 52.612099
# | Global Round : 4 | Local Epoch : 1 | [0/18116 (0%)]	Loss: 97.347885
# | Global Round : 4 | Local Epoch : 1 | [6400/18116 (35%)]	Loss: 89.166000
# | Global Round : 4 | Local Epoch : 1 | [12800/18116 (70%)]	Loss: 73.205559
# | Global Round : 4 | Local Epoch : 2 | [0/18116 (0%)]	Loss: 50.746319
# | Global Round : 4 | Local Epoch : 2 | [6400/18116 (35%)]	Loss: 57.851093
# | Global Round : 4 | Local Epoch : 2 | [12800/18116 (70%)]	Loss: 62.077255
# | Global Round : 4 | Local Epoch : 3 | [0/18116 (0%)]	Loss: 43.189537
# | Global Round : 4 | Local Epoch : 3 | [6400/18116 (35%)]	Loss: 55.078159
# | Global Round : 4 | Local Epoch : 3 | [12800/18116 (70%)]	Loss: 122.506302
# | Global Round : 4 | Local Epoch : 4 | [0/18116 (0%)]	Loss: 34.584358
# | Global Round : 4 | Local Epoch : 4 | [6400/18116 (35%)]	Loss: 87.425217
# | Global Round : 4 | Local Epoch : 4 | [12800/18116 (70%)]	Loss: 138.550720
# | Global Round : 4 | Local Epoch : 5 | [0/18116 (0%)]	Loss: 52.219971
# | Global Round : 4 | Local Epoch : 5 | [6400/18116 (35%)]	Loss: 92.714012
# | Global Round : 4 | Local Epoch : 5 | [12800/18116 (70%)]	Loss: 102.162781
# | Global Round : 4 | Local Epoch : 6 | [0/18116 (0%)]	Loss: 45.664753
# | Global Round : 4 | Local Epoch : 6 | [6400/18116 (35%)]	Loss: 92.902267
# | Global Round : 4 | Local Epoch : 6 | [12800/18116 (70%)]	Loss: 45.793530
# | Global Round : 4 | Local Epoch : 7 | [0/18116 (0%)]	Loss: 49.597023
# | Global Round : 4 | Local Epoch : 7 | [6400/18116 (35%)]	Loss: 94.598595
# | Global Round : 4 | Local Epoch : 7 | [12800/18116 (70%)]	Loss: 45.609135
# | Global Round : 4 | Local Epoch : 8 | [0/18116 (0%)]	Loss: 69.084282
# | Global Round : 4 | Local Epoch : 8 | [6400/18116 (35%)]	Loss: 58.455456
# | Global Round : 4 | Local Epoch : 8 | [12800/18116 (70%)]	Loss: 58.325356
# | Global Round : 4 | Local Epoch : 9 | [0/18116 (0%)]	Loss: 34.397278
# | Global Round : 4 | Local Epoch : 9 | [6400/18116 (35%)]	Loss: 79.276871
# | Global Round : 4 | Local Epoch : 9 | [12800/18116 (70%)]	Loss: 56.993767
# 100%|██████████| 5/5 [00:40<00:00,  8.04s/it]
# In client 0, the RD is 0.26 = |68/592-529/1421|.
# In client 1, the RD is 0.23 = |42/421-274/823|.
#
# Avg Training Stats after 5 global rounds:
# Training loss: 71.22 | Validation accuracy: 83.88% | Validation RD: 0.25
#
#  Results after 5 global rounds of training:
# |---- Avg Train Accuracy: 83.88%
# |---- Test Accuracy: 84.48%
# |---- Test RD: 0.12
#
#  Total Run Time: 40.5763 sec

# %%
train(logReg(num_features=NUM_FEATURES, num_classes=2), optimizer = 'sgd', learning_rate = 0.01)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#  | Global Training Round : 1 |
#
# | Global Round : 0 | Local Epoch : 0 | [0/11188 (0%)]	Loss: 93.002548
# | Global Round : 0 | Local Epoch : 0 | [6400/11188 (57%)]	Loss: 69.492393
# | Global Round : 0 | Local Epoch : 1 | [0/11188 (0%)]	Loss: 47.031193
# | Global Round : 0 | Local Epoch : 1 | [6400/11188 (57%)]	Loss: 54.340210
# | Global Round : 0 | Local Epoch : 2 | [0/11188 (0%)]	Loss: 57.740227
# | Global Round : 0 | Local Epoch : 2 | [6400/11188 (57%)]	Loss: 42.863007
# | Global Round : 0 | Local Epoch : 3 | [0/11188 (0%)]	Loss: 35.554657
# | Global Round : 0 | Local Epoch : 3 | [6400/11188 (57%)]	Loss: 37.808662
# | Global Round : 0 | Local Epoch : 4 | [0/11188 (0%)]	Loss: 40.819706
# | Global Round : 0 | Local Epoch : 4 | [6400/11188 (57%)]	Loss: 60.515236
# | Global Round : 0 | Local Epoch : 0 | [0/18116 (0%)]	Loss: 93.193375
# | Global Round : 0 | Local Epoch : 0 | [6400/18116 (35%)]	Loss: 61.420052
# | Global Round : 0 | Local Epoch : 0 | [12800/18116 (70%)]	Loss: 36.336704
# | Global Round : 0 | Local Epoch : 1 | [0/18116 (0%)]	Loss: 40.868534
# | Global Round : 0 | Local Epoch : 1 | [6400/18116 (35%)]	Loss: 52.041531
# | Global Round : 0 | Local Epoch : 1 | [12800/18116 (70%)]	Loss: 44.657166
# | Global Round : 0 | Local Epoch : 2 | [0/18116 (0%)]	Loss: 36.367760
# | Global Round : 0 | Local Epoch : 2 | [6400/18116 (35%)]	Loss: 38.178757
# | Global Round : 0 | Local Epoch : 2 | [12800/18116 (70%)]	Loss: 39.489773
# | Global Round : 0 | Local Epoch : 3 | [0/18116 (0%)]	Loss: 53.710529
# | Global Round : 0 | Local Epoch : 3 | [6400/18116 (35%)]	Loss: 39.745106
# | Global Round : 0 | Local Epoch : 3 | [12800/18116 (70%)]	Loss: 47.663551
# | Global Round : 0 | Local Epoch : 4 | [0/18116 (0%)]	Loss: 38.713913
# | Global Round : 0 | Local Epoch : 4 | [6400/18116 (35%)]	Loss: 41.190144
# | Global Round : 0 | Local Epoch : 4 | [12800/18116 (70%)]	Loss: 45.539818
#  20%|██        | 1/5 [00:03<00:15,  3.96s/it]
# In client 0, the RD is 0.38 = |104/592-784/1421|.
# In client 1, the RD is 0.29 = |62/421-363/823|.
#
# Avg Training Stats after 1 global rounds:
# Training loss: 48.38 | Validation accuracy: 78.70% | Validation RD: 0.35
#
#  | Global Training Round : 2 |
#
# | Global Round : 1 | Local Epoch : 0 | [0/18116 (0%)]	Loss: 27.846607
# | Global Round : 1 | Local Epoch : 0 | [6400/18116 (35%)]	Loss: 48.043636
# | Global Round : 1 | Local Epoch : 0 | [12800/18116 (70%)]	Loss: 61.422527
# | Global Round : 1 | Local Epoch : 1 | [0/18116 (0%)]	Loss: 40.716099
# | Global Round : 1 | Local Epoch : 1 | [6400/18116 (35%)]	Loss: 47.060272
# | Global Round : 1 | Local Epoch : 1 | [12800/18116 (70%)]	Loss: 39.354794
# | Global Round : 1 | Local Epoch : 2 | [0/18116 (0%)]	Loss: 49.975140
# | Global Round : 1 | Local Epoch : 2 | [6400/18116 (35%)]	Loss: 38.019928
# | Global Round : 1 | Local Epoch : 2 | [12800/18116 (70%)]	Loss: 31.296812
# | Global Round : 1 | Local Epoch : 3 | [0/18116 (0%)]	Loss: 49.768524
# | Global Round : 1 | Local Epoch : 3 | [6400/18116 (35%)]	Loss: 41.729084
# | Global Round : 1 | Local Epoch : 3 | [12800/18116 (70%)]	Loss: 33.447220
# | Global Round : 1 | Local Epoch : 4 | [0/18116 (0%)]	Loss: 37.975605
# | Global Round : 1 | Local Epoch : 4 | [6400/18116 (35%)]	Loss: 43.921574
# | Global Round : 1 | Local Epoch : 4 | [12800/18116 (70%)]	Loss: 48.328514
# | Global Round : 1 | Local Epoch : 0 | [0/11188 (0%)]	Loss: 61.016708
# | Global Round : 1 | Local Epoch : 0 | [6400/11188 (57%)]	Loss: 43.808407
# | Global Round : 1 | Local Epoch : 1 | [0/11188 (0%)]	Loss: 43.098030
# | Global Round : 1 | Local Epoch : 1 | [6400/11188 (57%)]	Loss: 46.950306
# | Global Round : 1 | Local Epoch : 2 | [0/11188 (0%)]	Loss: 46.926586
# | Global Round : 1 | Local Epoch : 2 | [6400/11188 (57%)]	Loss: 33.482834
# | Global Round : 1 | Local Epoch : 3 | [0/11188 (0%)]	Loss: 49.261879
# | Global Round : 1 | Local Epoch : 3 | [6400/11188 (57%)]	Loss: 52.704826
# | Global Round : 1 | Local Epoch : 4 | [0/11188 (0%)]	Loss: 36.153240
# | Global Round : 1 | Local Epoch : 4 | [6400/11188 (57%)]	Loss: 55.809326
#  40%|████      | 2/5 [00:07<00:11,  3.91s/it]
# In client 0, the RD is 0.27 = |97/592-615/1421|.
# In client 1, the RD is 0.25 = |53/421-307/823|.
#
# Avg Training Stats after 2 global rounds:
# Training loss: 47.05 | Validation accuracy: 81.91% | Validation RD: 0.26
#
#  | Global Training Round : 3 |
#
# | Global Round : 2 | Local Epoch : 0 | [0/11188 (0%)]	Loss: 50.165337
# | Global Round : 2 | Local Epoch : 0 | [6400/11188 (57%)]	Loss: 43.332649
# | Global Round : 2 | Local Epoch : 1 | [0/11188 (0%)]	Loss: 49.328442
# | Global Round : 2 | Local Epoch : 1 | [6400/11188 (57%)]	Loss: 49.271786
# | Global Round : 2 | Local Epoch : 2 | [0/11188 (0%)]	Loss: 39.606594
# | Global Round : 2 | Local Epoch : 2 | [6400/11188 (57%)]	Loss: 46.713963
# | Global Round : 2 | Local Epoch : 3 | [0/11188 (0%)]	Loss: 44.118191
# | Global Round : 2 | Local Epoch : 3 | [6400/11188 (57%)]	Loss: 47.675804
# | Global Round : 2 | Local Epoch : 4 | [0/11188 (0%)]	Loss: 46.641232
# | Global Round : 2 | Local Epoch : 4 | [6400/11188 (57%)]	Loss: 57.602432
# | Global Round : 2 | Local Epoch : 0 | [0/18116 (0%)]	Loss: 40.648045
# | Global Round : 2 | Local Epoch : 0 | [6400/18116 (35%)]	Loss: 38.049118
# | Global Round : 2 | Local Epoch : 0 | [12800/18116 (70%)]	Loss: 40.316032
# | Global Round : 2 | Local Epoch : 1 | [0/18116 (0%)]	Loss: 43.569111
# | Global Round : 2 | Local Epoch : 1 | [6400/18116 (35%)]	Loss: 41.866032
# | Global Round : 2 | Local Epoch : 1 | [12800/18116 (70%)]	Loss: 49.612507
# | Global Round : 2 | Local Epoch : 2 | [0/18116 (0%)]	Loss: 50.965942
# | Global Round : 2 | Local Epoch : 2 | [6400/18116 (35%)]	Loss: 28.584726
# | Global Round : 2 | Local Epoch : 2 | [12800/18116 (70%)]	Loss: 51.980751
# | Global Round : 2 | Local Epoch : 3 | [0/18116 (0%)]	Loss: 40.594128
# | Global Round : 2 | Local Epoch : 3 | [6400/18116 (35%)]	Loss: 45.237785
# | Global Round : 2 | Local Epoch : 3 | [12800/18116 (70%)]	Loss: 41.952728
# | Global Round : 2 | Local Epoch : 4 | [0/18116 (0%)]	Loss: 43.510086
# | Global Round : 2 | Local Epoch : 4 | [6400/18116 (35%)]	Loss: 37.154301
# | Global Round : 2 | Local Epoch : 4 | [12800/18116 (70%)]	Loss: 49.350651
# In client 0, the RD is 0.29 = |86/592-622/1421|.
#  60%|██████    | 3/5 [00:11<00:07,  3.88s/it]
# In client 1, the RD is 0.28 = |47/421-323/823|.
#
# Avg Training Stats after 3 global rounds:
# Training loss: 46.47 | Validation accuracy: 81.86% | Validation RD: 0.29
#
#  | Global Training Round : 4 |
#
# | Global Round : 3 | Local Epoch : 0 | [0/11188 (0%)]	Loss: 37.018890
# | Global Round : 3 | Local Epoch : 0 | [6400/11188 (57%)]	Loss: 64.279480
# | Global Round : 3 | Local Epoch : 1 | [0/11188 (0%)]	Loss: 59.291298
# | Global Round : 3 | Local Epoch : 1 | [6400/11188 (57%)]	Loss: 41.470345
# | Global Round : 3 | Local Epoch : 2 | [0/11188 (0%)]	Loss: 45.804871
# | Global Round : 3 | Local Epoch : 2 | [6400/11188 (57%)]	Loss: 50.384151
# | Global Round : 3 | Local Epoch : 3 | [0/11188 (0%)]	Loss: 44.137280
# | Global Round : 3 | Local Epoch : 3 | [6400/11188 (57%)]	Loss: 65.056488
# | Global Round : 3 | Local Epoch : 4 | [0/11188 (0%)]	Loss: 46.620605
# | Global Round : 3 | Local Epoch : 4 | [6400/11188 (57%)]	Loss: 65.099709
# | Global Round : 3 | Local Epoch : 0 | [0/18116 (0%)]	Loss: 41.579872
# | Global Round : 3 | Local Epoch : 0 | [6400/18116 (35%)]	Loss: 42.045959
# | Global Round : 3 | Local Epoch : 0 | [12800/18116 (70%)]	Loss: 36.269276
# | Global Round : 3 | Local Epoch : 1 | [0/18116 (0%)]	Loss: 35.665485
# | Global Round : 3 | Local Epoch : 1 | [6400/18116 (35%)]	Loss: 36.050652
# | Global Round : 3 | Local Epoch : 1 | [12800/18116 (70%)]	Loss: 63.275856
# | Global Round : 3 | Local Epoch : 2 | [0/18116 (0%)]	Loss: 50.722237
# | Global Round : 3 | Local Epoch : 2 | [6400/18116 (35%)]	Loss: 57.182693
# | Global Round : 3 | Local Epoch : 2 | [12800/18116 (70%)]	Loss: 31.293236
# | Global Round : 3 | Local Epoch : 3 | [0/18116 (0%)]	Loss: 50.105518
# | Global Round : 3 | Local Epoch : 3 | [6400/18116 (35%)]	Loss: 36.557648
# | Global Round : 3 | Local Epoch : 3 | [12800/18116 (70%)]	Loss: 40.490582
# | Global Round : 3 | Local Epoch : 4 | [0/18116 (0%)]	Loss: 39.740265
# | Global Round : 3 | Local Epoch : 4 | [6400/18116 (35%)]	Loss: 35.755054
# | Global Round : 3 | Local Epoch : 4 | [12800/18116 (70%)]	Loss: 45.686794
#  80%|████████  | 4/5 [00:15<00:03,  3.92s/it]
# In client 0, the RD is 0.21 = |79/592-484/1421|.
# In client 1, the RD is 0.20 = |45/421-250/823|.
#
# Avg Training Stats after 4 global rounds:
# Training loss: 45.98 | Validation accuracy: 83.74% | Validation RD: 0.20
#
#  | Global Training Round : 5 |
#
# | Global Round : 4 | Local Epoch : 0 | [0/11188 (0%)]	Loss: 37.388119
# | Global Round : 4 | Local Epoch : 0 | [6400/11188 (57%)]	Loss: 57.172165
# | Global Round : 4 | Local Epoch : 1 | [0/11188 (0%)]	Loss: 60.511341
# | Global Round : 4 | Local Epoch : 1 | [6400/11188 (57%)]	Loss: 54.603451
# | Global Round : 4 | Local Epoch : 2 | [0/11188 (0%)]	Loss: 48.786533
# | Global Round : 4 | Local Epoch : 2 | [6400/11188 (57%)]	Loss: 40.720695
# | Global Round : 4 | Local Epoch : 3 | [0/11188 (0%)]	Loss: 49.488594
# | Global Round : 4 | Local Epoch : 3 | [6400/11188 (57%)]	Loss: 50.179955
# | Global Round : 4 | Local Epoch : 4 | [0/11188 (0%)]	Loss: 50.713879
# | Global Round : 4 | Local Epoch : 4 | [6400/11188 (57%)]	Loss: 50.901196
# | Global Round : 4 | Local Epoch : 0 | [0/18116 (0%)]	Loss: 40.407482
# | Global Round : 4 | Local Epoch : 0 | [6400/18116 (35%)]	Loss: 34.762123
# | Global Round : 4 | Local Epoch : 0 | [12800/18116 (70%)]	Loss: 32.151657
# | Global Round : 4 | Local Epoch : 1 | [0/18116 (0%)]	Loss: 46.663422
# | Global Round : 4 | Local Epoch : 1 | [6400/18116 (35%)]	Loss: 47.465000
# | Global Round : 4 | Local Epoch : 1 | [12800/18116 (70%)]	Loss: 38.424545
# | Global Round : 4 | Local Epoch : 2 | [0/18116 (0%)]	Loss: 38.347801
# | Global Round : 4 | Local Epoch : 2 | [6400/18116 (35%)]	Loss: 47.645927
# | Global Round : 4 | Local Epoch : 2 | [12800/18116 (70%)]	Loss: 30.696125
# | Global Round : 4 | Local Epoch : 3 | [0/18116 (0%)]	Loss: 32.082710
# | Global Round : 4 | Local Epoch : 3 | [6400/18116 (35%)]	Loss: 52.631165
# | Global Round : 4 | Local Epoch : 3 | [12800/18116 (70%)]	Loss: 30.177355
# | Global Round : 4 | Local Epoch : 4 | [0/18116 (0%)]	Loss: 37.050884
# | Global Round : 4 | Local Epoch : 4 | [6400/18116 (35%)]	Loss: 30.635870
# | Global Round : 4 | Local Epoch : 4 | [12800/18116 (70%)]	Loss: 38.065609
# 100%|██████████| 5/5 [00:19<00:00,  3.90s/it]
# In client 0, the RD is 0.24 = |76/592-521/1421|.
# In client 1, the RD is 0.24 = |44/421-283/823|.
#
# Avg Training Stats after 5 global rounds:
# Training loss: 45.62 | Validation accuracy: 83.51% | Validation RD: 0.24
#
#  Results after 5 global rounds of training:
# |---- Avg Train Accuracy: 83.51%
# |---- Test Accuracy: 84.52%
# |---- Test RD: 0.12
#
#  Total Run Time: 19.8862 sec
