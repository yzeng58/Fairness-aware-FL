# %%
# copied from Agnostic_LR_Adult.py

import time
import numpy as np
import torch
import torch.nn.functional as F
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torch.autograd import Variable
from numpy import genfromtxt
from Adult_dataset import MyDataset
from alpha_maximization import compute_alpha_with_fairness, compute_alpha_no_fairness, compute_alpha_with_local_fairness
import kernel
from risk_difference_calculation import risk_difference_calculation

# %%
batch_size = 30000
learning_rate = 0.1
num_epochs = 10
filename = 'adult_norm.csv'
numpy_data = genfromtxt(filename, delimiter=',')


train = []

index = batch_size
train_data = numpy_data[:, 1:-1][0:index]
train_label = numpy_data[:, -1][0:index]

test_data = numpy_data[:, 1:-1][index:]
test_label = numpy_data[:, -1][index:]

train_dataset = MyDataset(train_data, train_label)
test_dataset = MyDataset(test_data, test_label)
train_loader = DataLoader(train_dataset, batch_size = batch_size, shuffle = False)
test_loader = DataLoader(test_dataset, batch_size = len(numpy_data) - batch_size, shuffle = False)

class logsticRegression(nn.Module):
    def __init__(self, in_dim, n_class):
        super(logsticRegression, self).__init__()
        self.logstic = nn.Linear(in_dim, n_class)

    def forward(self, x):
        out = self.logstic(x)
        Theta_X = out
        out = torch.sigmoid(out)
        # return class labels, probas
        return out, Theta_X


def loss_no_fair(output, target):
    # cross entropy -\sum p(x) log q(x) 
    loss = torch.mean((-target * torch.log(output)- (1 - target) * torch.log(1 - output))) 

    return loss

# Zafar et al. Need to add some details to make it work better: cross validation to choose the hyperparameter
# theta_x is the distance to the boundary
def loss_with_fair(output, target, Theta_X, Sen, Sen_bar):
    # cross entropy
    pred_loss = torch.mean((-target * torch.log(output)- (1 - target) * torch.log(1 - output)))
    # Zafar et al. 
    fair_loss = torch.mul(Sen - Sen_bar, Theta_X)
    fair_loss = torch.mean(torch.mul(fair_loss, fair_loss))
    # they fixed the lagangian multiplier manually instead of using cross validation to compute lambda
    # may get better performance with cross validation
    return pred_loss + 4.0*fair_loss

# k is the number of clients
def loss_with_local_fair(output, target, Theta_X, Sen, k):
    pred_loss = torch.mean((-target * torch.log(output)- (1 - target) * torch.log(1 - output)))
    local_length = len(Sen) // k
    fair_loss = 0
    for i in range(k):
        Sen_bar_temp = torch.sum(Sen[i*local_length: (i + 1)*local_length])/local_length
        Sen_temp = Sen[i*local_length: (i + 1)*local_length]
        Theta_X_temp = Theta_X[i*local_length: (i + 1)*local_length]
        loss_temp = torch.mul(Sen_temp - Sen_bar_temp, Theta_X_temp)
        loss_temp = torch.mean(torch.mul(loss_temp, loss_temp))
        fair_loss = fair_loss + loss_temp
    print(pred_loss)
    print(fair_loss)
    return pred_loss + 1.0*fair_loss



def agnostic_loss_no_fair(output, target, weight):

    pred_loss = (-target * torch.log(output)- (1 - target) * torch.log(1 - output))
    pred_loss = torch.mean(torch.mul(pred_loss, weight))
    return pred_loss


def loss_with_agnostic_local_fair(output, target, Theta_X, weight, Sen, Sen_bar, k):
    pred_loss = (-target * torch.log(output)- (1 - target) * torch.log(1 - output))
    pred_loss = torch.mean(torch.mul(pred_loss, weight))

    fair_loss = 0
    local_length = len(Sen) // k
    for i in range(k):
        weight_temp = weight[i*local_length: (i+1)*local_length]
        Sen_temp = Sen[i*local_length: (i+1)*local_length]
        Theta_X_temp = Theta_X[i*local_length: (i+1)*local_length]
        temp_loss = torch.mul(torch.mul(weight_temp, Sen_temp) - Sen_bar[i], Theta_X_temp)
        fair_loss = fair_loss + torch.mean(torch.mul(temp_loss, temp_loss))

    return pred_loss + 2.0*fair_loss

# Agnostic 
def loss_with_agnostic_fair(output, target, Theta_X, weight, Sen, Sen_bar):
    pred_loss = (-target * torch.log(output)- (1 - target) * torch.log(1 - output))
    pred_loss = torch.mean(torch.mul(pred_loss, weight))

    fair_loss = torch.mul(torch.mul(weight, Sen) - Sen_bar, Theta_X)
    fair_loss = torch.mean(torch.mul(fair_loss, fair_loss))

    return pred_loss + 2.0*fair_loss

input_dim = 40
output_dim = 1

model = logsticRegression(input_dim, output_dim)
use_gpu = torch.cuda.is_available()


criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)


def compute_model_parameter_fairness(weight, Sen, ratio, option, k):
    for epoch in range(num_epochs):
        print('*' * 10)
        print(f'epoch {epoch+1}')
        running_acc = 0.0
        
        # Sets the module in training mode
        model.train() 
        for i,  (data, target) in enumerate(train_loader):
            img, label = data, target

            label = label.view(len(label), -1)

            out, Theta_X = model(img) # Theta_X >0 then 1 else 0, Theta_X is the distance to the boundary

            if option == "no_fair":
                loss = loss_no_fair(out, label)
            elif option == "with_fair":
                loss = loss_with_fair(out, label, Theta_X, Sen, ratio)
            elif option == "agnostic_fair":
                loss = loss_with_agnostic_fair(out, label, Theta_X, weight, Sen, ratio)
            elif option == "agnostic_loss_no_fair":
                loss = agnostic_loss_no_fair(out, label, weight)
            elif option == "loss_with_local_fair":
                loss = loss_with_local_fair(out, label, Theta_X, Sen, k)
            elif option == "loss_with_agnostic_local_fair":
                loss = loss_with_agnostic_local_fair(out, label, Theta_X, weight, Sen, ratio, k)

            print(loss)

            pred = torch.where(out > 0.5, torch.tensor(1.0), torch.tensor(0.0))

            running_acc += torch.sum((pred==label))

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
        Sen_train = numpy_data[:, 0][0:index].reshape(-1, 1)
        risk_difference = np.random.rand(k)
        for j in range(k):
            local_length = len(pred) // k
            Sen_train_j = Sen_train[j*local_length : (j + 1)*local_length]
            pred_j = pred[j*local_length : (j + 1)*local_length]
            label_j = label[j*local_length : (j + 1)*local_length]
            risk_difference[j] = risk_difference_calculation(Sen_train_j, pred_j)
            accuracy = torch.sum((pred_j==label_j))
            accuracy = accuracy.numpy()
            print(f'Party {i + 1} accuracy {accuracy / local_length:.6f}')
        running_acc = running_acc.numpy()
        global_risk_difference = risk_difference_calculation(Sen_train, pred)
        for i in range(k):
            print(f'Party {i + 1} risk difference {risk_difference[i]:.6f}')
        print(f'global training risk dfference: {global_risk_difference:.6f}')
        print(f'Finish {epoch + 1} training epoch, Acc: {running_acc / len(train_label):.6f}')
        
        # Sets the module in evaluation mode.
        model.eval()
        theta = model.logstic.weight
        bias = model.logstic.bias

        running_acc = 0.0
        for data in test_loader:
            img, label = data
            img = img.view(img.size(0), -1)
            with torch.no_grad():
                out, Theta_X = model(img)

            pred = torch.where(out > 0.5, torch.tensor(1.0), torch.tensor(0.0))
            label = label.view(len(label), -1)
            running_acc += torch.sum((pred == label))

        Sen_test = numpy_data[:, 0][index:].reshape(-1, 1)
        for i in range(k):
            length = len(Sen_test) // k
            Sen_train_j = Sen_test[i*length: (i+1)*length]
            pred_j = pred[i * length: (i + 1) * length]
            label_j = label[i * length: (i + 1) * length]
            risk_difference = risk_difference_calculation(Sen_train_j, pred_j)
            accuracy = torch.sum((pred_j == label_j)).numpy()
            print(f'Finish party {i + 1} test risk difference {risk_difference:.6f}')
            print(f'Party {i + 1} accuracy {accuracy / len(pred_j):.6f}')
        running_acc = running_acc.numpy()
        print(f'Finish {epoch + 1} testing epoch, Acc: {running_acc / len(test_label):.6f}')
        risk_difference = risk_difference_calculation(Sen_test[0:20000], pred[0:20000])
        print(f'Finish {epoch + 1} risk difference {risk_difference:.6f}')


    return theta.detach().numpy().transpose(), bias.detach().numpy()

Iteration = 20
sigma = 2
B = 5
Xtr = train_data
Ytr = train_label
ref_idx = np.random.randint(len(test_data), size = 30)
Xref = test_data[ref_idx, :]
Sen = numpy_data[:, 0][0:index].reshape(-1, 1)
Sen_torch = torch.from_numpy(Sen).float()

weight = torch.ones(batch_size, 1)
ratio = 0.1
options = ["no_fair", "with_fair", "agnostic_fair", "agnostic_loss_no_fair", "loss_with_local_fair", "loss_with_agnostic_local_fair"]
ratio_fair = np.sum(Sen) / len(Sen)
print(ratio_fair)

tau = 1000 # useless
k = 2
ratio = np.random.rand(k)
for i in range(k):
    local_length = len(Sen) // k
    ratio[i] = np.sum(Sen[i*local_length: (i+1)*local_length]) / local_length
# Out:
# 0.6760333333333334
# **********
# epoch 1
# tensor(0.6977, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.460733
# Party 1 accuracy 0.459733
# Party 1 risk difference 0.191799
# Party 2 risk difference 0.204090
# global training risk dfference: 0.197946
# Finish 1 training epoch, Acc: 0.460233
# Finish party 1 test risk difference 0.147014
# Party 1 accuracy 0.620155
# Finish party 2 test risk difference 0.161210
# Party 2 accuracy 0.620024
# Finish 1 testing epoch, Acc: 0.620089
# Finish 1 risk difference 0.154084
# **********
# epoch 2
# tensor(0.6709, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.618467
# Party 1 accuracy 0.615067
# Party 1 risk difference 0.162501
# Party 2 risk difference 0.162547
# global training risk dfference: 0.162529
# Finish 2 training epoch, Acc: 0.616767
# Finish party 1 test risk difference 0.028919
# Party 1 accuracy 0.733675
# Finish party 2 test risk difference 0.022508
# Party 2 accuracy 0.730784
# Finish 2 testing epoch, Acc: 0.732230
# Finish 2 risk difference 0.025721
# **********
# epoch 3
# tensor(0.6492, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.733800
# Party 1 accuracy 0.727933
# Party 1 risk difference 0.032071
# Party 2 risk difference 0.032374
# global training risk dfference: 0.032220
# Finish 3 training epoch, Acc: 0.730867
# Finish party 1 test risk difference 0.003100
# Party 1 accuracy 0.754434
# Finish party 2 test risk difference 0.002559
# Party 2 accuracy 0.750624
# Finish 3 testing epoch, Acc: 0.752529
# Finish 3 risk difference 0.002837
# **********
# epoch 4
# tensor(0.6316, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.750133
# Party 1 accuracy 0.745333
# Party 1 risk difference 0.003770
# Party 2 risk difference 0.006247
# global training risk dfference: 0.005007
# Finish 4 training epoch, Acc: 0.747733
# Finish party 1 test risk difference 0.000408
# Party 1 accuracy 0.756931
# Finish party 2 test risk difference 0.000165
# Party 2 accuracy 0.751675
# Finish 4 testing epoch, Acc: 0.754303
# Finish 4 risk difference 0.000121
# **********
# epoch 5
# tensor(0.6173, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752800
# Party 1 accuracy 0.748133
# Party 1 risk difference 0.000641
# Party 2 risk difference 0.002285
# global training risk dfference: 0.001462
# Finish 5 training epoch, Acc: 0.750467
# Finish party 1 test risk difference 0.000400
# Party 1 accuracy 0.757062
# Finish party 2 test risk difference 0.000404
# Party 2 accuracy 0.751938
# Finish 5 testing epoch, Acc: 0.754500
# Finish 5 risk difference 0.000402
# **********
# epoch 6
# tensor(0.6055, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753000
# Party 1 accuracy 0.748667
# Party 1 risk difference 0.000099
# Party 2 risk difference 0.000726
# global training risk dfference: 0.000313
# Finish 6 training epoch, Acc: 0.750833
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 6 testing epoch, Acc: 0.754631
# Finish 6 risk difference 0.000000
# **********
# epoch 7
# tensor(0.5958, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748933
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000206
# global training risk dfference: 0.000103
# Finish 7 training epoch, Acc: 0.750933
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 7 testing epoch, Acc: 0.754631
# Finish 7 risk difference 0.000000
# **********
# epoch 8
# tensor(0.5876, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748867
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000000
# global training risk dfference: 0.000000
# Finish 8 training epoch, Acc: 0.750900
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 8 testing epoch, Acc: 0.754631
# Finish 8 risk difference 0.000000
# **********
# epoch 9
# tensor(0.5806, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748867
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000000
# global training risk dfference: 0.000000
# Finish 9 training epoch, Acc: 0.750900
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 9 testing epoch, Acc: 0.754631
# Finish 9 risk difference 0.000000
# **********
# epoch 10
# tensor(0.5747, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748867
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000000
# global training risk dfference: 0.000000
# Finish 10 training epoch, Acc: 0.750900
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 10 testing epoch, Acc: 0.754631
# Finish 10 risk difference 0.000000
# **********
# epoch 1
# tensor(0.5695, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748867
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000000
# global training risk dfference: 0.000000
# Finish 1 training epoch, Acc: 0.750900
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 1 testing epoch, Acc: 0.754631
# Finish 1 risk difference 0.000000
# **********
# epoch 2
# tensor(0.5650, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748867
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000000
# global training risk dfference: 0.000000
# Finish 2 training epoch, Acc: 0.750900
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 2 testing epoch, Acc: 0.754631
# Finish 2 risk difference 0.000000
# **********
# epoch 3
# tensor(0.5611, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748867
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000000
# global training risk dfference: 0.000000
# Finish 3 training epoch, Acc: 0.750900
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 3 testing epoch, Acc: 0.754631
# Finish 3 risk difference 0.000000
# **********
# epoch 4
# tensor(0.5575, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748867
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000000
# global training risk dfference: 0.000000
# Finish 4 training epoch, Acc: 0.750900
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 4 testing epoch, Acc: 0.754631
# Finish 4 risk difference 0.000000
# **********
# epoch 5
# tensor(0.5543, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748867
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000000
# global training risk dfference: 0.000000
# Finish 5 training epoch, Acc: 0.750900
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 5 testing epoch, Acc: 0.754631
# Finish 5 risk difference 0.000000
# **********
# epoch 6
# tensor(0.5514, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748867
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000000
# global training risk dfference: 0.000000
# Finish 6 training epoch, Acc: 0.750900
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 6 testing epoch, Acc: 0.754631
# Finish 6 risk difference 0.000000
# **********
# epoch 7
# tensor(0.5488, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748867
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000000
# global training risk dfference: 0.000000
# Finish 7 training epoch, Acc: 0.750900
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 7 testing epoch, Acc: 0.754631
# Finish 7 risk difference 0.000000
# **********
# epoch 8
# tensor(0.5463, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748867
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000000
# global training risk dfference: 0.000000
# Finish 8 training epoch, Acc: 0.750900
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 8 testing epoch, Acc: 0.754631
# Finish 8 risk difference 0.000000
# **********
# epoch 9
# tensor(0.5440, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748867
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000000
# global training risk dfference: 0.000000
# Finish 9 training epoch, Acc: 0.750900
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 9 testing epoch, Acc: 0.754631
# Finish 9 risk difference 0.000000
# **********
# epoch 10
# tensor(0.5418, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748867
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000000
# global training risk dfference: 0.000000
# Finish 10 training epoch, Acc: 0.750900
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 10 testing epoch, Acc: 0.754631
# Finish 10 risk difference 0.000000
# **********
# epoch 1
# tensor(0.5398, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748867
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000000
# global training risk dfference: 0.000000
# Finish 1 training epoch, Acc: 0.750900
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 1 testing epoch, Acc: 0.754631
# Finish 1 risk difference 0.000000
# **********
# epoch 2
# tensor(0.5378, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748867
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000000
# global training risk dfference: 0.000000
# Finish 2 training epoch, Acc: 0.750900
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 2 testing epoch, Acc: 0.754631
# Finish 2 risk difference 0.000000
# **********
# epoch 3
# tensor(0.5360, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748867
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000000
# global training risk dfference: 0.000000
# Finish 3 training epoch, Acc: 0.750900
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 3 testing epoch, Acc: 0.754631
# Finish 3 risk difference 0.000000
# **********
# epoch 4
# tensor(0.5342, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748867
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000000
# global training risk dfference: 0.000000
# Finish 4 training epoch, Acc: 0.750900
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 4 testing epoch, Acc: 0.754631
# Finish 4 risk difference 0.000000
# **********
# epoch 5
# tensor(0.5325, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748867
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000000
# global training risk dfference: 0.000000
# Finish 5 training epoch, Acc: 0.750900
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 5 testing epoch, Acc: 0.754631
# Finish 5 risk difference 0.000000
# **********
# epoch 6
# tensor(0.5308, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748867
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000000
# global training risk dfference: 0.000000
# Finish 6 training epoch, Acc: 0.750900
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 6 testing epoch, Acc: 0.754631
# Finish 6 risk difference 0.000000
# **********
# epoch 7
# tensor(0.5292, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748867
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000000
# global training risk dfference: 0.000000
# Finish 7 training epoch, Acc: 0.750900
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 7 testing epoch, Acc: 0.754631
# Finish 7 risk difference 0.000000
# **********
# epoch 8
# tensor(0.5277, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748867
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000000
# global training risk dfference: 0.000000
# Finish 8 training epoch, Acc: 0.750900
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 8 testing epoch, Acc: 0.754631
# Finish 8 risk difference 0.000000
# **********
# epoch 9
# tensor(0.5262, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748867
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000000
# global training risk dfference: 0.000000
# Finish 9 training epoch, Acc: 0.750900
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 9 testing epoch, Acc: 0.754631
# Finish 9 risk difference 0.000000
# **********
# epoch 10
# tensor(0.5247, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748867
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000000
# global training risk dfference: 0.000000
# Finish 10 training epoch, Acc: 0.750900
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 10 testing epoch, Acc: 0.754631
# Finish 10 risk difference 0.000000
# **********
# epoch 1
# tensor(0.5232, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748867
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000000
# global training risk dfference: 0.000000
# Finish 1 training epoch, Acc: 0.750900
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 1 testing epoch, Acc: 0.754631
# Finish 1 risk difference 0.000000
# **********
# epoch 2
# tensor(0.5218, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748867
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000000
# global training risk dfference: 0.000000
# Finish 2 training epoch, Acc: 0.750900
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 2 testing epoch, Acc: 0.754631
# Finish 2 risk difference 0.000000
# **********
# epoch 3
# tensor(0.5205, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748867
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000000
# global training risk dfference: 0.000000
# Finish 3 training epoch, Acc: 0.750900
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 3 testing epoch, Acc: 0.754631
# Finish 3 risk difference 0.000000
# **********
# epoch 4
# tensor(0.5191, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748867
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000000
# global training risk dfference: 0.000000
# Finish 4 training epoch, Acc: 0.750900
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 4 testing epoch, Acc: 0.754631
# Finish 4 risk difference 0.000000
# **********
# epoch 5
# tensor(0.5178, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748867
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000000
# global training risk dfference: 0.000000
# Finish 5 training epoch, Acc: 0.750900
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 5 testing epoch, Acc: 0.754631
# Finish 5 risk difference 0.000000
# **********
# epoch 6
# tensor(0.5165, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748867
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000000
# global training risk dfference: 0.000000
# Finish 6 training epoch, Acc: 0.750900
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 6 testing epoch, Acc: 0.754631
# Finish 6 risk difference 0.000000
# **********
# epoch 7
# tensor(0.5153, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748867
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000000
# global training risk dfference: 0.000000
# Finish 7 training epoch, Acc: 0.750900
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 7 testing epoch, Acc: 0.754631
# Finish 7 risk difference 0.000000
# **********
# epoch 8
# tensor(0.5140, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748933
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000206
# global training risk dfference: 0.000103
# Finish 8 training epoch, Acc: 0.750933
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 8 testing epoch, Acc: 0.754631
# Finish 8 risk difference 0.000000
# **********
# epoch 9
# tensor(0.5128, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748933
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000206
# global training risk dfference: 0.000103
# Finish 9 training epoch, Acc: 0.750933
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 9 testing epoch, Acc: 0.754631
# Finish 9 risk difference 0.000000
# **********
# epoch 10
# tensor(0.5116, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748933
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000206
# global training risk dfference: 0.000103
# Finish 10 training epoch, Acc: 0.750933
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 10 testing epoch, Acc: 0.754631
# Finish 10 risk difference 0.000000
# **********
# epoch 1
# tensor(0.5104, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748933
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000206
# global training risk dfference: 0.000103
# Finish 1 training epoch, Acc: 0.750933
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 1 testing epoch, Acc: 0.754631
# Finish 1 risk difference 0.000000
# **********
# epoch 2
# tensor(0.5093, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748933
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000206
# global training risk dfference: 0.000103
# Finish 2 training epoch, Acc: 0.750933
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 2 testing epoch, Acc: 0.754631
# Finish 2 risk difference 0.000000
# **********
# epoch 3
# tensor(0.5081, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748933
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000206
# global training risk dfference: 0.000103
# Finish 3 training epoch, Acc: 0.750933
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 3 testing epoch, Acc: 0.754631
# Finish 3 risk difference 0.000000
# **********
# epoch 4
# tensor(0.5070, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748933
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000206
# global training risk dfference: 0.000103
# Finish 4 training epoch, Acc: 0.750933
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 4 testing epoch, Acc: 0.754631
# Finish 4 risk difference 0.000000
# **********
# epoch 5
# tensor(0.5059, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748933
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000206
# global training risk dfference: 0.000103
# Finish 5 training epoch, Acc: 0.750933
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 5 testing epoch, Acc: 0.754631
# Finish 5 risk difference 0.000000
# **********
# epoch 6
# tensor(0.5048, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748933
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000206
# global training risk dfference: 0.000103
# Finish 6 training epoch, Acc: 0.750933
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 6 testing epoch, Acc: 0.754631
# Finish 6 risk difference 0.000000
# **********
# epoch 7
# tensor(0.5038, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748933
# Party 1 risk difference 0.000000
# Party 2 risk difference 0.000206
# global training risk dfference: 0.000103
# Finish 7 training epoch, Acc: 0.750933
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 7 testing epoch, Acc: 0.754631
# Finish 7 risk difference 0.000000
# **********
# epoch 8
# tensor(0.5027, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753000
# Party 1 accuracy 0.748933
# Party 1 risk difference 0.000205
# Party 2 risk difference 0.000206
# global training risk dfference: 0.000206
# Finish 8 training epoch, Acc: 0.750967
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 8 testing epoch, Acc: 0.754631
# Finish 8 risk difference 0.000000
# **********
# epoch 9
# tensor(0.5017, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753000
# Party 1 accuracy 0.748933
# Party 1 risk difference 0.000205
# Party 2 risk difference 0.000206
# global training risk dfference: 0.000206
# Finish 9 training epoch, Acc: 0.750967
# Finish party 1 test risk difference 0.000000
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 9 testing epoch, Acc: 0.754631
# Finish 9 risk difference 0.000000
# **********
# epoch 10
# tensor(0.5007, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748933
# Party 1 risk difference 0.000411
# Party 2 risk difference 0.000206
# global training risk dfference: 0.000309
# Finish 10 training epoch, Acc: 0.750933
# Finish party 1 test risk difference 0.000391
# Party 1 accuracy 0.757456
# Finish party 2 test risk difference 0.000000
# Party 2 accuracy 0.752069
# Finish 10 testing epoch, Acc: 0.754763
# Finish 10 risk difference 0.000195
# **********
# epoch 1
# tensor(0.4997, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.752933
# Party 1 accuracy 0.748933
# Party 1 risk difference 0.000411
# Party 2 risk difference 0.000206
# global training risk dfference: 0.000309
# Finish 1 training epoch, Acc: 0.750933
# Finish party 1 test risk difference 0.000391
# Party 1 accuracy 0.757456
# Finish party 2 test risk difference 0.000404
# Party 2 accuracy 0.751938
# Finish 1 testing epoch, Acc: 0.754697
# Finish 1 risk difference 0.000006
# **********
# epoch 2
# tensor(0.4987, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753000
# Party 1 accuracy 0.748933
# Party 1 risk difference 0.000312
# Party 2 risk difference 0.000206
# global training risk dfference: 0.000259
# Finish 2 training epoch, Acc: 0.750967
# Finish party 1 test risk difference 0.000391
# Party 1 accuracy 0.757456
# Finish party 2 test risk difference 0.000404
# Party 2 accuracy 0.751938
# Finish 2 testing epoch, Acc: 0.754697
# Finish 2 risk difference 0.000006
# **********
# epoch 3
# tensor(0.4977, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753067
# Party 1 accuracy 0.749067
# Party 1 risk difference 0.000320
# Party 2 risk difference 0.000009
# global training risk dfference: 0.000165
# Finish 3 training epoch, Acc: 0.751067
# Finish party 1 test risk difference 0.000587
# Party 1 accuracy 0.757588
# Finish party 2 test risk difference 0.000808
# Party 2 accuracy 0.752069
# Finish 3 testing epoch, Acc: 0.754829
# Finish 3 risk difference 0.000109
# **********
# epoch 4
# tensor(0.4968, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753133
# Party 1 accuracy 0.749067
# Party 1 risk difference 0.000222
# Party 2 risk difference 0.000385
# global training risk dfference: 0.000082
# Finish 4 training epoch, Acc: 0.751100
# Finish party 1 test risk difference 0.000587
# Party 1 accuracy 0.757588
# Finish party 2 test risk difference 0.000614
# Party 2 accuracy 0.752201
# Finish 4 testing epoch, Acc: 0.754894
# Finish 4 risk difference 0.000012
# **********
# epoch 5
# tensor(0.4958, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753133
# Party 1 accuracy 0.749200
# Party 1 risk difference 0.000328
# Party 2 risk difference 0.000278
# global training risk dfference: 0.000026
# Finish 5 training epoch, Acc: 0.751167
# Finish party 1 test risk difference 0.000783
# Party 1 accuracy 0.757719
# Finish party 2 test risk difference 0.000614
# Party 2 accuracy 0.752201
# Finish 5 testing epoch, Acc: 0.754960
# Finish 5 risk difference 0.000086
# **********
# epoch 6
# tensor(0.4949, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753133
# Party 1 accuracy 0.749267
# Party 1 risk difference 0.000328
# Party 2 risk difference 0.000376
# global training risk dfference: 0.000024
# Finish 6 training epoch, Acc: 0.751200
# Finish party 1 test risk difference 0.000783
# Party 1 accuracy 0.757719
# Finish party 2 test risk difference 0.000419
# Party 2 accuracy 0.752332
# Finish 6 testing epoch, Acc: 0.755026
# Finish 6 risk difference 0.000184
# **********
# epoch 7
# tensor(0.4940, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753133
# Party 1 accuracy 0.749267
# Party 1 risk difference 0.000328
# Party 2 risk difference 0.000376
# global training risk dfference: 0.000024
# Finish 7 training epoch, Acc: 0.751200
# Finish party 1 test risk difference 0.000979
# Party 1 accuracy 0.757588
# Finish party 2 test risk difference 0.000419
# Party 2 accuracy 0.752332
# Finish 7 testing epoch, Acc: 0.754960
# Finish 7 risk difference 0.000281
# **********
# epoch 8
# tensor(0.4931, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753133
# Party 1 accuracy 0.749333
# Party 1 risk difference 0.000328
# Party 2 risk difference 0.000170
# global training risk dfference: 0.000079
# Finish 8 training epoch, Acc: 0.751233
# Finish party 1 test risk difference 0.000979
# Party 1 accuracy 0.757588
# Finish party 2 test risk difference 0.000419
# Party 2 accuracy 0.752332
# Finish 8 testing epoch, Acc: 0.754960
# Finish 8 risk difference 0.000281
# **********
# epoch 9
# tensor(0.4922, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753133
# Party 1 accuracy 0.749333
# Party 1 risk difference 0.000328
# Party 2 risk difference 0.000170
# global training risk dfference: 0.000079
# Finish 9 training epoch, Acc: 0.751233
# Finish party 1 test risk difference 0.000979
# Party 1 accuracy 0.757588
# Finish party 2 test risk difference 0.000419
# Party 2 accuracy 0.752332
# Finish 9 testing epoch, Acc: 0.754960
# Finish 9 risk difference 0.000281
# **********
# epoch 10
# tensor(0.4913, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753133
# Party 1 accuracy 0.749333
# Party 1 risk difference 0.000328
# Party 2 risk difference 0.000170
# global training risk dfference: 0.000079
# Finish 10 training epoch, Acc: 0.751233
# Finish party 1 test risk difference 0.000979
# Party 1 accuracy 0.757588
# Finish party 2 test risk difference 0.000419
# Party 2 accuracy 0.752332
# Finish 10 testing epoch, Acc: 0.754960
# Finish 10 risk difference 0.000281
# **********
# epoch 1
# tensor(0.4905, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753133
# Party 1 accuracy 0.749333
# Party 1 risk difference 0.000328
# Party 2 risk difference 0.000170
# global training risk dfference: 0.000079
# Finish 1 training epoch, Acc: 0.751233
# Finish party 1 test risk difference 0.000979
# Party 1 accuracy 0.757588
# Finish party 2 test risk difference 0.000823
# Party 2 accuracy 0.752464
# Finish 1 testing epoch, Acc: 0.755026
# Finish 1 risk difference 0.000080
# **********
# epoch 2
# tensor(0.4896, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753133
# Party 1 accuracy 0.749267
# Party 1 risk difference 0.000328
# Party 2 risk difference 0.000036
# global training risk dfference: 0.000182
# Finish 2 training epoch, Acc: 0.751200
# Finish party 1 test risk difference 0.000579
# Party 1 accuracy 0.757719
# Finish party 2 test risk difference 0.000629
# Party 2 accuracy 0.752595
# Finish 2 testing epoch, Acc: 0.755157
# Finish 2 risk difference 0.000023
# **********
# epoch 3
# tensor(0.4888, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753200
# Party 1 accuracy 0.749333
# Party 1 risk difference 0.000534
# Party 2 risk difference 0.000242
# global training risk dfference: 0.000388
# Finish 3 training epoch, Acc: 0.751267
# Finish party 1 test risk difference 0.000579
# Party 1 accuracy 0.757719
# Finish party 2 test risk difference 0.000629
# Party 2 accuracy 0.752595
# Finish 3 testing epoch, Acc: 0.755157
# Finish 3 risk difference 0.000023
# **********
# epoch 4
# tensor(0.4880, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753267
# Party 1 accuracy 0.749333
# Party 1 risk difference 0.000739
# Party 2 risk difference 0.000242
# global training risk dfference: 0.000491
# Finish 4 training epoch, Acc: 0.751300
# Finish party 1 test risk difference 0.000775
# Party 1 accuracy 0.757850
# Finish party 2 test risk difference 0.000629
# Party 2 accuracy 0.752595
# Finish 4 testing epoch, Acc: 0.755223
# Finish 4 risk difference 0.000075
# **********
# epoch 5
# tensor(0.4872, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753333
# Party 1 accuracy 0.749400
# Party 1 risk difference 0.000641
# Party 2 risk difference 0.000144
# global training risk dfference: 0.000392
# Finish 5 training epoch, Acc: 0.751367
# Finish party 1 test risk difference 0.000375
# Party 1 accuracy 0.757719
# Finish party 2 test risk difference 0.000045
# Party 2 accuracy 0.752464
# Finish 5 testing epoch, Acc: 0.755091
# Finish 5 risk difference 0.000166
# **********
# epoch 6
# tensor(0.4864, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753467
# Party 1 accuracy 0.749533
# Party 1 risk difference 0.000550
# Party 2 risk difference 0.000054
# global training risk dfference: 0.000302
# Finish 6 training epoch, Acc: 0.751500
# Finish party 1 test risk difference 0.000571
# Party 1 accuracy 0.757850
# Finish party 2 test risk difference 0.000464
# Party 2 accuracy 0.752989
# Finish 6 testing epoch, Acc: 0.755420
# Finish 6 risk difference 0.000057
# **********
# epoch 7
# tensor(0.4856, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753533
# Party 1 accuracy 0.749600
# Party 1 risk difference 0.000254
# Party 2 risk difference 0.000368
# global training risk dfference: 0.000311
# Finish 7 training epoch, Acc: 0.751567
# Finish party 1 test risk difference 0.000767
# Party 1 accuracy 0.757982
# Finish party 2 test risk difference 0.000120
# Party 2 accuracy 0.753120
# Finish 7 testing epoch, Acc: 0.755551
# Finish 7 risk difference 0.000448
# **********
# epoch 8
# tensor(0.4848, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753467
# Party 1 accuracy 0.749733
# Party 1 risk difference 0.000155
# Party 2 risk difference 0.000171
# global training risk dfference: 0.000163
# Finish 8 training epoch, Acc: 0.751600
# Finish party 1 test risk difference 0.000767
# Party 1 accuracy 0.757982
# Finish party 2 test risk difference 0.000120
# Party 2 accuracy 0.753120
# Finish 8 testing epoch, Acc: 0.755551
# Finish 8 risk difference 0.000448
# **********
# epoch 9
# tensor(0.4841, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753267
# Party 1 accuracy 0.749867
# Party 1 risk difference 0.000141
# Party 2 risk difference 0.000026
# global training risk dfference: 0.000084
# Finish 9 training epoch, Acc: 0.751567
# Finish party 1 test risk difference 0.001158
# Party 1 accuracy 0.758245
# Finish party 2 test risk difference 0.000510
# Party 2 accuracy 0.753120
# Finish 9 testing epoch, Acc: 0.755683
# Finish 9 risk difference 0.000838
# **********
# epoch 10
# tensor(0.4833, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753333
# Party 1 accuracy 0.749867
# Party 1 risk difference 0.000239
# Party 2 risk difference 0.000026
# global training risk dfference: 0.000133
# Finish 10 training epoch, Acc: 0.751600
# Finish party 1 test risk difference 0.001354
# Party 1 accuracy 0.758376
# Finish party 2 test risk difference 0.001094
# Party 2 accuracy 0.753515
# Finish 10 testing epoch, Acc: 0.755945
# Finish 10 risk difference 0.001228
# **********
# epoch 1
# tensor(0.4826, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753400
# Party 1 accuracy 0.749933
# Party 1 risk difference 0.000231
# Party 2 risk difference 0.000125
# global training risk dfference: 0.000178
# Finish 1 training epoch, Acc: 0.751667
# Finish party 1 test risk difference 0.000954
# Party 1 accuracy 0.758507
# Finish party 2 test risk difference 0.001094
# Party 2 accuracy 0.753515
# Finish 1 testing epoch, Acc: 0.756011
# Finish 1 risk difference 0.001027
# **********
# epoch 2
# tensor(0.4819, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753400
# Party 1 accuracy 0.750067
# Party 1 risk difference 0.000180
# Party 2 risk difference 0.000322
# global training risk dfference: 0.000071
# Finish 2 training epoch, Acc: 0.751733
# Finish party 1 test risk difference 0.001150
# Party 1 accuracy 0.758639
# Finish party 2 test risk difference 0.000689
# Party 2 accuracy 0.753383
# Finish 2 testing epoch, Acc: 0.756011
# Finish 2 risk difference 0.000924
# **********
# epoch 3
# tensor(0.4811, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753533
# Party 1 accuracy 0.750000
# Party 1 risk difference 0.000018
# Party 2 risk difference 0.000421
# global training risk dfference: 0.000219
# Finish 3 training epoch, Acc: 0.751767
# Finish party 1 test risk difference 0.001150
# Party 1 accuracy 0.758639
# Finish party 2 test risk difference 0.000689
# Party 2 accuracy 0.753383
# Finish 3 testing epoch, Acc: 0.756011
# Finish 3 risk difference 0.000924
# **********
# epoch 4
# tensor(0.4804, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753533
# Party 1 accuracy 0.750067
# Party 1 risk difference 0.000018
# Party 2 risk difference 0.000519
# global training risk dfference: 0.000268
# Finish 4 training epoch, Acc: 0.751800
# Finish party 1 test risk difference 0.001345
# Party 1 accuracy 0.758770
# Finish party 2 test risk difference 0.000884
# Party 2 accuracy 0.753515
# Finish 4 testing epoch, Acc: 0.756142
# Finish 4 risk difference 0.001119
# **********
# epoch 5
# tensor(0.4797, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753600
# Party 1 accuracy 0.750200
# Party 1 risk difference 0.000188
# Party 2 risk difference 0.000716
# global training risk dfference: 0.000264
# Finish 5 training epoch, Acc: 0.751900
# Finish party 1 test risk difference 0.001345
# Party 1 accuracy 0.758770
# Finish party 2 test risk difference 0.001079
# Party 2 accuracy 0.753646
# Finish 5 testing epoch, Acc: 0.756208
# Finish 5 risk difference 0.001217
# **********
# epoch 6
# tensor(0.4791, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753667
# Party 1 accuracy 0.750267
# Party 1 risk difference 0.000089
# Party 2 risk difference 0.000815
# global training risk dfference: 0.000363
# Finish 6 training epoch, Acc: 0.751967
# Finish party 1 test risk difference 0.001345
# Party 1 accuracy 0.758770
# Finish party 2 test risk difference 0.001273
# Party 2 accuracy 0.753777
# Finish 6 testing epoch, Acc: 0.756274
# Finish 6 risk difference 0.001314
# **********
# epoch 7
# tensor(0.4784, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753733
# Party 1 accuracy 0.750333
# Party 1 risk difference 0.000207
# Party 2 risk difference 0.000806
# global training risk dfference: 0.000506
# Finish 7 training epoch, Acc: 0.752033
# Finish party 1 test risk difference 0.001541
# Party 1 accuracy 0.758639
# Finish party 2 test risk difference 0.001273
# Party 2 accuracy 0.753777
# Finish 7 testing epoch, Acc: 0.756208
# Finish 7 risk difference 0.001412
# **********
# epoch 8
# tensor(0.4777, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753867
# Party 1 accuracy 0.750400
# Party 1 risk difference 0.000404
# Party 2 risk difference 0.000904
# global training risk dfference: 0.000654
# Finish 8 training epoch, Acc: 0.752133
# Finish party 1 test risk difference 0.001142
# Party 1 accuracy 0.758770
# Finish party 2 test risk difference 0.001663
# Party 2 accuracy 0.754040
# Finish 8 testing epoch, Acc: 0.756405
# Finish 8 risk difference 0.001406
# **********
# epoch 9
# tensor(0.4770, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753800
# Party 1 accuracy 0.750467
# Party 1 risk difference 0.000503
# Party 2 risk difference 0.000698
# global training risk dfference: 0.000600
# Finish 9 training epoch, Acc: 0.752133
# Finish party 1 test risk difference 0.001337
# Party 1 accuracy 0.758639
# Finish party 2 test risk difference 0.002052
# Party 2 accuracy 0.754303
# Finish 9 testing epoch, Acc: 0.756471
# Finish 9 risk difference 0.001699
# **********
# epoch 10
# tensor(0.4764, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753800
# Party 1 accuracy 0.750467
# Party 1 risk difference 0.000503
# Party 2 risk difference 0.000698
# global training risk dfference: 0.000600
# Finish 10 training epoch, Acc: 0.752133
# Finish party 1 test risk difference 0.001337
# Party 1 accuracy 0.758639
# Finish party 2 test risk difference 0.002037
# Party 2 accuracy 0.754434
# Finish 10 testing epoch, Acc: 0.756537
# Finish 10 risk difference 0.001693
# **********
# epoch 1
# tensor(0.4758, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753933
# Party 1 accuracy 0.750533
# Party 1 risk difference 0.000396
# Party 2 risk difference 0.000797
# global training risk dfference: 0.000596
# Finish 1 training epoch, Acc: 0.752233
# Finish party 1 test risk difference 0.001329
# Party 1 accuracy 0.758770
# Finish party 2 test risk difference 0.002037
# Party 2 accuracy 0.754434
# Finish 1 testing epoch, Acc: 0.756602
# Finish 1 risk difference 0.001688
# **********
# epoch 2
# tensor(0.4751, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753867
# Party 1 accuracy 0.750600
# Party 1 risk difference 0.000495
# Party 2 risk difference 0.000591
# global training risk dfference: 0.000543
# Finish 2 training epoch, Acc: 0.752233
# Finish party 1 test risk difference 0.001721
# Party 1 accuracy 0.758770
# Finish party 2 test risk difference 0.002232
# Party 2 accuracy 0.754566
# Finish 2 testing epoch, Acc: 0.756668
# Finish 2 risk difference 0.001980
# **********
# epoch 3
# tensor(0.4745, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753933
# Party 1 accuracy 0.750867
# Party 1 risk difference 0.000380
# Party 2 risk difference 0.000985
# global training risk dfference: 0.000682
# Finish 3 training epoch, Acc: 0.752400
# Finish party 1 test risk difference 0.002104
# Party 1 accuracy 0.759164
# Finish party 2 test risk difference 0.002816
# Party 2 accuracy 0.754434
# Finish 3 testing epoch, Acc: 0.756799
# Finish 3 risk difference 0.002463
# **********
# epoch 4
# tensor(0.4739, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753933
# Party 1 accuracy 0.750867
# Party 1 risk difference 0.000150
# Party 2 risk difference 0.000967
# global training risk dfference: 0.000558
# Finish 4 training epoch, Acc: 0.752400
# Finish party 1 test risk difference 0.002691
# Party 1 accuracy 0.759559
# Finish party 2 test risk difference 0.002606
# Party 2 accuracy 0.754434
# Finish 4 testing epoch, Acc: 0.756996
# Finish 4 risk difference 0.002652
# **********
# epoch 5
# tensor(0.4733, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753933
# Party 1 accuracy 0.751133
# Party 1 risk difference 0.000545
# Party 2 risk difference 0.001146
# global training risk dfference: 0.000845
# Finish 5 training epoch, Acc: 0.752533
# Finish party 1 test risk difference 0.002878
# Party 1 accuracy 0.759821
# Finish party 2 test risk difference 0.002996
# Party 2 accuracy 0.754434
# Finish 5 testing epoch, Acc: 0.757128
# Finish 5 risk difference 0.002939
# **********
# epoch 6
# tensor(0.4727, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.753933
# Party 1 accuracy 0.751333
# Party 1 risk difference 0.001137
# Party 2 risk difference 0.001531
# global training risk dfference: 0.001334
# Finish 6 training epoch, Acc: 0.752633
# Finish party 1 test risk difference 0.003074
# Party 1 accuracy 0.759953
# Finish party 2 test risk difference 0.003969
# Party 2 accuracy 0.754829
# Finish 6 testing epoch, Acc: 0.757391
# Finish 6 risk difference 0.003525
# **********
# epoch 7
# tensor(0.4721, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754400
# Party 1 accuracy 0.751600
# Party 1 risk difference 0.001828
# Party 2 risk difference 0.001818
# global training risk dfference: 0.001823
# Finish 7 training epoch, Acc: 0.753000
# Finish party 1 test risk difference 0.003066
# Party 1 accuracy 0.760084
# Finish party 2 test risk difference 0.003759
# Party 2 accuracy 0.754829
# Finish 7 testing epoch, Acc: 0.757456
# Finish 7 risk difference 0.003416
# **********
# epoch 8
# tensor(0.4715, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754733
# Party 1 accuracy 0.751600
# Party 1 risk difference 0.002017
# Party 2 risk difference 0.001800
# global training risk dfference: 0.001908
# Finish 8 training epoch, Acc: 0.753167
# Finish party 1 test risk difference 0.003849
# Party 1 accuracy 0.760610
# Finish party 2 test risk difference 0.004343
# Party 2 accuracy 0.754960
# Finish 8 testing epoch, Acc: 0.757785
# Finish 8 risk difference 0.004099
# **********
# epoch 9
# tensor(0.4709, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754800
# Party 1 accuracy 0.751733
# Party 1 risk difference 0.001812
# Party 2 risk difference 0.001997
# global training risk dfference: 0.001904
# Finish 9 training epoch, Acc: 0.753267
# Finish party 1 test risk difference 0.004632
# Party 1 accuracy 0.760610
# Finish party 2 test risk difference 0.003520
# Party 2 accuracy 0.755091
# Finish 9 testing epoch, Acc: 0.757850
# Finish 9 risk difference 0.004081
# **********
# epoch 10
# tensor(0.4703, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754867
# Party 1 accuracy 0.752400
# Party 1 risk difference 0.002108
# Party 2 risk difference 0.001961
# global training risk dfference: 0.002035
# Finish 10 training epoch, Acc: 0.753633
# Finish party 1 test risk difference 0.004811
# Party 1 accuracy 0.760741
# Finish party 2 test risk difference 0.003101
# Party 2 accuracy 0.755617
# Finish 10 testing epoch, Acc: 0.758179
# Finish 10 risk difference 0.003961
# **********
# epoch 1
# tensor(0.4698, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754867
# Party 1 accuracy 0.752867
# Party 1 risk difference 0.001788
# Party 2 risk difference 0.002238
# global training risk dfference: 0.002014
# Finish 1 training epoch, Acc: 0.753867
# Finish party 1 test risk difference 0.005790
# Party 1 accuracy 0.761398
# Finish party 2 test risk difference 0.002473
# Party 2 accuracy 0.756142
# Finish 1 testing epoch, Acc: 0.758770
# Finish 1 risk difference 0.004139
# **********
# epoch 2
# tensor(0.4692, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.755200
# Party 1 accuracy 0.753067
# Party 1 risk difference 0.001977
# Party 2 risk difference 0.002820
# global training risk dfference: 0.002399
# Finish 2 training epoch, Acc: 0.754133
# Finish party 1 test risk difference 0.004982
# Party 1 accuracy 0.761529
# Finish party 2 test risk difference 0.003027
# Party 2 accuracy 0.756799
# Finish 2 testing epoch, Acc: 0.759164
# Finish 2 risk difference 0.004012
# **********
# epoch 3
# tensor(0.4687, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.756067
# Party 1 accuracy 0.753733
# Party 1 risk difference 0.001115
# Party 2 risk difference 0.002372
# global training risk dfference: 0.001744
# Finish 3 training epoch, Acc: 0.754900
# Finish party 1 test risk difference 0.005953
# Party 1 accuracy 0.761792
# Finish party 2 test risk difference 0.002189
# Party 2 accuracy 0.757850
# Finish 3 testing epoch, Acc: 0.759821
# Finish 3 risk difference 0.004081
# **********
# epoch 4
# tensor(0.4681, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.756867
# Party 1 accuracy 0.755000
# Party 1 risk difference 0.000257
# Party 2 risk difference 0.001485
# global training risk dfference: 0.000614
# Finish 4 training epoch, Acc: 0.755933
# Finish party 1 test risk difference 0.004941
# Party 1 accuracy 0.762449
# Finish party 2 test risk difference 0.001350
# Party 2 accuracy 0.758639
# Finish 4 testing epoch, Acc: 0.760544
# Finish 4 risk difference 0.003156
# **********
# epoch 5
# tensor(0.4676, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.757400
# Party 1 accuracy 0.755867
# Party 1 risk difference 0.001202
# Party 2 risk difference 0.000113
# global training risk dfference: 0.000543
# Finish 5 training epoch, Acc: 0.756633
# Finish party 1 test risk difference 0.004933
# Party 1 accuracy 0.762843
# Finish party 2 test risk difference 0.001350
# Party 2 accuracy 0.758639
# Finish 5 testing epoch, Acc: 0.760741
# Finish 5 risk difference 0.003151
# **********
# epoch 6
# tensor(0.4671, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.757667
# Party 1 accuracy 0.756067
# Party 1 risk difference 0.002131
# Party 2 risk difference 0.000720
# global training risk dfference: 0.001424
# Finish 6 training epoch, Acc: 0.756867
# Finish party 1 test risk difference 0.005324
# Party 1 accuracy 0.762843
# Finish party 2 test risk difference 0.000527
# Party 2 accuracy 0.758507
# Finish 6 testing epoch, Acc: 0.760675
# Finish 6 risk difference 0.002938
# **********
# epoch 7
# tensor(0.4666, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.757933
# Party 1 accuracy 0.756200
# Party 1 risk difference 0.002558
# Party 2 risk difference 0.001150
# global training risk dfference: 0.001853
# Finish 7 training epoch, Acc: 0.757067
# Finish party 1 test risk difference 0.004517
# Party 1 accuracy 0.762975
# Finish party 2 test risk difference 0.000707
# Party 2 accuracy 0.758507
# Finish 7 testing epoch, Acc: 0.760741
# Finish 7 risk difference 0.002622
# **********
# epoch 8
# tensor(0.4660, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.758000
# Party 1 accuracy 0.756333
# Party 1 risk difference 0.002673
# Party 2 risk difference 0.001061
# global training risk dfference: 0.001866
# Finish 8 training epoch, Acc: 0.757167
# Finish party 1 test risk difference 0.004313
# Party 1 accuracy 0.762975
# Finish party 2 test risk difference 0.001096
# Party 2 accuracy 0.758770
# Finish 8 testing epoch, Acc: 0.760872
# Finish 8 risk difference 0.002714
# **********
# epoch 9
# tensor(0.4655, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.757933
# Party 1 accuracy 0.756467
# Party 1 risk difference 0.002574
# Party 2 risk difference 0.001383
# global training risk dfference: 0.001977
# Finish 9 training epoch, Acc: 0.757200
# Finish party 1 test risk difference 0.004313
# Party 1 accuracy 0.762975
# Finish party 2 test risk difference 0.001486
# Party 2 accuracy 0.758770
# Finish 9 testing epoch, Acc: 0.760872
# Finish 9 risk difference 0.002909
# **********
# epoch 10
# tensor(0.4650, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.757800
# Party 1 accuracy 0.756400
# Party 1 risk difference 0.002377
# Party 2 risk difference 0.000998
# global training risk dfference: 0.001686
# Finish 10 training epoch, Acc: 0.757100
# Finish party 1 test risk difference 0.004305
# Party 1 accuracy 0.763106
# Finish party 2 test risk difference 0.001875
# Party 2 accuracy 0.758770
# Finish 10 testing epoch, Acc: 0.760938
# Finish 10 risk difference 0.003099
# **********
# epoch 1
# tensor(0.4645, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.757733
# Party 1 accuracy 0.756400
# Party 1 risk difference 0.002582
# Party 2 risk difference 0.000801
# global training risk dfference: 0.001690
# Finish 1 training epoch, Acc: 0.757067
# Finish party 1 test risk difference 0.004500
# Party 1 accuracy 0.762975
# Finish party 2 test risk difference 0.001665
# Party 2 accuracy 0.758770
# Finish 1 testing epoch, Acc: 0.760872
# Finish 1 risk difference 0.003093
# **********
# epoch 2
# tensor(0.4641, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.757600
# Party 1 accuracy 0.756533
# Party 1 risk difference 0.002492
# Party 2 risk difference 0.000819
# global training risk dfference: 0.001654
# Finish 2 training epoch, Acc: 0.757067
# Finish party 1 test risk difference 0.004101
# Party 1 accuracy 0.762843
# ...
# Party 1 accuracy 0.778600
# Party 1 accuracy 0.778000
# Party 1 risk difference 0.046495
# Party 2 risk difference 0.051636
# global training risk dfference: 0.049066
# Finish 7 training epoch, Acc: 0.778300
# Finish party 1 test risk difference 0.052673
# Party 1 accuracy 0.778347
# Finish party 2 test risk difference 0.057420
# Party 2 accuracy 0.780449
# Finish 7 testing epoch, Acc: 0.779398
# Finish 7 risk difference 0.055071
# **********
# epoch 8
# tensor(0.4414, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.778600
# Party 1 accuracy 0.778067
# Party 1 risk difference 0.047481
# Party 2 risk difference 0.052128
# global training risk dfference: 0.049806
# Finish 8 training epoch, Acc: 0.778333
# Finish party 1 test risk difference 0.053651
# Party 1 accuracy 0.778479
# Finish party 2 test risk difference 0.058004
# Party 2 accuracy 0.780844
# Finish 8 testing epoch, Acc: 0.779661
# Finish 8 risk difference 0.055852
# **********
# epoch 9
# tensor(0.4412, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.779200
# Party 1 accuracy 0.777667
# Party 1 risk difference 0.048353
# Party 2 risk difference 0.052899
# global training risk dfference: 0.050627
# Finish 9 training epoch, Acc: 0.778433
# Finish party 1 test risk difference 0.055413
# Party 1 accuracy 0.778610
# Finish party 2 test risk difference 0.058962
# Party 2 accuracy 0.780844
# Finish 9 testing epoch, Acc: 0.779727
# Finish 9 risk difference 0.057212
# **********
# epoch 10
# tensor(0.4409, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.780000
# Party 1 accuracy 0.778333
# Party 1 risk difference 0.048823
# Party 2 risk difference 0.054565
# global training risk dfference: 0.051695
# Finish 10 training epoch, Acc: 0.779167
# Finish party 1 test risk difference 0.055184
# Party 1 accuracy 0.778741
# Finish party 2 test risk difference 0.060115
# Party 2 accuracy 0.781500
# Finish 10 testing epoch, Acc: 0.780121
# Finish 10 risk difference 0.057671
# **********
# epoch 1
# tensor(0.4407, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.780067
# Party 1 accuracy 0.778733
# Party 1 risk difference 0.049284
# Party 2 risk difference 0.055228
# global training risk dfference: 0.052256
# Finish 1 training epoch, Acc: 0.779400
# Finish party 1 test risk difference 0.055364
# Party 1 accuracy 0.778873
# Finish party 2 test risk difference 0.062242
# Party 2 accuracy 0.782026
# Finish 1 testing epoch, Acc: 0.780449
# Finish 1 risk difference 0.058825
# **********
# epoch 2
# tensor(0.4405, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.780800
# Party 1 accuracy 0.778667
# Party 1 risk difference 0.049958
# Party 2 risk difference 0.055899
# global training risk dfference: 0.052930
# Finish 2 training epoch, Acc: 0.779733
# Finish party 1 test risk difference 0.055143
# Party 1 accuracy 0.779135
# Finish party 2 test risk difference 0.062407
# Party 2 accuracy 0.781632
# Finish 2 testing epoch, Acc: 0.780384
# Finish 2 risk difference 0.058796
# **********
# epoch 3
# tensor(0.4402, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.781067
# Party 1 accuracy 0.778867
# Party 1 risk difference 0.050534
# Party 2 risk difference 0.056267
# global training risk dfference: 0.053401
# Finish 3 training epoch, Acc: 0.779967
# Finish party 1 test risk difference 0.055127
# Party 1 accuracy 0.779135
# Finish party 2 test risk difference 0.062362
# Party 2 accuracy 0.782289
# Finish 3 testing epoch, Acc: 0.780712
# Finish 3 risk difference 0.058768
# **********
# epoch 4
# tensor(0.4400, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.781200
# Party 1 accuracy 0.779200
# Party 1 risk difference 0.050411
# Party 2 risk difference 0.056544
# global training risk dfference: 0.053478
# Finish 4 training epoch, Acc: 0.780200
# Finish party 1 test risk difference 0.054915
# Party 1 accuracy 0.779004
# Finish party 2 test risk difference 0.061329
# Party 2 accuracy 0.782946
# Finish 4 testing epoch, Acc: 0.780975
# Finish 4 risk difference 0.058147
# **********
# epoch 5
# tensor(0.4398, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.781533
# Party 1 accuracy 0.779533
# Party 1 risk difference 0.050083
# Party 2 risk difference 0.056911
# global training risk dfference: 0.053498
# Finish 5 training epoch, Acc: 0.780533
# Finish party 1 test risk difference 0.055110
# Party 1 accuracy 0.778873
# Finish party 2 test risk difference 0.061494
# Party 2 accuracy 0.782289
# Finish 5 testing epoch, Acc: 0.780581
# Finish 5 risk difference 0.058331
# **********
# epoch 6
# tensor(0.4395, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.781800
# Party 1 accuracy 0.779667
# Party 1 risk difference 0.049960
# Party 2 risk difference 0.057180
# global training risk dfference: 0.053571
# Finish 6 training epoch, Acc: 0.780733
# Finish party 1 test risk difference 0.054702
# Party 1 accuracy 0.778873
# Finish party 2 test risk difference 0.062078
# Party 2 accuracy 0.782420
# Finish 6 testing epoch, Acc: 0.780646
# Finish 6 risk difference 0.058417
# **********
# epoch 7
# tensor(0.4393, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.781800
# Party 1 accuracy 0.780133
# Party 1 risk difference 0.050429
# Party 2 risk difference 0.056633
# global training risk dfference: 0.053532
# Finish 7 training epoch, Acc: 0.780967
# Finish party 1 test risk difference 0.054499
# Party 1 accuracy 0.779135
# Finish party 2 test risk difference 0.062048
# Party 2 accuracy 0.782420
# Finish 7 testing epoch, Acc: 0.780778
# Finish 7 risk difference 0.058302
# **********
# epoch 8
# tensor(0.4391, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.782067
# Party 1 accuracy 0.779933
# Party 1 risk difference 0.050594
# Party 2 risk difference 0.056606
# global training risk dfference: 0.053601
# Finish 8 training epoch, Acc: 0.781000
# Finish party 1 test risk difference 0.052296
# Party 1 accuracy 0.779530
# Finish party 2 test risk difference 0.062632
# Party 2 accuracy 0.782552
# Finish 8 testing epoch, Acc: 0.781041
# Finish 8 risk difference 0.057487
# **********
# epoch 9
# tensor(0.4389, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.782467
# Party 1 accuracy 0.780067
# Party 1 risk difference 0.049238
# Party 2 risk difference 0.056677
# global training risk dfference: 0.052958
# Finish 9 training epoch, Acc: 0.781267
# Finish party 1 test risk difference 0.051880
# Party 1 accuracy 0.780449
# Finish party 2 test risk difference 0.063591
# Party 2 accuracy 0.782289
# Finish 9 testing epoch, Acc: 0.781369
# Finish 9 risk difference 0.057757
# **********
# epoch 10
# tensor(0.4387, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.782333
# Party 1 accuracy 0.779667
# Party 1 risk difference 0.049724
# Party 2 risk difference 0.057448
# global training risk dfference: 0.053586
# Finish 10 training epoch, Acc: 0.781000
# Finish party 1 test risk difference 0.051676
# Party 1 accuracy 0.780449
# Finish party 2 test risk difference 0.063771
# Party 2 accuracy 0.782814
# Finish 10 testing epoch, Acc: 0.781632
# Finish 10 risk difference 0.057745
# **********
# epoch 1
# tensor(0.4384, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.782600
# Party 1 accuracy 0.780067
# Party 1 risk difference 0.050209
# Party 2 risk difference 0.057716
# global training risk dfference: 0.053963
# Finish 1 training epoch, Acc: 0.781333
# Finish party 1 test risk difference 0.051660
# Party 1 accuracy 0.780712
# Finish party 2 test risk difference 0.063756
# Party 2 accuracy 0.782683
# Finish 1 testing epoch, Acc: 0.781698
# Finish 1 risk difference 0.057728
# **********
# epoch 2
# tensor(0.4382, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.782267
# Party 1 accuracy 0.779933
# Party 1 risk difference 0.050900
# Party 2 risk difference 0.057089
# global training risk dfference: 0.053996
# Finish 2 training epoch, Acc: 0.781100
# Finish party 1 test risk difference 0.051651
# Party 1 accuracy 0.780844
# Finish party 2 test risk difference 0.062932
# Party 2 accuracy 0.782814
# Finish 2 testing epoch, Acc: 0.781829
# Finish 2 risk difference 0.057314
# **********
# epoch 3
# tensor(0.4380, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.781933
# Party 1 accuracy 0.779867
# Party 1 risk difference 0.051286
# Party 2 risk difference 0.057976
# global training risk dfference: 0.054632
# Finish 3 training epoch, Acc: 0.780900
# Finish party 1 test risk difference 0.050844
# Party 1 accuracy 0.780975
# Finish party 2 test risk difference 0.063307
# Party 2 accuracy 0.782683
# Finish 3 testing epoch, Acc: 0.781829
# Finish 3 risk difference 0.057096
# **********
# epoch 4
# tensor(0.4378, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.781800
# Party 1 accuracy 0.779667
# Party 1 risk difference 0.052060
# Party 2 risk difference 0.058038
# global training risk dfference: 0.055050
# Finish 4 training epoch, Acc: 0.780733
# Finish party 1 test risk difference 0.051031
# Party 1 accuracy 0.780975
# Finish party 2 test risk difference 0.063681
# Party 2 accuracy 0.782552
# Finish 4 testing epoch, Acc: 0.781763
# Finish 4 risk difference 0.057377
# **********
# epoch 5
# tensor(0.4376, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.782000
# Party 1 accuracy 0.779600
# Party 1 risk difference 0.052537
# Party 2 risk difference 0.058208
# global training risk dfference: 0.055374
# Finish 5 training epoch, Acc: 0.780800
# Finish party 1 test risk difference 0.051610
# Party 1 accuracy 0.780975
# Finish party 2 test risk difference 0.063068
# Party 2 accuracy 0.782946
# Finish 5 testing epoch, Acc: 0.781960
# Finish 5 risk difference 0.057360
# **********
# epoch 6
# tensor(0.4374, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.781933
# Party 1 accuracy 0.779467
# Party 1 risk difference 0.053302
# Party 2 risk difference 0.058566
# global training risk dfference: 0.055936
# Finish 6 training epoch, Acc: 0.780700
# Finish party 1 test risk difference 0.051610
# Party 1 accuracy 0.780975
# Finish party 2 test risk difference 0.063457
# Party 2 accuracy 0.782683
# Finish 6 testing epoch, Acc: 0.781829
# Finish 6 risk difference 0.057555
# **********
# epoch 7
# tensor(0.4372, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.781800
# Party 1 accuracy 0.779533
# Party 1 risk difference 0.053483
# Party 2 risk difference 0.058450
# global training risk dfference: 0.055968
# Finish 7 training epoch, Acc: 0.780667
# Finish party 1 test risk difference 0.050990
# Party 1 accuracy 0.780581
# Finish party 2 test risk difference 0.063427
# Party 2 accuracy 0.782420
# Finish 7 testing epoch, Acc: 0.781500
# Finish 7 risk difference 0.057228
# **********
# epoch 8
# tensor(0.4370, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.781667
# Party 1 accuracy 0.779333
# Party 1 risk difference 0.053467
# Party 2 risk difference 0.058423
# global training risk dfference: 0.055947
# Finish 8 training epoch, Acc: 0.780500
# Finish party 1 test risk difference 0.051186
# Party 1 accuracy 0.780712
# Finish party 2 test risk difference 0.063607
# Party 2 accuracy 0.782420
# Finish 8 testing epoch, Acc: 0.781566
# Finish 8 risk difference 0.057417
# **********
# epoch 9
# tensor(0.4368, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.781533
# Party 1 accuracy 0.779267
# Party 1 risk difference 0.053451
# Party 2 risk difference 0.058199
# global training risk dfference: 0.055827
# Finish 9 training epoch, Acc: 0.780400
# Finish party 1 test risk difference 0.050982
# Party 1 accuracy 0.780712
# Finish party 2 test risk difference 0.063203
# Party 2 accuracy 0.782552
# Finish 9 testing epoch, Acc: 0.781632
# Finish 9 risk difference 0.057113
# **********
# epoch 10
# tensor(0.4366, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.781533
# Party 1 accuracy 0.779267
# Party 1 risk difference 0.053040
# Party 2 risk difference 0.058091
# global training risk dfference: 0.055567
# Finish 10 training epoch, Acc: 0.780400
# Finish party 1 test risk difference 0.050175
# Party 1 accuracy 0.780581
# Finish party 2 test risk difference 0.062993
# Party 2 accuracy 0.782552
# Finish 10 testing epoch, Acc: 0.781566
# Finish 10 risk difference 0.056602
# **********
# epoch 1
# tensor(0.4364, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.781467
# Party 1 accuracy 0.779333
# Party 1 risk difference 0.053032
# Party 2 risk difference 0.057777
# global training risk dfference: 0.055407
# Finish 1 training epoch, Acc: 0.780400
# Finish party 1 test risk difference 0.049171
# Party 1 accuracy 0.780844
# Finish party 2 test risk difference 0.061781
# Party 2 accuracy 0.782683
# Finish 1 testing epoch, Acc: 0.781763
# Finish 1 risk difference 0.055494
# **********
# epoch 2
# tensor(0.4362, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.781267
# Party 1 accuracy 0.779400
# Party 1 risk difference 0.053526
# Party 2 risk difference 0.057768
# global training risk dfference: 0.055649
# Finish 2 training epoch, Acc: 0.780333
# Finish party 1 test risk difference 0.049367
# Party 1 accuracy 0.780975
# Finish party 2 test risk difference 0.060957
# Party 2 accuracy 0.783077
# Finish 2 testing epoch, Acc: 0.782026
# Finish 2 risk difference 0.055184
# **********
# epoch 3
# tensor(0.4360, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.781133
# Party 1 accuracy 0.779333
# Party 1 risk difference 0.053008
# Party 2 risk difference 0.057043
# global training risk dfference: 0.055027
# Finish 3 training epoch, Acc: 0.780233
# Finish party 1 test risk difference 0.049563
# Party 1 accuracy 0.781106
# Finish party 2 test risk difference 0.060149
# Party 2 accuracy 0.783340
# Finish 3 testing epoch, Acc: 0.782223
# Finish 3 risk difference 0.054879
# **********
# epoch 4
# tensor(0.4358, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.781267
# Party 1 accuracy 0.779267
# Party 1 risk difference 0.052597
# Party 2 risk difference 0.056424
# global training risk dfference: 0.054513
# Finish 4 training epoch, Acc: 0.780267
# Finish party 1 test risk difference 0.049163
# Party 1 accuracy 0.781238
# Finish party 2 test risk difference 0.059939
# Party 2 accuracy 0.783603
# Finish 4 testing epoch, Acc: 0.782420
# Finish 4 risk difference 0.054575
# **********
# epoch 5
# tensor(0.4356, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.781333
# Party 1 accuracy 0.779533
# Party 1 risk difference 0.051874
# Party 2 risk difference 0.056102
# global training risk dfference: 0.053990
# Finish 5 training epoch, Acc: 0.780433
# Finish party 1 test risk difference 0.049163
# Party 1 accuracy 0.781238
# Finish party 2 test risk difference 0.059730
# Party 2 accuracy 0.783603
# Finish 5 testing epoch, Acc: 0.782420
# Finish 5 risk difference 0.054472
# **********
# epoch 6
# tensor(0.4354, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.781600
# Party 1 accuracy 0.780000
# Party 1 risk difference 0.050945
# Party 2 risk difference 0.055358
# global training risk dfference: 0.053154
# Finish 6 training epoch, Acc: 0.780800
# Finish party 1 test risk difference 0.048364
# Party 1 accuracy 0.781238
# Finish party 2 test risk difference 0.059715
# Party 2 accuracy 0.783997
# Finish 6 testing epoch, Acc: 0.782617
# Finish 6 risk difference 0.054064
# **********
# epoch 7
# tensor(0.4352, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.781533
# Party 1 accuracy 0.780067
# Party 1 risk difference 0.050830
# Party 2 risk difference 0.054721
# global training risk dfference: 0.052779
# Finish 7 training epoch, Acc: 0.780800
# Finish party 1 test risk difference 0.047156
# Party 1 accuracy 0.782026
# Finish party 2 test risk difference 0.059101
# Party 2 accuracy 0.784128
# Finish 7 testing epoch, Acc: 0.783077
# Finish 7 risk difference 0.053151
# **********
# epoch 8
# tensor(0.4350, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.781533
# Party 1 accuracy 0.780467
# Party 1 risk difference 0.050510
# Party 2 risk difference 0.053270
# global training risk dfference: 0.051894
# Finish 8 training epoch, Acc: 0.781000
# Finish party 1 test risk difference 0.047352
# Party 1 accuracy 0.781895
# Finish party 2 test risk difference 0.059296
# Party 2 accuracy 0.783997
# Finish 8 testing epoch, Acc: 0.782946
# Finish 8 risk difference 0.053346
# **********
# epoch 9
# tensor(0.4348, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.781467
# Party 1 accuracy 0.780333
# Party 1 risk difference 0.050502
# Party 2 risk difference 0.053055
# global training risk dfference: 0.051782
# Finish 9 training epoch, Acc: 0.780900
# Finish party 1 test risk difference 0.048135
# Party 1 accuracy 0.782157
# Finish party 2 test risk difference 0.058892
# Party 2 accuracy 0.783865
# Finish 9 testing epoch, Acc: 0.783011
# Finish 9 risk difference 0.053535
# **********
# epoch 10
# tensor(0.4346, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.781600
# Party 1 accuracy 0.780533
# Party 1 risk difference 0.050699
# Party 2 risk difference 0.052741
# global training risk dfference: 0.051724
# Finish 10 training epoch, Acc: 0.781067
# Finish party 1 test risk difference 0.048135
# Party 1 accuracy 0.782157
# Finish party 2 test risk difference 0.058892
# Party 2 accuracy 0.783865
# Finish 10 testing epoch, Acc: 0.783011
# Finish 10 risk difference 0.053535

# %%
# "no_fair"
for i in range(Iteration):
    # compute with the option "with fair" => Zafar et al.
    theta, bias = compute_model_parameter_fairness(weight, Sen_torch, ratio_fair, options[0], k)
# Out:
# **********
# epoch 1
# tensor(0.6011, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.824067
# Party 1 accuracy 0.825067
# Party 1 risk difference 0.181428
# Party 2 risk difference 0.178632
# global training risk dfference: 0.180037
# Finish 1 training epoch, Acc: 0.824567
# Finish party 1 test risk difference 0.130498
# Party 1 accuracy 0.820260
# Finish party 2 test risk difference 0.128313
# Party 2 accuracy 0.821180
# Finish 1 testing epoch, Acc: 0.820720
# Finish 1 risk difference 0.129410
# **********
# epoch 2
# tensor(0.5843, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.823200
# Party 1 accuracy 0.817533
# Party 1 risk difference 0.131403
# Party 2 risk difference 0.133356
# global training risk dfference: 0.132383
# Finish 2 training epoch, Acc: 0.820367
# Finish party 1 test risk difference 0.073331
# Party 1 accuracy 0.799107
# Finish party 2 test risk difference 0.080462
# Party 2 accuracy 0.796085
# Finish 2 testing epoch, Acc: 0.797596
# Finish 2 risk difference 0.076894
# **********
# epoch 3
# tensor(0.5706, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.799333
# Party 1 accuracy 0.797267
# Party 1 risk difference 0.076966
# Party 2 risk difference 0.081300
# global training risk dfference: 0.079132
# Finish 3 training epoch, Acc: 0.798300
# Finish party 1 test risk difference 0.032523
# Party 1 accuracy 0.775194
# Finish party 2 test risk difference 0.035475
# Party 2 accuracy 0.767705
# Finish 3 testing epoch, Acc: 0.771449
# Finish 3 risk difference 0.033987
# **********
# epoch 4
# tensor(0.5595, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.769267
# Party 1 accuracy 0.768800
# Party 1 risk difference 0.033804
# Party 2 risk difference 0.035016
# global training risk dfference: 0.034411
# Finish 4 training epoch, Acc: 0.769033
# Finish party 1 test risk difference 0.024181
# Party 1 accuracy 0.769675
# Finish party 2 test risk difference 0.026206
# Party 2 accuracy 0.763894
# Finish 4 testing epoch, Acc: 0.766785
# Finish 4 risk difference 0.025186
# **********
# epoch 5
# tensor(0.5503, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.763533
# Party 1 accuracy 0.762667
# Party 1 risk difference 0.022939
# Party 2 risk difference 0.025611
# global training risk dfference: 0.024275
# Finish 5 training epoch, Acc: 0.763100
# Finish party 1 test risk difference 0.018333
# Party 1 accuracy 0.766916
# Finish party 2 test risk difference 0.018419
# Party 2 accuracy 0.761267
# Finish 5 testing epoch, Acc: 0.764091
# Finish 5 risk difference 0.018371
# **********
# epoch 6
# tensor(0.5427, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.762200
# Party 1 accuracy 0.759867
# Party 1 risk difference 0.016746
# Party 2 risk difference 0.019341
# global training risk dfference: 0.018042
# Finish 6 training epoch, Acc: 0.761033
# Finish party 1 test risk difference 0.013269
# Party 1 accuracy 0.764157
# Finish party 2 test risk difference 0.014361
# Party 2 accuracy 0.759821
# Finish 6 testing epoch, Acc: 0.761989
# Finish 6 risk difference 0.013813
# **********
# epoch 7
# tensor(0.5364, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.759533
# Party 1 accuracy 0.757333
# Party 1 risk difference 0.011252
# Party 2 risk difference 0.014342
# global training risk dfference: 0.012796
# Finish 7 training epoch, Acc: 0.758433
# Finish party 1 test risk difference 0.009966
# Party 1 accuracy 0.762318
# Finish party 2 test risk difference 0.010108
# Party 2 accuracy 0.757982
# Finish 7 testing epoch, Acc: 0.760150
# Finish 7 risk difference 0.010035
# **********
# epoch 8
# tensor(0.5310, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.757933
# Party 1 accuracy 0.755267
# Party 1 risk difference 0.008036
# Party 2 risk difference 0.010212
# global training risk dfference: 0.009124
# Finish 8 training epoch, Acc: 0.756600
# Finish party 1 test risk difference 0.005864
# Party 1 accuracy 0.760741
# Finish party 2 test risk difference 0.006020
# Party 2 accuracy 0.756011
# Finish 8 testing epoch, Acc: 0.758376
# Finish 8 risk difference 0.005942
# **********
# epoch 9
# tensor(0.5264, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.756467
# Party 1 accuracy 0.753333
# Party 1 risk difference 0.005395
# Party 2 risk difference 0.005975
# global training risk dfference: 0.005685
# Finish 9 training epoch, Acc: 0.754900
# Finish party 1 test risk difference 0.005481
# Party 1 accuracy 0.760347
# Finish party 2 test risk difference 0.003684
# Party 2 accuracy 0.754697
# Finish 9 testing epoch, Acc: 0.757522
# Finish 9 risk difference 0.004581
# **********
# epoch 10
# tensor(0.5225, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.755400
# Party 1 accuracy 0.751867
# Party 1 risk difference 0.003726
# Party 2 risk difference 0.003610
# global training risk dfference: 0.003668
# Finish 10 training epoch, Acc: 0.753633
# Finish party 1 test risk difference 0.003915
# Party 1 accuracy 0.759296
# Finish party 2 test risk difference 0.002126
# Party 2 accuracy 0.753909
# Finish 10 testing epoch, Acc: 0.756602
# Finish 10 risk difference 0.003020
# **********
# epoch 1
# tensor(0.5191, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754400
# Party 1 accuracy 0.751067
# Party 1 risk difference 0.002246
# Party 2 risk difference 0.002732
# global training risk dfference: 0.002489
# Finish 1 training epoch, Acc: 0.752733
# Finish party 1 test risk difference 0.003523
# Party 1 accuracy 0.759296
# Finish party 2 test risk difference 0.002126
# Party 2 accuracy 0.753909
# Finish 1 testing epoch, Acc: 0.756602
# Finish 1 risk difference 0.002825
# **********
# epoch 2
# tensor(0.5161, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754333
# Party 1 accuracy 0.750800
# Party 1 risk difference 0.002147
# Party 2 risk difference 0.002947
# global training risk dfference: 0.002547
# Finish 2 training epoch, Acc: 0.752567
# Finish party 1 test risk difference 0.003327
# Party 1 accuracy 0.759164
# Finish party 2 test risk difference 0.002126
# Party 2 accuracy 0.753909
# Finish 2 testing epoch, Acc: 0.756537
# Finish 2 risk difference 0.002727
# **********
# epoch 3
# tensor(0.5134, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754200
# Party 1 accuracy 0.750733
# Party 1 risk difference 0.001949
# Party 2 risk difference 0.002652
# global training risk dfference: 0.002300
# Finish 3 training epoch, Acc: 0.752467
# Finish party 1 test risk difference 0.003327
# Party 1 accuracy 0.759164
# Finish party 2 test risk difference 0.002126
# Party 2 accuracy 0.753909
# Finish 3 testing epoch, Acc: 0.756537
# Finish 3 risk difference 0.002727
# **********
# epoch 4
# tensor(0.5110, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754133
# Party 1 accuracy 0.750533
# Party 1 risk difference 0.001851
# Party 2 risk difference 0.002356
# global training risk dfference: 0.002103
# Finish 4 training epoch, Acc: 0.752333
# Finish party 1 test risk difference 0.003327
# Party 1 accuracy 0.759164
# Finish party 2 test risk difference 0.002126
# Party 2 accuracy 0.753909
# Finish 4 testing epoch, Acc: 0.756537
# Finish 4 risk difference 0.002727
# **********
# epoch 5
# tensor(0.5088, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754000
# Party 1 accuracy 0.750400
# Party 1 risk difference 0.001653
# Party 2 risk difference 0.002464
# global training risk dfference: 0.002058
# Finish 5 training epoch, Acc: 0.752200
# Finish party 1 test risk difference 0.003327
# Party 1 accuracy 0.759164
# Finish party 2 test risk difference 0.001932
# Party 2 accuracy 0.753777
# Finish 5 testing epoch, Acc: 0.756471
# Finish 5 risk difference 0.002629
# **********
# epoch 6
# tensor(0.5068, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754000
# Party 1 accuracy 0.750400
# Party 1 risk difference 0.001653
# Party 2 risk difference 0.002464
# global training risk dfference: 0.002058
# Finish 6 training epoch, Acc: 0.752200
# Finish party 1 test risk difference 0.003132
# Party 1 accuracy 0.759033
# Finish party 2 test risk difference 0.001932
# Party 2 accuracy 0.753777
# Finish 6 testing epoch, Acc: 0.756405
# Finish 6 risk difference 0.002532
# **********
# epoch 7
# tensor(0.5050, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754000
# Party 1 accuracy 0.750400
# Party 1 risk difference 0.001653
# Party 2 risk difference 0.002464
# global training risk dfference: 0.002058
# Finish 7 training epoch, Acc: 0.752200
# Finish party 1 test risk difference 0.003132
# Party 1 accuracy 0.759033
# Finish party 2 test risk difference 0.001932
# Party 2 accuracy 0.753777
# Finish 7 testing epoch, Acc: 0.756405
# Finish 7 risk difference 0.002532
# **********
# epoch 8
# tensor(0.5033, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754000
# Party 1 accuracy 0.750400
# Party 1 risk difference 0.001653
# Party 2 risk difference 0.002464
# global training risk dfference: 0.002058
# Finish 8 training epoch, Acc: 0.752200
# Finish party 1 test risk difference 0.003132
# Party 1 accuracy 0.759033
# Finish party 2 test risk difference 0.001932
# Party 2 accuracy 0.753777
# Finish 8 testing epoch, Acc: 0.756405
# Finish 8 risk difference 0.002532
# **********
# epoch 9
# tensor(0.5018, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754000
# Party 1 accuracy 0.750400
# Party 1 risk difference 0.001653
# Party 2 risk difference 0.002464
# global training risk dfference: 0.002058
# Finish 9 training epoch, Acc: 0.752200
# Finish party 1 test risk difference 0.003132
# Party 1 accuracy 0.759033
# Finish party 2 test risk difference 0.001932
# Party 2 accuracy 0.753777
# Finish 9 testing epoch, Acc: 0.756405
# Finish 9 risk difference 0.002532
# **********
# epoch 10
# tensor(0.5003, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754000
# Party 1 accuracy 0.750400
# Party 1 risk difference 0.001653
# Party 2 risk difference 0.002464
# global training risk dfference: 0.002058
# Finish 10 training epoch, Acc: 0.752200
# Finish party 1 test risk difference 0.003132
# Party 1 accuracy 0.759033
# Finish party 2 test risk difference 0.001932
# Party 2 accuracy 0.753777
# Finish 10 testing epoch, Acc: 0.756405
# Finish 10 risk difference 0.002532
# **********
# epoch 1
# tensor(0.4989, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754000
# Party 1 accuracy 0.750400
# Party 1 risk difference 0.001653
# Party 2 risk difference 0.002464
# global training risk dfference: 0.002058
# Finish 1 training epoch, Acc: 0.752200
# Finish party 1 test risk difference 0.003132
# Party 1 accuracy 0.759033
# Finish party 2 test risk difference 0.001932
# Party 2 accuracy 0.753777
# Finish 1 testing epoch, Acc: 0.756405
# Finish 1 risk difference 0.002532
# **********
# epoch 2
# tensor(0.4976, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754000
# Party 1 accuracy 0.750400
# Party 1 risk difference 0.001653
# Party 2 risk difference 0.002464
# global training risk dfference: 0.002058
# Finish 2 training epoch, Acc: 0.752200
# Finish party 1 test risk difference 0.003132
# Party 1 accuracy 0.759033
# Finish party 2 test risk difference 0.001932
# Party 2 accuracy 0.753777
# Finish 2 testing epoch, Acc: 0.756405
# Finish 2 risk difference 0.002532
# **********
# epoch 3
# tensor(0.4963, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754000
# Party 1 accuracy 0.750400
# Party 1 risk difference 0.001653
# Party 2 risk difference 0.002464
# global training risk dfference: 0.002058
# Finish 3 training epoch, Acc: 0.752200
# Finish party 1 test risk difference 0.003132
# Party 1 accuracy 0.759033
# Finish party 2 test risk difference 0.002126
# Party 2 accuracy 0.753909
# Finish 3 testing epoch, Acc: 0.756471
# Finish 3 risk difference 0.002629
# **********
# epoch 4
# tensor(0.4951, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754000
# Party 1 accuracy 0.750467
# Party 1 risk difference 0.001653
# Party 2 risk difference 0.002562
# global training risk dfference: 0.002107
# Finish 4 training epoch, Acc: 0.752233
# Finish party 1 test risk difference 0.003132
# Party 1 accuracy 0.759033
# Finish party 2 test risk difference 0.002126
# Party 2 accuracy 0.753909
# Finish 4 testing epoch, Acc: 0.756471
# Finish 4 risk difference 0.002629
# **********
# epoch 5
# tensor(0.4939, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754000
# Party 1 accuracy 0.750533
# Party 1 risk difference 0.001653
# Party 2 risk difference 0.002356
# global training risk dfference: 0.002004
# Finish 5 training epoch, Acc: 0.752267
# Finish party 1 test risk difference 0.003132
# Party 1 accuracy 0.759033
# Finish party 2 test risk difference 0.002126
# Party 2 accuracy 0.753909
# Finish 5 testing epoch, Acc: 0.756471
# Finish 5 risk difference 0.002629
# **********
# epoch 6
# tensor(0.4927, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754000
# Party 1 accuracy 0.750600
# Party 1 risk difference 0.001653
# Party 2 risk difference 0.002455
# global training risk dfference: 0.002054
# Finish 6 training epoch, Acc: 0.752300
# Finish party 1 test risk difference 0.003132
# Party 1 accuracy 0.759033
# Finish party 2 test risk difference 0.002126
# Party 2 accuracy 0.753909
# Finish 6 testing epoch, Acc: 0.756471
# Finish 6 risk difference 0.002629
# **********
# epoch 7
# tensor(0.4916, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754000
# Party 1 accuracy 0.750733
# Party 1 risk difference 0.001653
# Party 2 risk difference 0.002652
# global training risk dfference: 0.002152
# Finish 7 training epoch, Acc: 0.752367
# Finish party 1 test risk difference 0.003132
# Party 1 accuracy 0.759033
# Finish party 2 test risk difference 0.002126
# Party 2 accuracy 0.753909
# Finish 7 testing epoch, Acc: 0.756471
# Finish 7 risk difference 0.002629
# **********
# epoch 8
# tensor(0.4906, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754067
# Party 1 accuracy 0.750733
# Party 1 risk difference 0.001752
# Party 2 risk difference 0.002652
# global training risk dfference: 0.002202
# Finish 8 training epoch, Acc: 0.752400
# Finish party 1 test risk difference 0.003327
# Party 1 accuracy 0.759164
# Finish party 2 test risk difference 0.002321
# Party 2 accuracy 0.753777
# Finish 8 testing epoch, Acc: 0.756471
# Finish 8 risk difference 0.002825
# **********
# epoch 9
# tensor(0.4895, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754067
# Party 1 accuracy 0.750800
# Party 1 risk difference 0.001752
# Party 2 risk difference 0.002750
# global training risk dfference: 0.002251
# Finish 9 training epoch, Acc: 0.752433
# Finish party 1 test risk difference 0.003327
# Party 1 accuracy 0.759164
# Finish party 2 test risk difference 0.002321
# Party 2 accuracy 0.753777
# Finish 9 testing epoch, Acc: 0.756471
# Finish 9 risk difference 0.002825
# **********
# epoch 10
# tensor(0.4885, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754067
# Party 1 accuracy 0.750800
# Party 1 risk difference 0.001752
# Party 2 risk difference 0.002750
# global training risk dfference: 0.002251
# Finish 10 training epoch, Acc: 0.752433
# Finish party 1 test risk difference 0.003327
# Party 1 accuracy 0.759164
# Finish party 2 test risk difference 0.002321
# Party 2 accuracy 0.753777
# Finish 10 testing epoch, Acc: 0.756471
# Finish 10 risk difference 0.002825
# **********
# epoch 1
# tensor(0.4875, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754133
# Party 1 accuracy 0.750933
# Party 1 risk difference 0.001547
# Party 2 risk difference 0.002643
# global training risk dfference: 0.002095
# Finish 1 training epoch, Acc: 0.752533
# Finish party 1 test risk difference 0.003327
# Party 1 accuracy 0.759164
# Finish party 2 test risk difference 0.002516
# Party 2 accuracy 0.753646
# Finish 1 testing epoch, Acc: 0.756405
# Finish 1 risk difference 0.002922
# **********
# epoch 2
# tensor(0.4866, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754067
# Party 1 accuracy 0.751000
# Party 1 risk difference 0.001645
# Party 2 risk difference 0.002741
# global training risk dfference: 0.002193
# Finish 2 training epoch, Acc: 0.752533
# Finish party 1 test risk difference 0.003327
# Party 1 accuracy 0.759164
# Finish party 2 test risk difference 0.002516
# Party 2 accuracy 0.753646
# Finish 2 testing epoch, Acc: 0.756405
# Finish 2 risk difference 0.002922
# **********
# epoch 3
# tensor(0.4856, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754067
# Party 1 accuracy 0.751000
# Party 1 risk difference 0.001645
# Party 2 risk difference 0.002741
# global training risk dfference: 0.002193
# Finish 3 training epoch, Acc: 0.752533
# Finish party 1 test risk difference 0.003327
# Party 1 accuracy 0.759164
# Finish party 2 test risk difference 0.003100
# Party 2 accuracy 0.754040
# Finish 3 testing epoch, Acc: 0.756602
# Finish 3 risk difference 0.003215
# **********
# epoch 4
# tensor(0.4847, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754000
# Party 1 accuracy 0.751067
# Party 1 risk difference 0.001744
# Party 2 risk difference 0.002840
# global training risk dfference: 0.002292
# Finish 4 training epoch, Acc: 0.752533
# Finish party 1 test risk difference 0.002928
# Party 1 accuracy 0.759033
# Finish party 2 test risk difference 0.003294
# Party 2 accuracy 0.754172
# Finish 4 testing epoch, Acc: 0.756602
# Finish 4 risk difference 0.003112
# **********
# epoch 5
# tensor(0.4838, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754200
# Party 1 accuracy 0.751000
# Party 1 risk difference 0.002040
# Party 2 risk difference 0.002938
# global training risk dfference: 0.002489
# Finish 5 training epoch, Acc: 0.752600
# Finish party 1 test risk difference 0.003319
# Party 1 accuracy 0.759296
# Finish party 2 test risk difference 0.003489
# Party 2 accuracy 0.754303
# Finish 5 testing epoch, Acc: 0.756799
# Finish 5 risk difference 0.003404
# **********
# epoch 6
# tensor(0.4829, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754200
# Party 1 accuracy 0.751000
# Party 1 risk difference 0.002040
# Party 2 risk difference 0.002938
# global training risk dfference: 0.002489
# Finish 6 training epoch, Acc: 0.752600
# Finish party 1 test risk difference 0.003515
# Party 1 accuracy 0.759427
# Finish party 2 test risk difference 0.003878
# Party 2 accuracy 0.754566
# Finish 6 testing epoch, Acc: 0.756996
# Finish 6 risk difference 0.003697
# **********
# epoch 7
# tensor(0.4820, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754333
# Party 1 accuracy 0.751067
# Party 1 risk difference 0.002237
# Party 2 risk difference 0.002732
# global training risk dfference: 0.002485
# Finish 7 training epoch, Acc: 0.752700
# Finish party 1 test risk difference 0.003711
# Party 1 accuracy 0.759559
# Finish party 2 test risk difference 0.003474
# Party 2 accuracy 0.754434
# Finish 7 testing epoch, Acc: 0.756996
# Finish 7 risk difference 0.003594
# **********
# epoch 8
# tensor(0.4811, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754400
# Party 1 accuracy 0.751133
# Party 1 risk difference 0.002534
# Party 2 risk difference 0.003028
# global training risk dfference: 0.002781
# Finish 8 training epoch, Acc: 0.752767
# Finish party 1 test risk difference 0.003711
# Party 1 accuracy 0.759559
# Finish party 2 test risk difference 0.003474
# Party 2 accuracy 0.754434
# Finish 8 testing epoch, Acc: 0.756996
# Finish 8 risk difference 0.003594
# **********
# epoch 9
# tensor(0.4803, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754400
# Party 1 accuracy 0.751133
# Party 1 risk difference 0.002534
# Party 2 risk difference 0.002920
# global training risk dfference: 0.002727
# Finish 9 training epoch, Acc: 0.752767
# Finish party 1 test risk difference 0.003711
# Party 1 accuracy 0.759559
# Finish party 2 test risk difference 0.003669
# Party 2 accuracy 0.754566
# Finish 9 testing epoch, Acc: 0.757062
# Finish 9 risk difference 0.003691
# **********
# epoch 10
# tensor(0.4795, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754467
# Party 1 accuracy 0.751000
# Party 1 risk difference 0.002632
# Party 2 risk difference 0.003117
# global training risk dfference: 0.002875
# Finish 10 training epoch, Acc: 0.752733
# Finish party 1 test risk difference 0.003311
# Party 1 accuracy 0.759427
# Finish party 2 test risk difference 0.003669
# Party 2 accuracy 0.754566
# Finish 10 testing epoch, Acc: 0.756996
# Finish 10 risk difference 0.003491
# **********
# epoch 1
# tensor(0.4786, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754467
# Party 1 accuracy 0.751000
# Party 1 risk difference 0.002632
# Party 2 risk difference 0.003117
# global training risk dfference: 0.002875
# Finish 1 training epoch, Acc: 0.752733
# Finish party 1 test risk difference 0.003507
# Party 1 accuracy 0.759559
# Finish party 2 test risk difference 0.003669
# Party 2 accuracy 0.754566
# Finish 1 testing epoch, Acc: 0.757062
# Finish 1 risk difference 0.003588
# **********
# epoch 2
# tensor(0.4778, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754600
# Party 1 accuracy 0.751000
# Party 1 risk difference 0.002723
# Party 2 risk difference 0.003117
# global training risk dfference: 0.002920
# Finish 2 training epoch, Acc: 0.752800
# Finish party 1 test risk difference 0.003702
# Party 1 accuracy 0.759427
# Finish party 2 test risk difference 0.003669
# Party 2 accuracy 0.754566
# Finish 2 testing epoch, Acc: 0.756996
# Finish 2 risk difference 0.003686
# **********
# epoch 3
# tensor(0.4771, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.754733
# Party 1 accuracy 0.751200
# Party 1 risk difference 0.002616
# Party 2 risk difference 0.003108
# global training risk dfference: 0.002862
# Finish 3 training epoch, Acc: 0.752967
# Finish party 1 test risk difference 0.004290
# Party 1 accuracy 0.759821
# Finish party 2 test risk difference 0.004058
# Party 2 accuracy 0.754829
# Finish 3 testing epoch, Acc: 0.757325
# Finish 3 risk difference 0.004174
# **********
# epoch 4
# tensor(0.4763, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.755000
# Party 1 accuracy 0.751600
# Party 1 risk difference 0.003011
# Party 2 risk difference 0.003699
# global training risk dfference: 0.003355
# Finish 4 training epoch, Acc: 0.753300
# Finish party 1 test risk difference 0.005073
# Party 1 accuracy 0.760347
# Finish party 2 test risk difference 0.005032
# Party 2 accuracy 0.755223
# Finish 4 testing epoch, Acc: 0.757785
# Finish 4 risk difference 0.005052
# **********
# epoch 5
# tensor(0.4755, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.755333
# Party 1 accuracy 0.751800
# Party 1 risk difference 0.003397
# Party 2 risk difference 0.003995
# global training risk dfference: 0.003696
# Finish 5 training epoch, Acc: 0.753567
# Finish party 1 test risk difference 0.005660
# Party 1 accuracy 0.760741
# Finish party 2 test risk difference 0.006005
# Party 2 accuracy 0.755617
# Finish 5 testing epoch, Acc: 0.758179
# Finish 5 risk difference 0.005833
# **********
# epoch 6
# tensor(0.4748, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.755667
# Party 1 accuracy 0.751800
# Party 1 risk difference 0.003891
# Party 2 risk difference 0.004192
# global training risk dfference: 0.004041
# Finish 6 training epoch, Acc: 0.753733
# Finish party 1 test risk difference 0.006051
# Party 1 accuracy 0.761004
# Finish party 2 test risk difference 0.006005
# Party 2 accuracy 0.755617
# Finish 6 testing epoch, Acc: 0.758310
# Finish 6 risk difference 0.006028
# **********
# epoch 7
# tensor(0.4740, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.756133
# Party 1 accuracy 0.752000
# Party 1 risk difference 0.004582
# Party 2 risk difference 0.004488
# global training risk dfference: 0.004534
# Finish 7 training epoch, Acc: 0.754067
# Finish party 1 test risk difference 0.006443
# Party 1 accuracy 0.761004
# Finish party 2 test risk difference 0.006379
# Party 2 accuracy 0.756011
# Finish 7 testing epoch, Acc: 0.758507
# Finish 7 risk difference 0.006413
# **********
# epoch 8
# tensor(0.4733, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.756400
# Party 1 accuracy 0.752400
# Party 1 risk difference 0.004870
# Party 2 risk difference 0.005276
# global training risk dfference: 0.005072
# Finish 8 training epoch, Acc: 0.754400
# Finish party 1 test risk difference 0.007421
# Party 1 accuracy 0.761398
# Finish party 2 test risk difference 0.006379
# Party 2 accuracy 0.756011
# Finish 8 testing epoch, Acc: 0.758705
# Finish 8 risk difference 0.006901
# **********
# epoch 9
# tensor(0.4726, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.756667
# Party 1 accuracy 0.752933
# Party 1 risk difference 0.005643
# Party 2 risk difference 0.006459
# global training risk dfference: 0.006050
# Finish 9 training epoch, Acc: 0.754800
# Finish party 1 test risk difference 0.007413
# Party 1 accuracy 0.761529
# Finish party 2 test risk difference 0.007158
# Party 2 accuracy 0.756011
# Finish 9 testing epoch, Acc: 0.758770
# Finish 9 risk difference 0.007285
# **********
# epoch 10
# tensor(0.4718, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.756867
# Party 1 accuracy 0.753133
# Party 1 risk difference 0.005939
# Party 2 risk difference 0.006951
# global training risk dfference: 0.006444
# Finish 10 training epoch, Acc: 0.755000
# Finish party 1 test risk difference 0.007601
# Party 1 accuracy 0.762055
# Finish party 2 test risk difference 0.007143
# Party 2 accuracy 0.756142
# Finish 10 testing epoch, Acc: 0.759099
# Finish 10 risk difference 0.007371
# **********
# epoch 1
# tensor(0.4711, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.757000
# Party 1 accuracy 0.753467
# Party 1 risk difference 0.006531
# Party 2 risk difference 0.007641
# global training risk dfference: 0.007085
# Finish 1 training epoch, Acc: 0.755233
# Finish party 1 test risk difference 0.009362
# Party 1 accuracy 0.762186
# Finish party 2 test risk difference 0.007907
# Party 2 accuracy 0.756537
# Finish 1 testing epoch, Acc: 0.759361
# Finish 1 risk difference 0.008634
# **********
# epoch 2
# tensor(0.4705, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.757400
# Party 1 accuracy 0.754467
# Party 1 risk difference 0.007000
# Party 2 risk difference 0.009513
# global training risk dfference: 0.008256
# Finish 2 training epoch, Acc: 0.755933
# Finish party 1 test risk difference 0.011116
# Party 1 accuracy 0.762975
# Finish party 2 test risk difference 0.008491
# Party 2 accuracy 0.756668
# Finish 2 testing epoch, Acc: 0.759821
# Finish 2 risk difference 0.009800
# **********
# epoch 3
# tensor(0.4698, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.757600
# Party 1 accuracy 0.755333
# Party 1 risk difference 0.007889
# Party 2 risk difference 0.011081
# global training risk dfference: 0.009484
# Finish 3 training epoch, Acc: 0.756467
# Finish party 1 test risk difference 0.011499
# Party 1 accuracy 0.763106
# Finish party 2 test risk difference 0.010048
# Party 2 accuracy 0.757719
# Finish 3 testing epoch, Acc: 0.760413
# Finish 3 risk difference 0.010770
# **********
# epoch 4
# tensor(0.4691, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.758000
# Party 1 accuracy 0.755800
# Party 1 risk difference 0.008966
# Party 2 risk difference 0.012057
# global training risk dfference: 0.010511
# Finish 4 training epoch, Acc: 0.756900
# Finish party 1 test risk difference 0.011483
# Party 1 accuracy 0.763369
# Finish party 2 test risk difference 0.012774
# Party 2 accuracy 0.758770
# Finish 4 testing epoch, Acc: 0.761070
# Finish 4 risk difference 0.012125
# **********
# epoch 5
# tensor(0.4684, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.758467
# Party 1 accuracy 0.756533
# Party 1 risk difference 0.010249
# Party 2 risk difference 0.013733
# global training risk dfference: 0.011990
# Finish 5 training epoch, Acc: 0.757500
# Finish party 1 test risk difference 0.012853
# Party 1 accuracy 0.763763
# Finish party 2 test risk difference 0.013942
# Party 2 accuracy 0.759296
# Finish 5 testing epoch, Acc: 0.761529
# Finish 5 risk difference 0.013394
# **********
# epoch 6
# tensor(0.4678, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.758800
# Party 1 accuracy 0.756933
# Party 1 risk difference 0.010940
# Party 2 risk difference 0.014324
# global training risk dfference: 0.012631
# Finish 6 training epoch, Acc: 0.757867
# Finish party 1 test risk difference 0.013244
# Party 1 accuracy 0.763763
# Finish party 2 test risk difference 0.014526
# Party 2 accuracy 0.759427
# Finish 6 testing epoch, Acc: 0.761595
# Finish 6 risk difference 0.013882
# **********
# epoch 7
# tensor(0.4672, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.759000
# Party 1 accuracy 0.757533
# Party 1 risk difference 0.011417
# Party 2 risk difference 0.015408
# global training risk dfference: 0.013412
# Finish 7 training epoch, Acc: 0.758267
# Finish party 1 test risk difference 0.014223
# Party 1 accuracy 0.764420
# Finish party 2 test risk difference 0.015694
# Party 2 accuracy 0.759953
# Finish 7 testing epoch, Acc: 0.762186
# Finish 7 risk difference 0.014955
# **********
# epoch 8
# tensor(0.4665, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.759200
# Party 1 accuracy 0.757667
# Party 1 risk difference 0.011910
# Party 2 risk difference 0.015695
# global training risk dfference: 0.013802
# Finish 8 training epoch, Acc: 0.758433
# Finish party 1 test risk difference 0.014810
# Party 1 accuracy 0.764551
# Finish party 2 test risk difference 0.016278
# Party 2 accuracy 0.760347
# Finish 8 testing epoch, Acc: 0.762449
# Finish 8 risk difference 0.015541
# **********
# epoch 9
# tensor(0.4659, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.759533
# Party 1 accuracy 0.757933
# Party 1 risk difference 0.012996
# Party 2 risk difference 0.015784
# global training risk dfference: 0.014389
# Finish 9 training epoch, Acc: 0.758733
# Finish party 1 test risk difference 0.015006
# Party 1 accuracy 0.764683
# Finish party 2 test risk difference 0.016847
# Party 2 accuracy 0.760347
# Finish 9 testing epoch, Acc: 0.762515
# Finish 9 risk difference 0.015926
# **********
# epoch 10
# tensor(0.4653, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.759867
# Party 1 accuracy 0.758200
# Party 1 risk difference 0.013687
# Party 2 risk difference 0.016465
# global training risk dfference: 0.015075
# Finish 10 training epoch, Acc: 0.759033
# Finish party 1 test risk difference 0.015201
# Party 1 accuracy 0.764814
# Finish party 2 test risk difference 0.016847
# Party 2 accuracy 0.760347
# Finish 10 testing epoch, Acc: 0.762580
# Finish 10 risk difference 0.016023
# **********
# epoch 1
# tensor(0.4647, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.760067
# Party 1 accuracy 0.758400
# Party 1 risk difference 0.014575
# Party 2 risk difference 0.017047
# global training risk dfference: 0.015811
# Finish 1 training epoch, Acc: 0.759233
# Finish party 1 test risk difference 0.016180
# Party 1 accuracy 0.765208
# Finish party 2 test risk difference 0.017236
# Party 2 accuracy 0.760084
# Finish 1 testing epoch, Acc: 0.762646
# Finish 1 risk difference 0.016706
# **********
# epoch 2
# tensor(0.4641, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.760533
# Party 1 accuracy 0.758933
# Party 1 risk difference 0.015266
# Party 2 risk difference 0.017531
# global training risk dfference: 0.016398
# Finish 2 training epoch, Acc: 0.759733
# Finish party 1 test risk difference 0.017550
# Party 1 accuracy 0.765602
# Finish party 2 test risk difference 0.018793
# Party 2 accuracy 0.760610
# Finish 2 testing epoch, Acc: 0.763106
# Finish 2 risk difference 0.018170
# **********
# epoch 3
# tensor(0.4635, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.760800
# Party 1 accuracy 0.759133
# Party 1 risk difference 0.016647
# Party 2 risk difference 0.018507
# global training risk dfference: 0.017577
# Finish 3 training epoch, Acc: 0.759967
# Finish party 1 test risk difference 0.019116
# Party 1 accuracy 0.765602
# Finish party 2 test risk difference 0.020351
# Party 2 accuracy 0.761398
# Finish 3 testing epoch, Acc: 0.763500
# Finish 3 risk difference 0.019732
# **********
# epoch 4
# tensor(0.4629, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.760800
# Party 1 accuracy 0.759200
# Party 1 risk difference 0.017634
# Party 2 risk difference 0.019394
# global training risk dfference: 0.018514
# Finish 4 training epoch, Acc: 0.760000
# Finish party 1 test risk difference 0.020095
# Party 1 accuracy 0.765471
# Finish party 2 test risk difference 0.021519
# Party 2 accuracy 0.762186
# Finish 4 testing epoch, Acc: 0.763829
# Finish 4 risk difference 0.020805
# **********
# epoch 5
# tensor(0.4623, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.760733
# Party 1 accuracy 0.759667
# Party 1 risk difference 0.018218
# Party 2 risk difference 0.020478
# global training risk dfference: 0.019348
# Finish 5 training epoch, Acc: 0.760200
# Finish party 1 test risk difference 0.020878
# Party 1 accuracy 0.765471
# Finish party 2 test risk difference 0.022297
# Party 2 accuracy 0.762449
# Finish 5 testing epoch, Acc: 0.763960
# Finish 5 risk difference 0.021586
# **********
# epoch 6
# tensor(0.4618, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.761133
# Party 1 accuracy 0.759667
# Party 1 risk difference 0.019797
# Party 2 risk difference 0.021266
# global training risk dfference: 0.020531
# Finish 6 training epoch, Acc: 0.760400
# Finish party 1 test risk difference 0.022052
# Party 1 accuracy 0.765734
# Finish party 2 test risk difference 0.022867
# Party 2 accuracy 0.762186
# Finish 6 testing epoch, Acc: 0.763960
# Finish 6 risk difference 0.022459
# **********
# epoch 7
# tensor(0.4612, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.761133
# Party 1 accuracy 0.759667
# Party 1 risk difference 0.020784
# Party 2 risk difference 0.022341
# global training risk dfference: 0.021563
# Finish 7 training epoch, Acc: 0.760400
# Finish party 1 test risk difference 0.022044
# Party 1 accuracy 0.766128
# Finish party 2 test risk difference 0.023840
# Party 2 accuracy 0.762580
# Finish 7 testing epoch, Acc: 0.764354
# Finish 7 risk difference 0.022941
# **********
# epoch 8
# tensor(0.4607, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.761067
# Party 1 accuracy 0.760000
# Party 1 risk difference 0.021475
# Party 2 risk difference 0.023031
# global training risk dfference: 0.022253
# Finish 8 training epoch, Acc: 0.760533
# Finish party 1 test risk difference 0.022036
# Party 1 accuracy 0.766522
# Finish party 2 test risk difference 0.024229
# Party 2 accuracy 0.762843
# Finish 8 testing epoch, Acc: 0.764683
# Finish 8 risk difference 0.023131
# **********
# epoch 9
# tensor(0.4601, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.761267
# Party 1 accuracy 0.760133
# Party 1 risk difference 0.021862
# Party 2 risk difference 0.023228
# global training risk dfference: 0.022544
# Finish 9 training epoch, Acc: 0.760700
# Finish party 1 test risk difference 0.021432
# Party 1 accuracy 0.766391
# Finish party 2 test risk difference 0.024020
# Party 2 accuracy 0.763106
# Finish 9 testing epoch, Acc: 0.764748
# Finish 9 risk difference 0.022723
# **********
# epoch 10
# tensor(0.4596, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.761333
# Party 1 accuracy 0.760333
# Party 1 risk difference 0.022158
# Party 2 risk difference 0.023416
# global training risk dfference: 0.022787
# Finish 10 training epoch, Acc: 0.760833
# Finish party 1 test risk difference 0.021824
# Party 1 accuracy 0.766391
# Finish party 2 test risk difference 0.024409
# Party 2 accuracy 0.763106
# Finish 10 testing epoch, Acc: 0.764748
# Finish 10 risk difference 0.023113
# **********
# epoch 1
# tensor(0.4591, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.761267
# Party 1 accuracy 0.760333
# Party 1 risk difference 0.022454
# Party 2 risk difference 0.023613
# global training risk dfference: 0.023033
# Finish 1 training epoch, Acc: 0.760800
# Finish party 1 test risk difference 0.022215
# Party 1 accuracy 0.766391
# Finish party 2 test risk difference 0.025382
# Party 2 accuracy 0.762975
# Finish 1 testing epoch, Acc: 0.764683
# Finish 1 risk difference 0.023796
# **********
# epoch 2
# tensor(0.4585, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.761200
# Party 1 accuracy 0.760267
# Party 1 risk difference 0.022552
# Party 2 risk difference 0.023604
# global training risk dfference: 0.023078
# Finish 2 training epoch, Acc: 0.760733
# Finish party 1 test risk difference 0.022802
# Party 1 accuracy 0.766522
# Finish party 2 test risk difference 0.025173
# Party 2 accuracy 0.762975
# Finish 2 testing epoch, Acc: 0.764748
# Finish 2 risk difference 0.023986
# **********
# epoch 3
# tensor(0.4580, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.761400
# Party 1 accuracy 0.760333
# Party 1 risk difference 0.022544
# Party 2 risk difference 0.023900
# global training risk dfference: 0.023222
# Finish 3 training epoch, Acc: 0.760867
# Finish party 1 test risk difference 0.022998
# Party 1 accuracy 0.766654
# Finish party 2 test risk difference 0.025158
# Party 2 accuracy 0.762843
# Finish 3 testing epoch, Acc: 0.764748
# Finish 3 risk difference 0.024078
# **********
# epoch 4
# tensor(0.4575, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.761533
# Party 1 accuracy 0.760400
# Party 1 risk difference 0.022438
# Party 2 risk difference 0.023891
# global training risk dfference: 0.023164
# Finish 4 training epoch, Acc: 0.760967
# Finish party 1 test risk difference 0.022794
# Party 1 accuracy 0.766916
# Finish party 2 test risk difference 0.025547
# Party 2 accuracy 0.762580
# Finish 4 testing epoch, Acc: 0.764748
# Finish 4 risk difference 0.024170
# **********
# epoch 5
# tensor(0.4570, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.761600
# Party 1 accuracy 0.760533
# Party 1 risk difference 0.022536
# Party 2 risk difference 0.023980
# global training risk dfference: 0.023258
# Finish 5 training epoch, Acc: 0.761067
# Finish party 1 test risk difference 0.022394
# Party 1 accuracy 0.766785
# Finish party 2 test risk difference 0.026131
# Party 2 accuracy 0.762712
# Finish 5 testing epoch, Acc: 0.764748
# Finish 5 risk difference 0.024261
# **********
# epoch 6
# tensor(0.4565, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.761733
# Party 1 accuracy 0.760600
# Party 1 risk difference 0.022734
# Party 2 risk difference 0.024061
# global training risk dfference: 0.023398
# Finish 6 training epoch, Acc: 0.761167
# Finish party 1 test risk difference 0.022590
# Party 1 accuracy 0.766916
# Finish party 2 test risk difference 0.026521
# Party 2 accuracy 0.762975
# Finish 6 testing epoch, Acc: 0.764945
# Finish 6 risk difference 0.024554
# **********
# epoch 7
# tensor(0.4560, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.761667
# Party 1 accuracy 0.760800
# Party 1 risk difference 0.022528
# Party 2 risk difference 0.023425
# global training risk dfference: 0.022978
# Finish 7 training epoch, Acc: 0.761233
# Finish party 1 test risk difference 0.021791
# Party 1 accuracy 0.766916
# Finish party 2 test risk difference 0.026715
# Party 2 accuracy 0.763106
# Finish 7 testing epoch, Acc: 0.765011
# Finish 7 risk difference 0.024250
# **********
# epoch 8
# tensor(0.4556, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.761667
# Party 1 accuracy 0.761267
# Party 1 risk difference 0.022726
# Party 2 risk difference 0.023810
# global training risk dfference: 0.023269
# Finish 8 training epoch, Acc: 0.761467
# Finish party 1 test risk difference 0.022182
# Party 1 accuracy 0.767179
# Finish party 2 test risk difference 0.026910
# Party 2 accuracy 0.763237
# Finish 8 testing epoch, Acc: 0.765208
# Finish 8 risk difference 0.024543
# **********
# epoch 9
# tensor(0.4551, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.761867
# Party 1 accuracy 0.761333
# Party 1 risk difference 0.022504
# Party 2 risk difference 0.023604
# global training risk dfference: 0.023055
# Finish 9 training epoch, Acc: 0.761600
# Finish party 1 test risk difference 0.021970
# Party 1 accuracy 0.767310
# Finish party 2 test risk difference 0.026910
# Party 2 accuracy 0.763237
# Finish 9 testing epoch, Acc: 0.765274
# Finish 9 risk difference 0.024434
# **********
# epoch 10
# tensor(0.4546, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.762000
# Party 1 accuracy 0.761333
# Party 1 risk difference 0.021986
# Party 2 risk difference 0.023173
# global training risk dfference: 0.022581
# Finish 10 training epoch, Acc: 0.761667
# Finish party 1 test risk difference 0.021962
# Party 1 accuracy 0.767705
# Finish party 2 test risk difference 0.026296
# Party 2 accuracy 0.763632
# Finish 10 testing epoch, Acc: 0.765668
# Finish 10 risk difference 0.024123
# **********
# epoch 1
# tensor(0.4541, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.762133
# Party 1 accuracy 0.761400
# Party 1 risk difference 0.022669
# Party 2 risk difference 0.023559
# global training risk dfference: 0.023115
# Finish 1 training epoch, Acc: 0.761767
# Finish party 1 test risk difference 0.022745
# Party 1 accuracy 0.767705
# Finish party 2 test risk difference 0.025877
# Party 2 accuracy 0.763894
# Finish 1 testing epoch, Acc: 0.765800
# Finish 1 risk difference 0.024307
# **********
# epoch 2
# tensor(0.4537, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.762400
# Party 1 accuracy 0.761533
# Party 1 risk difference 0.023154
# Party 2 risk difference 0.023953
# global training risk dfference: 0.023555
# Finish 2 training epoch, Acc: 0.761967
# Finish party 1 test risk difference 0.023136
# Party 1 accuracy 0.767967
# Finish party 2 test risk difference 0.026057
# Party 2 accuracy 0.764157
# Finish 2 testing epoch, Acc: 0.766062
# Finish 2 risk difference 0.024594
# **********
# epoch 3
# tensor(0.4532, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.763000
# Party 1 accuracy 0.761933
# Party 1 risk difference 0.023434
# Party 2 risk difference 0.023827
# global training risk dfference: 0.023632
# Finish 3 training epoch, Acc: 0.762467
# Finish party 1 test risk difference 0.023324
# Party 1 accuracy 0.768493
# Finish party 2 test risk difference 0.026222
# Party 2 accuracy 0.764551
# Finish 3 testing epoch, Acc: 0.766522
# Finish 3 risk difference 0.024772
# **********
# epoch 4
# tensor(0.4528, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.763333
# Party 1 accuracy 0.762267
# Party 1 risk difference 0.024322
# Party 2 risk difference 0.024212
# global training risk dfference: 0.024268
# Finish 4 training epoch, Acc: 0.762800
# Finish party 1 test risk difference 0.024107
# Party 1 accuracy 0.769019
# Finish party 2 test risk difference 0.027180
# Party 2 accuracy 0.765077
# Finish 4 testing epoch, Acc: 0.767048
# Finish 4 risk difference 0.025645
# **********
# epoch 5
# tensor(0.4523, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.763733
# Party 1 accuracy 0.762467
# Party 1 risk difference 0.025005
# Party 2 risk difference 0.024794
# global training risk dfference: 0.024901
# Finish 5 training epoch, Acc: 0.763100
# Finish party 1 test risk difference 0.024294
# Party 1 accuracy 0.769281
# Finish party 2 test risk difference 0.026971
# Party 2 accuracy 0.765340
# Finish 5 testing epoch, Acc: 0.767310
# Finish 5 risk difference 0.025633
# **********
# epoch 6
# tensor(0.4519, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.763933
# Party 1 accuracy 0.763000
# Party 1 risk difference 0.025194
# Party 2 risk difference 0.025475
# global training risk dfference: 0.025336
# Finish 6 training epoch, Acc: 0.763467
# Finish party 1 test risk difference 0.024677
# Party 1 accuracy 0.769675
# Finish party 2 test risk difference 0.026731
# Party 2 accuracy 0.766391
# Finish 6 testing epoch, Acc: 0.768033
# Finish 6 risk difference 0.025708
# **********
# epoch 7
# tensor(0.4515, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.764467
# Party 1 accuracy 0.763533
# Party 1 risk difference 0.024965
# Party 2 risk difference 0.026246
# global training risk dfference: 0.025606
# Finish 7 training epoch, Acc: 0.764000
# Finish party 1 test risk difference 0.025069
# Party 1 accuracy 0.769938
# Finish party 2 test risk difference 0.028678
# Party 2 accuracy 0.766916
# Finish 7 testing epoch, Acc: 0.768427
# Finish 7 risk difference 0.026879
# **********
# epoch 8
# tensor(0.4511, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.764867
# Party 1 accuracy 0.763933
# Party 1 risk difference 0.025647
# Party 2 risk difference 0.026317
# global training risk dfference: 0.025984
# Finish 8 training epoch, Acc: 0.764400
# Finish party 1 test risk difference 0.025852
# Party 1 accuracy 0.769938
# Finish party 2 test risk difference 0.028633
# Party 2 accuracy 0.766785
# Finish 8 testing epoch, Acc: 0.768362
# Finish 8 risk difference 0.027252
# **********
# epoch 9
# tensor(0.4506, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.765333
# Party 1 accuracy 0.764600
# Party 1 risk difference 0.026429
# Party 2 risk difference 0.027195
# global training risk dfference: 0.026813
# Finish 9 training epoch, Acc: 0.764967
# Finish party 1 test risk difference 0.026635
# Party 1 accuracy 0.770464
# Finish party 2 test risk difference 0.028409
# Party 2 accuracy 0.767442
# Finish 9 testing epoch, Acc: 0.768953
# Finish 9 risk difference 0.027533
# **********
# epoch 10
# tensor(0.4502, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.765467
# Party 1 accuracy 0.764867
# Party 1 risk difference 0.027309
# Party 2 risk difference 0.027679
# global training risk dfference: 0.027495
# Finish 10 training epoch, Acc: 0.765167
# Finish party 1 test risk difference 0.027018
# Party 1 accuracy 0.770858
# Finish party 2 test risk difference 0.028798
# Party 2 accuracy 0.767705
# Finish 10 testing epoch, Acc: 0.769281
# Finish 10 risk difference 0.027918
# **********
# epoch 1
# tensor(0.4498, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.765600
# Party 1 accuracy 0.765400
# Party 1 risk difference 0.026791
# Party 2 risk difference 0.027858
# global training risk dfference: 0.027326
# Finish 1 training epoch, Acc: 0.765500
# Finish party 1 test risk difference 0.027393
# Party 1 accuracy 0.771384
# Finish party 2 test risk difference 0.027975
# Party 2 accuracy 0.767836
# Finish 1 testing epoch, Acc: 0.769610
# Finish 1 risk difference 0.027694
# **********
# epoch 2
# tensor(0.4494, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.766000
# Party 1 accuracy 0.765667
# Party 1 risk difference 0.026866
# Party 2 risk difference 0.028323
# global training risk dfference: 0.027596
# Finish 2 training epoch, Acc: 0.765833
# Finish party 1 test risk difference 0.028176
# Party 1 accuracy 0.771646
# Finish party 2 test risk difference 0.026748
# Party 2 accuracy 0.768362
# Finish 2 testing epoch, Acc: 0.770004
# Finish 2 risk difference 0.027476
# **********
# epoch 3
# tensor(0.4490, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.766467
# Party 1 accuracy 0.766133
# Party 1 risk difference 0.027450
# Party 2 risk difference 0.027776
# global training risk dfference: 0.027615
# Finish 3 training epoch, Acc: 0.766300
# Finish party 1 test risk difference 0.028168
# Party 1 accuracy 0.771778
# Finish party 2 test risk difference 0.026718
# Party 2 accuracy 0.768887
# Finish 3 testing epoch, Acc: 0.770332
# Finish 3 risk difference 0.027458
# **********
# epoch 4
# tensor(0.4486, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.767000
# Party 1 accuracy 0.767000
# Party 1 risk difference 0.027006
# Party 2 risk difference 0.028735
# global training risk dfference: 0.027873
# Finish 4 training epoch, Acc: 0.767000
# Finish party 1 test risk difference 0.026765
# Party 1 accuracy 0.771646
# Finish party 2 test risk difference 0.026703
# Party 2 accuracy 0.769019
# Finish 4 testing epoch, Acc: 0.770332
# Finish 4 risk difference 0.026746
# **********
# epoch 5
# tensor(0.4482, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.767533
# Party 1 accuracy 0.768200
# Party 1 risk difference 0.026867
# Party 2 risk difference 0.028358
# global training risk dfference: 0.027616
# Finish 5 training epoch, Acc: 0.767867
# Finish party 1 test risk difference 0.026536
# Party 1 accuracy 0.772566
# Finish party 2 test risk difference 0.027048
# Party 2 accuracy 0.770201
# Finish 5 testing epoch, Acc: 0.771384
# Finish 5 risk difference 0.026803
# **********
# epoch 6
# tensor(0.4478, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.768400
# Party 1 accuracy 0.768467
# Party 1 risk difference 0.026827
# Party 2 risk difference 0.027587
# global training risk dfference: 0.027211
# Finish 6 training epoch, Acc: 0.768433
# Finish party 1 test risk difference 0.028102
# Party 1 accuracy 0.772829
# Finish party 2 test risk difference 0.028186
# Party 2 accuracy 0.771252
# Finish 6 testing epoch, Acc: 0.772040
# Finish 6 risk difference 0.028158
# **********
# epoch 7
# tensor(0.4475, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.769333
# Party 1 accuracy 0.768933
# Party 1 risk difference 0.026170
# Party 2 risk difference 0.027040
# global training risk dfference: 0.026608
# Finish 7 training epoch, Acc: 0.769133
# Finish party 1 test risk difference 0.028885
# Party 1 accuracy 0.773092
# Finish party 2 test risk difference 0.028531
# Party 2 accuracy 0.772172
# Finish 7 testing epoch, Acc: 0.772632
# Finish 7 risk difference 0.028727
# **********
# epoch 8
# tensor(0.4471, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.770333
# Party 1 accuracy 0.769600
# Party 1 risk difference 0.026220
# Party 2 risk difference 0.028294
# global training risk dfference: 0.027260
# Finish 8 training epoch, Acc: 0.769967
# Finish party 1 test risk difference 0.029064
# Party 1 accuracy 0.773749
# Finish party 2 test risk difference 0.028696
# Party 2 accuracy 0.772303
# Finish 8 testing epoch, Acc: 0.773026
# Finish 8 risk difference 0.028899
# **********
# epoch 9
# tensor(0.4467, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.771133
# Party 1 accuracy 0.770667
# Party 1 risk difference 0.025974
# Party 2 risk difference 0.029118
# global training risk dfference: 0.027550
# Finish 9 training epoch, Acc: 0.770900
# Finish party 1 test risk difference 0.031013
# Party 1 accuracy 0.775194
# Finish party 2 test risk difference 0.029624
# Party 2 accuracy 0.772829
# Finish 9 testing epoch, Acc: 0.774011
# Finish 9 risk difference 0.030340
# **********
# epoch 10
# tensor(0.4463, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.771867
# Party 1 accuracy 0.771533
# Party 1 risk difference 0.025202
# Party 2 risk difference 0.029682
# global training risk dfference: 0.027445
# Finish 10 training epoch, Acc: 0.771700
# Finish party 1 test risk difference 0.031772
# Party 1 accuracy 0.776114
# Finish party 2 test risk difference 0.030957
# Party 2 accuracy 0.773486
# Finish 10 testing epoch, Acc: 0.774800
# Finish 10 risk difference 0.031384
# **********
# epoch 1
# tensor(0.4460, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.772800
# Party 1 accuracy 0.772533
# Party 1 risk difference 0.025762
# Party 2 risk difference 0.030820
# global training risk dfference: 0.028294
# Finish 1 training epoch, Acc: 0.772667
# Finish party 1 test risk difference 0.033338
# Party 1 accuracy 0.776902
# Finish party 2 test risk difference 0.031078
# Party 2 accuracy 0.774537
# Finish 1 testing epoch, Acc: 0.775719
# Finish 1 risk difference 0.032234
# **********
# epoch 2
# tensor(0.4456, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.773467
# Party 1 accuracy 0.773267
# Party 1 risk difference 0.026231
# Party 2 risk difference 0.032584
# global training risk dfference: 0.029411
# Finish 2 training epoch, Acc: 0.773367
# Finish party 1 test risk difference 0.033704
# Party 1 accuracy 0.777296
# Finish party 2 test risk difference 0.032231
# ...
# Party 1 accuracy 0.786267
# Party 1 accuracy 0.785600
# Party 1 risk difference 0.069097
# Party 2 risk difference 0.073743
# global training risk dfference: 0.071422
# Finish 7 training epoch, Acc: 0.785933
# Finish party 1 test risk difference 0.071935
# Party 1 accuracy 0.785311
# Finish party 2 test risk difference 0.076304
# Party 2 accuracy 0.784785
# Finish 7 testing epoch, Acc: 0.785048
# Finish 7 risk difference 0.074142
# **********
# epoch 8
# tensor(0.4286, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.786867
# Party 1 accuracy 0.786200
# Party 1 risk difference 0.069270
# Party 2 risk difference 0.074021
# global training risk dfference: 0.071647
# Finish 8 training epoch, Acc: 0.786533
# Finish party 1 test risk difference 0.071527
# Party 1 accuracy 0.785574
# Finish party 2 test risk difference 0.077082
# Party 2 accuracy 0.785311
# Finish 8 testing epoch, Acc: 0.785442
# Finish 8 risk difference 0.074326
# **********
# epoch 9
# tensor(0.4284, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.787600
# Party 1 accuracy 0.786600
# Party 1 risk difference 0.068835
# Party 2 risk difference 0.073178
# global training risk dfference: 0.071009
# Finish 9 training epoch, Acc: 0.787100
# Finish party 1 test risk difference 0.072114
# Party 1 accuracy 0.785968
# Finish party 2 test risk difference 0.076873
# Party 2 accuracy 0.785311
# Finish 9 testing epoch, Acc: 0.785639
# Finish 9 risk difference 0.074515
# **********
# epoch 10
# tensor(0.4282, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.788067
# Party 1 accuracy 0.786733
# Party 1 risk difference 0.068811
# Party 2 risk difference 0.072945
# global training risk dfference: 0.070880
# Finish 10 training epoch, Acc: 0.787400
# Finish party 1 test risk difference 0.072106
# Party 1 accuracy 0.786362
# Finish party 2 test risk difference 0.077038
# Party 2 accuracy 0.785705
# Finish 10 testing epoch, Acc: 0.786033
# Finish 10 risk difference 0.074596
# **********
# epoch 1
# tensor(0.4280, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.788067
# Party 1 accuracy 0.786800
# Party 1 risk difference 0.068901
# Party 2 risk difference 0.073133
# global training risk dfference: 0.071019
# Finish 1 training epoch, Acc: 0.787433
# Finish party 1 test risk difference 0.072693
# Party 1 accuracy 0.786493
# Finish party 2 test risk difference 0.077801
# Party 2 accuracy 0.786362
# Finish 1 testing epoch, Acc: 0.786428
# Finish 1 risk difference 0.075273
# **********
# epoch 2
# tensor(0.4279, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.788267
# Party 1 accuracy 0.787067
# Party 1 risk difference 0.068680
# Party 2 risk difference 0.073115
# global training risk dfference: 0.070899
# Finish 2 training epoch, Acc: 0.787667
# Finish party 1 test risk difference 0.072490
# Party 1 accuracy 0.786493
# Finish party 2 test risk difference 0.077787
# Party 2 accuracy 0.786756
# Finish 2 testing epoch, Acc: 0.786625
# Finish 2 risk difference 0.075164
# **********
# epoch 3
# tensor(0.4277, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.788400
# Party 1 accuracy 0.787200
# Party 1 risk difference 0.068573
# Party 2 risk difference 0.073097
# global training risk dfference: 0.070837
# Finish 3 training epoch, Acc: 0.787800
# Finish party 1 test risk difference 0.072873
# Party 1 accuracy 0.786887
# Finish party 2 test risk difference 0.077966
# Party 2 accuracy 0.787019
# Finish 3 testing epoch, Acc: 0.786953
# Finish 3 risk difference 0.075445
# **********
# epoch 4
# tensor(0.4275, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.788533
# Party 1 accuracy 0.787733
# Party 1 risk difference 0.068557
# Party 2 risk difference 0.072972
# global training risk dfference: 0.070767
# Finish 4 training epoch, Acc: 0.788133
# Finish party 1 test risk difference 0.073264
# Party 1 accuracy 0.786887
# Finish party 2 test risk difference 0.077757
# Party 2 accuracy 0.787282
# Finish 4 testing epoch, Acc: 0.787084
# Finish 4 risk difference 0.075537
# **********
# epoch 5
# tensor(0.4273, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.788867
# Party 1 accuracy 0.788067
# Party 1 risk difference 0.068228
# Party 2 risk difference 0.073160
# global training risk dfference: 0.070696
# Finish 5 training epoch, Acc: 0.788467
# Finish party 1 test risk difference 0.072065
# Party 1 accuracy 0.787019
# Finish party 2 test risk difference 0.077952
# Party 2 accuracy 0.787413
# Finish 5 testing epoch, Acc: 0.787216
# Finish 5 risk difference 0.075032
# **********
# epoch 6
# tensor(0.4271, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.789067
# Party 1 accuracy 0.788200
# Party 1 risk difference 0.068113
# Party 2 risk difference 0.073249
# global training risk dfference: 0.070683
# Finish 6 training epoch, Acc: 0.788633
# Finish party 1 test risk difference 0.071666
# Party 1 accuracy 0.786887
# Finish party 2 test risk difference 0.077128
# Party 2 accuracy 0.787807
# Finish 6 testing epoch, Acc: 0.787347
# Finish 6 risk difference 0.074423
# **********
# epoch 7
# tensor(0.4270, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.789467
# Party 1 accuracy 0.788467
# Party 1 risk difference 0.068097
# Party 2 risk difference 0.072926
# global training risk dfference: 0.070514
# Finish 7 training epoch, Acc: 0.788967
# Finish party 1 test risk difference 0.071657
# Party 1 accuracy 0.787282
# Finish party 2 test risk difference 0.078296
# Party 2 accuracy 0.788595
# Finish 7 testing epoch, Acc: 0.787939
# Finish 7 risk difference 0.075003
# **********
# epoch 8
# tensor(0.4268, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.790067
# Party 1 accuracy 0.789200
# Party 1 risk difference 0.068879
# Party 2 risk difference 0.073795
# global training risk dfference: 0.071339
# Finish 8 training epoch, Acc: 0.789633
# Finish party 1 test risk difference 0.072636
# Party 1 accuracy 0.787676
# Finish party 2 test risk difference 0.079075
# Party 2 accuracy 0.789121
# Finish 8 testing epoch, Acc: 0.788398
# Finish 8 risk difference 0.075881
# **********
# epoch 9
# tensor(0.4266, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.790467
# Party 1 accuracy 0.789400
# Party 1 risk difference 0.069044
# Party 2 risk difference 0.073983
# global training risk dfference: 0.071515
# Finish 9 training epoch, Acc: 0.789933
# Finish party 1 test risk difference 0.073215
# Party 1 accuracy 0.788201
# Finish party 2 test risk difference 0.080243
# Party 2 accuracy 0.789647
# Finish 9 testing epoch, Acc: 0.788924
# Finish 9 risk difference 0.076754
# **********
# epoch 10
# tensor(0.4265, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.790800
# Party 1 accuracy 0.790000
# Party 1 risk difference 0.069537
# Party 2 risk difference 0.074350
# global training risk dfference: 0.071946
# Finish 10 training epoch, Acc: 0.790400
# Finish party 1 test risk difference 0.072212
# Party 1 accuracy 0.788464
# Finish party 2 test risk difference 0.081022
# Party 2 accuracy 0.790172
# Finish 10 testing epoch, Acc: 0.789318
# Finish 10 risk difference 0.076639
# **********
# epoch 1
# tensor(0.4263, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.791267
# Party 1 accuracy 0.790400
# Party 1 risk difference 0.070319
# Party 2 risk difference 0.075533
# global training risk dfference: 0.072928
# Finish 1 training epoch, Acc: 0.790833
# Finish party 1 test risk difference 0.072195
# Party 1 accuracy 0.788990
# Finish party 2 test risk difference 0.081201
# Party 2 accuracy 0.790435
# Finish 1 testing epoch, Acc: 0.789712
# Finish 1 risk difference 0.076719
# **********
# epoch 2
# tensor(0.4261, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.791533
# Party 1 accuracy 0.790667
# Party 1 risk difference 0.070804
# Party 2 risk difference 0.075407
# global training risk dfference: 0.073108
# Finish 2 training epoch, Acc: 0.791100
# Finish party 1 test risk difference 0.072375
# Party 1 accuracy 0.789647
# Finish party 2 test risk difference 0.083118
# Party 2 accuracy 0.792012
# Finish 2 testing epoch, Acc: 0.790829
# Finish 2 risk difference 0.077770
# **********
# epoch 3
# tensor(0.4260, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.792067
# Party 1 accuracy 0.790867
# Party 1 risk difference 0.071289
# Party 2 risk difference 0.075595
# global training risk dfference: 0.073445
# Finish 3 training epoch, Acc: 0.791467
# Finish party 1 test risk difference 0.072366
# Party 1 accuracy 0.789778
# Finish party 2 test risk difference 0.082684
# Party 2 accuracy 0.792669
# Finish 3 testing epoch, Acc: 0.791223
# Finish 3 risk difference 0.077551
# **********
# epoch 4
# tensor(0.4258, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.792933
# Party 1 accuracy 0.791667
# Party 1 risk difference 0.071356
# Party 2 risk difference 0.076670
# global training risk dfference: 0.074015
# Finish 4 training epoch, Acc: 0.792300
# Finish party 1 test risk difference 0.074120
# Party 1 accuracy 0.791355
# Finish party 2 test risk difference 0.084047
# Party 2 accuracy 0.793588
# Finish 4 testing epoch, Acc: 0.792471
# Finish 4 risk difference 0.079107
# **********
# epoch 5
# tensor(0.4256, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.793267
# Party 1 accuracy 0.792533
# Party 1 risk difference 0.071545
# Party 2 risk difference 0.077127
# global training risk dfference: 0.074339
# Finish 5 training epoch, Acc: 0.792900
# Finish party 1 test risk difference 0.074699
# Party 1 accuracy 0.792143
# Finish party 2 test risk difference 0.085215
# Party 2 accuracy 0.793851
# Finish 5 testing epoch, Acc: 0.792997
# Finish 5 risk difference 0.079980
# **********
# epoch 6
# tensor(0.4255, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.794000
# Party 1 accuracy 0.792867
# Party 1 risk difference 0.073116
# Party 2 risk difference 0.077996
# global training risk dfference: 0.075559
# Finish 6 training epoch, Acc: 0.793433
# Finish party 1 test risk difference 0.074878
# Party 1 accuracy 0.792537
# Finish party 2 test risk difference 0.086368
# Party 2 accuracy 0.794508
# Finish 6 testing epoch, Acc: 0.793523
# Finish 6 risk difference 0.080646
# **********
# epoch 7
# tensor(0.4253, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.795067
# Party 1 accuracy 0.793267
# Party 1 risk difference 0.074481
# Party 2 risk difference 0.077028
# global training risk dfference: 0.075758
# Finish 7 training epoch, Acc: 0.794167
# Finish party 1 test risk difference 0.074862
# Party 1 accuracy 0.792800
# Finish party 2 test risk difference 0.086952
# Party 2 accuracy 0.794639
# Finish 7 testing epoch, Acc: 0.793720
# Finish 7 risk difference 0.080927
# **********
# epoch 8
# tensor(0.4252, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.796067
# Party 1 accuracy 0.793867
# Party 1 risk difference 0.075444
# Party 2 risk difference 0.077700
# global training risk dfference: 0.076575
# Finish 8 training epoch, Acc: 0.794967
# Finish party 1 test risk difference 0.075628
# Party 1 accuracy 0.794114
# Finish party 2 test risk difference 0.087521
# Party 2 accuracy 0.794902
# Finish 8 testing epoch, Acc: 0.794508
# Finish 8 risk difference 0.081593
# **********
# epoch 9
# tensor(0.4250, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.796667
# Party 1 accuracy 0.794533
# Party 1 risk difference 0.076817
# Party 2 risk difference 0.077645
# global training risk dfference: 0.077235
# Finish 9 training epoch, Acc: 0.795600
# Finish party 1 test risk difference 0.075816
# Party 1 accuracy 0.794639
# Finish party 2 test risk difference 0.087866
# Party 2 accuracy 0.795296
# Finish 9 testing epoch, Acc: 0.794968
# Finish 9 risk difference 0.081863
# **********
# epoch 10
# tensor(0.4248, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.797333
# Party 1 accuracy 0.795467
# Party 1 risk difference 0.078487
# Party 2 risk difference 0.079222
# global training risk dfference: 0.078858
# Finish 10 training epoch, Acc: 0.796400
# Finish party 1 test risk difference 0.076786
# Party 1 accuracy 0.795690
# Finish party 2 test risk difference 0.089034
# Party 2 accuracy 0.795559
# Finish 10 testing epoch, Acc: 0.795625
# Finish 10 risk difference 0.082931
# **********
# epoch 1
# tensor(0.4247, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.798000
# Party 1 accuracy 0.795800
# Party 1 risk difference 0.079564
# Party 2 risk difference 0.079589
# global training risk dfference: 0.079581
# Finish 1 training epoch, Acc: 0.796900
# Finish party 1 test risk difference 0.078352
# Party 1 accuracy 0.796216
# Finish party 2 test risk difference 0.089408
# Party 2 accuracy 0.796216
# Finish 1 testing epoch, Acc: 0.796216
# Finish 1 risk difference 0.083901
# **********
# epoch 2
# tensor(0.4245, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.798600
# Party 1 accuracy 0.796267
# Party 1 risk difference 0.080650
# Party 2 risk difference 0.080369
# global training risk dfference: 0.080513
# Finish 2 training epoch, Acc: 0.797433
# Finish party 1 test risk difference 0.078531
# Party 1 accuracy 0.796610
# Finish party 2 test risk difference 0.090576
# Party 2 accuracy 0.796742
# Finish 2 testing epoch, Acc: 0.796676
# Finish 2 risk difference 0.084572
# **********
# epoch 3
# tensor(0.4244, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.799133
# Party 1 accuracy 0.797133
# Party 1 risk difference 0.081925
# Party 2 risk difference 0.080736
# global training risk dfference: 0.081334
# Finish 3 training epoch, Acc: 0.798133
# Finish party 1 test risk difference 0.078498
# Party 1 accuracy 0.797399
# Finish party 2 test risk difference 0.091355
# Party 2 accuracy 0.797267
# Finish 3 testing epoch, Acc: 0.797333
# Finish 3 risk difference 0.084940
# **********
# epoch 4
# tensor(0.4242, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.799600
# Party 1 accuracy 0.797467
# Party 1 risk difference 0.082509
# Party 2 risk difference 0.081318
# global training risk dfference: 0.081917
# Finish 4 training epoch, Acc: 0.798533
# Finish party 1 test risk difference 0.078694
# Party 1 accuracy 0.797530
# Finish party 2 test risk difference 0.091535
# Party 2 accuracy 0.797267
# Finish 4 testing epoch, Acc: 0.797399
# Finish 4 risk difference 0.085129
# **********
# epoch 5
# tensor(0.4241, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.800333
# Party 1 accuracy 0.797933
# Party 1 risk difference 0.082879
# Party 2 risk difference 0.082402
# global training risk dfference: 0.082644
# Finish 5 training epoch, Acc: 0.799133
# Finish party 1 test risk difference 0.079077
# Party 1 accuracy 0.797924
# Finish party 2 test risk difference 0.092119
# Party 2 accuracy 0.797399
# Finish 5 testing epoch, Acc: 0.797661
# Finish 5 risk difference 0.085611
# **********
# epoch 6
# tensor(0.4239, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.800800
# Party 1 accuracy 0.798533
# Party 1 risk difference 0.083751
# Party 2 risk difference 0.083575
# global training risk dfference: 0.083667
# Finish 6 training epoch, Acc: 0.799667
# Finish party 1 test risk difference 0.080040
# Party 1 accuracy 0.799369
# Finish party 2 test risk difference 0.093257
# Party 2 accuracy 0.798712
# Finish 6 testing epoch, Acc: 0.799041
# Finish 6 risk difference 0.086662
# **********
# epoch 7
# tensor(0.4238, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.801000
# Party 1 accuracy 0.799133
# Party 1 risk difference 0.084837
# Party 2 risk difference 0.084856
# global training risk dfference: 0.084850
# Finish 7 training epoch, Acc: 0.800067
# Finish party 1 test risk difference 0.079623
# Party 1 accuracy 0.800289
# Finish party 2 test risk difference 0.093392
# Party 2 accuracy 0.799895
# Finish 7 testing epoch, Acc: 0.800092
# Finish 7 risk difference 0.086524
# **********
# epoch 8
# tensor(0.4236, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.801867
# Party 1 accuracy 0.799333
# Party 1 risk difference 0.086210
# Party 2 risk difference 0.086030
# global training risk dfference: 0.086124
# Finish 8 training epoch, Acc: 0.800600
# Finish party 1 test risk difference 0.080602
# Party 1 accuracy 0.800420
# Finish party 2 test risk difference 0.093363
# Party 2 accuracy 0.800420
# Finish 8 testing epoch, Acc: 0.800420
# Finish 8 risk difference 0.087000
# **********
# epoch 9
# tensor(0.4235, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.802733
# Party 1 accuracy 0.800533
# Party 1 risk difference 0.087280
# Party 2 risk difference 0.087570
# global training risk dfference: 0.087429
# Finish 9 training epoch, Acc: 0.801633
# Finish party 1 test risk difference 0.081573
# Party 1 accuracy 0.800946
# Finish party 2 test risk difference 0.094111
# Party 2 accuracy 0.801209
# Finish 9 testing epoch, Acc: 0.801077
# Finish 9 risk difference 0.087862
# **********
# epoch 10
# tensor(0.4233, grad_fn=<MeanBackward0>)
# Party 1 accuracy 0.803600
# Party 1 accuracy 0.801333
# Party 1 risk difference 0.088851
# Party 2 risk difference 0.089541
# global training risk dfference: 0.089200
# Finish 10 training epoch, Acc: 0.802467
# Finish party 1 test risk difference 0.083913
# Party 1 accuracy 0.801340
# Finish party 2 test risk difference 0.094875
# Party 2 accuracy 0.802128
# Finish 10 testing epoch, Acc: 0.801734
# Finish 10 risk difference 0.089412

# %%
# with fair
for i in range(Iteration):
    # compute with the option "with fair" => Zafar et al.
    theta, bias = compute_model_parameter_fairness(weight, Sen_torch, ratio_fair, options[1], k)
# Out:
# **********
# epoch 1
# tensor(3.1944, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.804400
# Party 1 accuracy 0.802400
# Party 1 risk difference 0.090216
# Party 2 risk difference 0.092103
# global training risk dfference: 0.091164
# Finish 1 training epoch, Acc: 0.803400
# Finish party 1 test risk difference 0.423856
# Party 1 accuracy 0.709762
# Finish party 2 test risk difference 0.424053
# Party 2 accuracy 0.696229
# Finish 1 testing epoch, Acc: 0.702996
# Finish 1 risk difference 0.424036
# **********
# epoch 2
# tensor(1.2806, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.700067
# Party 1 accuracy 0.704133
# Party 1 risk difference 0.420519
# Party 2 risk difference 0.433159
# global training risk dfference: 0.426833
# Finish 2 training epoch, Acc: 0.702100
# Finish party 1 test risk difference 0.399808
# Party 1 accuracy 0.694915
# Finish party 2 test risk difference 0.391884
# Party 2 accuracy 0.681908
# Finish 2 testing epoch, Acc: 0.688412
# Finish 2 risk difference 0.395946
# **********
# epoch 3
# tensor(1.1541, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.685333
# Party 1 accuracy 0.685867
# Party 1 risk difference 0.387931
# Party 2 risk difference 0.392365
# global training risk dfference: 0.390152
# Finish 3 training epoch, Acc: 0.685600
# Finish party 1 test risk difference 0.399375
# Party 1 accuracy 0.694521
# Finish party 2 test risk difference 0.390028
# Party 2 accuracy 0.682171
# Finish 3 testing epoch, Acc: 0.688346
# Finish 3 risk difference 0.394803
# **********
# epoch 4
# tensor(1.0777, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.685200
# Party 1 accuracy 0.685667
# Party 1 risk difference 0.385556
# Party 2 risk difference 0.388593
# global training risk dfference: 0.387078
# Finish 4 training epoch, Acc: 0.685433
# Finish party 1 test risk difference 0.398005
# Party 1 accuracy 0.695966
# Finish party 2 test risk difference 0.389054
# Party 2 accuracy 0.683090
# Finish 4 testing epoch, Acc: 0.689528
# Finish 4 risk difference 0.393632
# **********
# epoch 5
# tensor(1.0143, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.686067
# Party 1 accuracy 0.686333
# Party 1 risk difference 0.384849
# Party 2 risk difference 0.388306
# global training risk dfference: 0.386580
# Finish 5 training epoch, Acc: 0.686200
# Finish party 1 test risk difference 0.393707
# Party 1 accuracy 0.698726
# Finish party 2 test risk difference 0.386134
# Party 2 accuracy 0.684798
# Finish 5 testing epoch, Acc: 0.691762
# Finish 5 risk difference 0.390026
# **********
# epoch 6
# tensor(0.9613, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.688067
# Party 1 accuracy 0.689267
# Party 1 risk difference 0.380549
# Party 2 risk difference 0.385780
# global training risk dfference: 0.383165
# Finish 6 training epoch, Acc: 0.688667
# Finish party 1 test risk difference 0.386032
# Party 1 accuracy 0.701879
# Finish party 2 test risk difference 0.381867
# Party 2 accuracy 0.688083
# Finish 6 testing epoch, Acc: 0.694981
# Finish 6 risk difference 0.384050
# **********
# epoch 7
# tensor(0.9171, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.691400
# Party 1 accuracy 0.691533
# Party 1 risk difference 0.375689
# Party 2 risk difference 0.380727
# global training risk dfference: 0.378211
# Finish 7 training epoch, Acc: 0.691467
# Finish party 1 test risk difference 0.378774
# Party 1 accuracy 0.707003
# Finish party 2 test risk difference 0.373481
# Party 2 accuracy 0.693076
# Finish 7 testing epoch, Acc: 0.700039
# Finish 7 risk difference 0.376224
# **********
# epoch 8
# tensor(0.8800, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.695867
# Party 1 accuracy 0.694533
# Party 1 risk difference 0.367656
# Party 2 risk difference 0.371526
# global training risk dfference: 0.369594
# Finish 8 training epoch, Acc: 0.695200
# Finish party 1 test risk difference 0.360701
# Party 1 accuracy 0.714361
# Finish party 2 test risk difference 0.363090
# Party 2 accuracy 0.697280
# Finish 8 testing epoch, Acc: 0.705821
# Finish 8 risk difference 0.361998
# **********
# epoch 9
# tensor(0.8490, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.702400
# Party 1 accuracy 0.701000
# Party 1 risk difference 0.357467
# Party 2 risk difference 0.357129
# global training risk dfference: 0.357301
# Finish 9 training epoch, Acc: 0.701700
# Finish party 1 test risk difference 0.341208
# Party 1 accuracy 0.721062
# Finish party 2 test risk difference 0.345406
# Party 2 accuracy 0.702930
# Finish 9 testing epoch, Acc: 0.711996
# Finish 9 risk difference 0.343407
# **********
# epoch 10
# tensor(0.8230, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.709467
# Party 1 accuracy 0.707200
# Party 1 risk difference 0.340214
# Party 2 risk difference 0.337840
# global training risk dfference: 0.339034
# Finish 10 training epoch, Acc: 0.708333
# Finish party 1 test risk difference 0.326275
# Party 1 accuracy 0.724346
# Finish party 2 test risk difference 0.325835
# Party 2 accuracy 0.711996
# Finish 10 testing epoch, Acc: 0.718171
# Finish 10 risk difference 0.326149
# **********
# epoch 1
# tensor(0.8011, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.714800
# Party 1 accuracy 0.713467
# Party 1 risk difference 0.325709
# Party 2 risk difference 0.318238
# global training risk dfference: 0.321981
# Finish 1 training epoch, Acc: 0.714133
# Finish party 1 test risk difference 0.311163
# Party 1 accuracy 0.728814
# Finish party 2 test risk difference 0.312253
# Party 2 accuracy 0.718959
# Finish 1 testing epoch, Acc: 0.723886
# Finish 1 risk difference 0.311790
# **********
# epoch 2
# tensor(0.7828, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.720400
# Party 1 accuracy 0.720867
# Party 1 risk difference 0.307897
# Party 2 risk difference 0.297624
# global training risk dfference: 0.302768
# Finish 2 training epoch, Acc: 0.720633
# Finish party 1 test risk difference 0.298211
# Party 1 accuracy 0.731179
# Finish party 2 test risk difference 0.295108
# Party 2 accuracy 0.724346
# Finish 2 testing epoch, Acc: 0.727762
# Finish 2 risk difference 0.296731
# **********
# epoch 3
# tensor(0.7673, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.724000
# Party 1 accuracy 0.727667
# Party 1 risk difference 0.291007
# Party 2 risk difference 0.280890
# global training risk dfference: 0.285953
# Finish 3 training epoch, Acc: 0.725833
# Finish party 1 test risk difference 0.276860
# Party 1 accuracy 0.735777
# Finish party 2 test risk difference 0.273424
# Party 2 accuracy 0.732755
# Finish 3 testing epoch, Acc: 0.734266
# Finish 3 risk difference 0.275197
# **********
# epoch 4
# tensor(0.7543, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.732067
# Party 1 accuracy 0.737400
# Party 1 risk difference 0.269287
# Party 2 risk difference 0.255914
# global training risk dfference: 0.262605
# Finish 4 training epoch, Acc: 0.734733
# Finish party 1 test risk difference 0.251137
# Party 1 accuracy 0.739325
# Finish party 2 test risk difference 0.248926
# Party 2 accuracy 0.739587
# Finish 4 testing epoch, Acc: 0.739456
# Finish 4 risk difference 0.250067
# **********
# epoch 5
# tensor(0.7433, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.738667
# Party 1 accuracy 0.743733
# Party 1 risk difference 0.252467
# Party 2 risk difference 0.233044
# global training risk dfference: 0.242759
# Finish 5 training epoch, Acc: 0.741200
# Finish party 1 test risk difference 0.224068
# Party 1 accuracy 0.744449
# Finish party 2 test risk difference 0.226150
# Party 2 accuracy 0.744186
# Finish 5 testing epoch, Acc: 0.744317
# Finish 5 risk difference 0.225139
# **********
# epoch 6
# tensor(0.7340, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.742867
# Party 1 accuracy 0.750800
# Party 1 risk difference 0.227573
# Party 2 risk difference 0.206545
# global training risk dfference: 0.217062
# Finish 6 training epoch, Acc: 0.746833
# Finish party 1 test risk difference 0.204153
# Party 1 accuracy 0.753646
# Finish party 2 test risk difference 0.198912
# Party 2 accuracy 0.749310
# Finish 6 testing epoch, Acc: 0.751478
# Finish 6 risk difference 0.201561
# **********
# epoch 7
# tensor(0.7261, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.749000
# Party 1 accuracy 0.755933
# Party 1 risk difference 0.203649
# Party 2 risk difference 0.185019
# global training risk dfference: 0.194337
# Finish 7 training epoch, Acc: 0.752467
# Finish party 1 test risk difference 0.186969
# Party 1 accuracy 0.757194
# Finish party 2 test risk difference 0.183802
# Party 2 accuracy 0.753383
# Finish 7 testing epoch, Acc: 0.755288
# Finish 7 risk difference 0.185417
# **********
# epoch 8
# tensor(0.7193, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.752200
# Party 1 accuracy 0.757400
# Party 1 risk difference 0.186073
# Party 2 risk difference 0.167711
# global training risk dfference: 0.176897
# Finish 8 training epoch, Acc: 0.754800
# Finish party 1 test risk difference 0.170536
# Party 1 accuracy 0.757850
# Finish party 2 test risk difference 0.174188
# Party 2 accuracy 0.753909
# Finish 8 testing epoch, Acc: 0.755880
# Finish 8 risk difference 0.172391
# **********
# epoch 9
# tensor(0.7136, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.754333
# Party 1 accuracy 0.759467
# Party 1 risk difference 0.173324
# Party 2 risk difference 0.155717
# global training risk dfference: 0.164525
# Finish 9 training epoch, Acc: 0.756900
# Finish party 1 test risk difference 0.165684
# Party 1 accuracy 0.759164
# Finish party 2 test risk difference 0.170189
# Party 2 accuracy 0.754303
# Finish 9 testing epoch, Acc: 0.756734
# Finish 9 risk difference 0.167964
# **********
# epoch 10
# tensor(0.7086, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.755600
# Party 1 accuracy 0.762333
# Party 1 risk difference 0.169589
# Party 2 risk difference 0.148022
# global training risk dfference: 0.158810
# Finish 10 training epoch, Acc: 0.758967
# Finish party 1 test risk difference 0.162006
# Party 1 accuracy 0.759164
# Finish party 2 test risk difference 0.168810
# Party 2 accuracy 0.756931
# Finish 10 testing epoch, Acc: 0.758048
# Finish 10 risk difference 0.165427
# **********
# epoch 1
# tensor(0.7044, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.756133
# Party 1 accuracy 0.763533
# Party 1 risk difference 0.165797
# Party 2 risk difference 0.144673
# global training risk dfference: 0.155238
# Finish 1 training epoch, Acc: 0.759833
# Finish party 1 test risk difference 0.159902
# Party 1 accuracy 0.759033
# Finish party 2 test risk difference 0.168944
# Party 2 accuracy 0.758902
# Finish 1 testing epoch, Acc: 0.758967
# Finish 1 risk difference 0.164440
# **********
# epoch 2
# tensor(0.7007, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.758000
# Party 1 accuracy 0.763267
# Party 1 risk difference 0.164331
# Party 2 risk difference 0.142577
# global training risk dfference: 0.153458
# Finish 2 training epoch, Acc: 0.760633
# Finish party 1 test risk difference 0.159405
# Party 1 accuracy 0.760347
# Finish party 2 test risk difference 0.167101
# Party 2 accuracy 0.760347
# Finish 2 testing epoch, Acc: 0.760347
# Finish 2 risk difference 0.163275
# **********
# epoch 3
# tensor(0.6976, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.758133
# Party 1 accuracy 0.763533
# Party 1 risk difference 0.163826
# Party 2 risk difference 0.143707
# global training risk dfference: 0.153771
# Finish 3 training epoch, Acc: 0.760833
# Finish party 1 test risk difference 0.162456
# Party 1 accuracy 0.761004
# Finish party 2 test risk difference 0.171038
# Party 2 accuracy 0.761004
# Finish 3 testing epoch, Acc: 0.761004
# Finish 3 risk difference 0.166767
# **********
# epoch 4
# tensor(0.6948, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.758400
# Party 1 accuracy 0.763933
# Party 1 risk difference 0.166208
# Party 2 risk difference 0.142221
# global training risk dfference: 0.154221
# Finish 4 training epoch, Acc: 0.761167
# Finish party 1 test risk difference 0.159341
# Party 1 accuracy 0.761004
# Finish party 2 test risk difference 0.173717
# Party 2 accuracy 0.762186
# Finish 4 testing epoch, Acc: 0.761595
# Finish 4 risk difference 0.166543
# **********
# epoch 5
# tensor(0.6924, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.759267
# Party 1 accuracy 0.764733
# Party 1 risk difference 0.167668
# Party 2 risk difference 0.142849
# global training risk dfference: 0.155266
# Finish 5 training epoch, Acc: 0.762000
# Finish party 1 test risk difference 0.161813
# Party 1 accuracy 0.763237
# Finish party 2 test risk difference 0.174600
# Party 2 accuracy 0.763369
# Finish 5 testing epoch, Acc: 0.763303
# Finish 5 risk difference 0.168231
# **********
# epoch 6
# tensor(0.6903, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.759800
# Party 1 accuracy 0.766200
# Party 1 risk difference 0.167494
# Party 2 risk difference 0.143602
# global training risk dfference: 0.155555
# Finish 6 training epoch, Acc: 0.763000
# Finish party 1 test risk difference 0.162066
# Party 1 accuracy 0.762975
# Finish party 2 test risk difference 0.174674
# Party 2 accuracy 0.763500
# Finish 6 testing epoch, Acc: 0.763237
# Finish 6 risk difference 0.168398
# **********
# epoch 7
# tensor(0.6884, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.760667
# Party 1 accuracy 0.766800
# Party 1 risk difference 0.169760
# Party 2 risk difference 0.144239
# global training risk dfference: 0.157008
# Finish 7 training epoch, Acc: 0.763733
# Finish party 1 test risk difference 0.158322
# Party 1 accuracy 0.762186
# Finish party 2 test risk difference 0.171185
# Party 2 accuracy 0.765471
# Finish 7 testing epoch, Acc: 0.763829
# Finish 7 risk difference 0.164776
# **********
# epoch 8
# tensor(0.6867, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.762200
# Party 1 accuracy 0.767267
# Party 1 risk difference 0.170218
# Party 2 risk difference 0.143837
# global training risk dfference: 0.157038
# Finish 8 training epoch, Acc: 0.764733
# Finish party 1 test risk difference 0.157964
# Party 1 accuracy 0.761924
# Finish party 2 test risk difference 0.172248
# Party 2 accuracy 0.766916
# Finish 8 testing epoch, Acc: 0.764420
# Finish 8 risk difference 0.165126
# **********
# epoch 9
# tensor(0.6853, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.762867
# Party 1 accuracy 0.767733
# Party 1 risk difference 0.168490
# Party 2 risk difference 0.144240
# global training risk dfference: 0.156376
# Finish 9 training epoch, Acc: 0.765300
# Finish party 1 test risk difference 0.159408
# Party 1 accuracy 0.763500
# Finish party 2 test risk difference 0.171918
# Party 2 accuracy 0.767705
# Finish 9 testing epoch, Acc: 0.765602
# Finish 9 risk difference 0.165689
# **********
# epoch 10
# tensor(0.6839, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.763133
# Party 1 accuracy 0.769067
# Party 1 risk difference 0.167995
# Party 2 risk difference 0.142664
# global training risk dfference: 0.155340
# Finish 10 training epoch, Acc: 0.766100
# Finish party 1 test risk difference 0.160273
# Party 1 accuracy 0.765077
# Finish party 2 test risk difference 0.172441
# Party 2 accuracy 0.768887
# Finish 10 testing epoch, Acc: 0.766982
# Finish 10 risk difference 0.166384
# **********
# epoch 1
# tensor(0.6827, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.764533
# Party 1 accuracy 0.770600
# Party 1 risk difference 0.167994
# Party 2 risk difference 0.143480
# global training risk dfference: 0.155747
# Finish 1 training epoch, Acc: 0.767567
# Finish party 1 test risk difference 0.157728
# Party 1 accuracy 0.765471
# Finish party 2 test risk difference 0.172126
# Party 2 accuracy 0.770070
# Finish 1 testing epoch, Acc: 0.767770
# Finish 1 risk difference 0.164949
# **********
# epoch 2
# tensor(0.6817, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.765200
# Party 1 accuracy 0.771600
# Party 1 risk difference 0.167589
# Party 2 risk difference 0.145712
# global training risk dfference: 0.156660
# Finish 2 training epoch, Acc: 0.768400
# Finish party 1 test risk difference 0.159173
# Party 1 accuracy 0.765997
# Finish party 2 test risk difference 0.173667
# Party 2 accuracy 0.771778
# Finish 2 testing epoch, Acc: 0.768887
# Finish 2 risk difference 0.166436
# **********
# epoch 3
# tensor(0.6807, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.766667
# Party 1 accuracy 0.771800
# Party 1 risk difference 0.167900
# Party 2 risk difference 0.146510
# global training risk dfference: 0.157215
# Finish 3 training epoch, Acc: 0.769233
# Finish party 1 test risk difference 0.158847
# Party 1 accuracy 0.767048
# Finish party 2 test risk difference 0.172334
# Party 2 accuracy 0.772435
# Finish 3 testing epoch, Acc: 0.769741
# Finish 3 risk difference 0.165616
# **********
# epoch 4
# tensor(0.6798, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.767467
# Party 1 accuracy 0.772667
# Party 1 risk difference 0.166492
# Party 2 risk difference 0.146412
# global training risk dfference: 0.156462
# Finish 4 training epoch, Acc: 0.770067
# Finish party 1 test risk difference 0.161065
# Party 1 accuracy 0.767179
# Finish party 2 test risk difference 0.171421
# Party 2 accuracy 0.774143
# Finish 4 testing epoch, Acc: 0.770661
# Finish 4 risk difference 0.166271
# **********
# epoch 5
# tensor(0.6790, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.769200
# Party 1 accuracy 0.774200
# Party 1 risk difference 0.166819
# Party 2 risk difference 0.148554
# global training risk dfference: 0.157697
# Finish 5 training epoch, Acc: 0.771700
# Finish party 1 test risk difference 0.160723
# Party 1 accuracy 0.768493
# Finish party 2 test risk difference 0.172947
# Party 2 accuracy 0.774931
# Finish 5 testing epoch, Acc: 0.771712
# Finish 5 risk difference 0.166857
# **********
# epoch 6
# tensor(0.6782, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.770867
# Party 1 accuracy 0.775200
# Party 1 risk difference 0.167640
# Party 2 risk difference 0.149568
# global training risk dfference: 0.158614
# Finish 6 training epoch, Acc: 0.773033
# Finish party 1 test risk difference 0.158587
# Party 1 accuracy 0.769150
# Finish party 2 test risk difference 0.174818
# Party 2 accuracy 0.776114
# Finish 6 testing epoch, Acc: 0.772632
# Finish 6 risk difference 0.166719
# **********
# epoch 7
# tensor(0.6775, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.771733
# Party 1 accuracy 0.775867
# Party 1 risk difference 0.167819
# Party 2 risk difference 0.150751
# global training risk dfference: 0.159295
# Finish 7 training epoch, Acc: 0.773800
# Finish party 1 test risk difference 0.159003
# Party 1 accuracy 0.769281
# Finish party 2 test risk difference 0.176524
# Party 2 accuracy 0.777165
# Finish 7 testing epoch, Acc: 0.773223
# Finish 7 risk difference 0.167770
# **********
# epoch 8
# tensor(0.6769, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.773000
# Party 1 accuracy 0.776733
# Party 1 risk difference 0.168730
# Party 2 risk difference 0.151352
# global training risk dfference: 0.160052
# Finish 8 training epoch, Acc: 0.774867
# Finish party 1 test risk difference 0.159240
# Party 1 accuracy 0.769281
# Finish party 2 test risk difference 0.179637
# Party 2 accuracy 0.777427
# Finish 8 testing epoch, Acc: 0.773354
# Finish 8 risk difference 0.169435
# **********
# epoch 9
# tensor(0.6763, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.773933
# Party 1 accuracy 0.777000
# Party 1 risk difference 0.170348
# Party 2 risk difference 0.152660
# global training risk dfference: 0.161516
# Finish 9 training epoch, Acc: 0.775467
# Finish party 1 test risk difference 0.162078
# Party 1 accuracy 0.770595
# Finish party 2 test risk difference 0.180310
# Party 2 accuracy 0.778347
# Finish 9 testing epoch, Acc: 0.774471
# Finish 9 risk difference 0.171198
# **********
# epoch 10
# tensor(0.6757, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.774800
# Party 1 accuracy 0.777533
# Party 1 risk difference 0.169615
# Party 2 risk difference 0.153772
# global training risk dfference: 0.161704
# Finish 10 training epoch, Acc: 0.776167
# Finish party 1 test risk difference 0.162307
# Party 1 accuracy 0.771252
# Finish party 2 test risk difference 0.181373
# Party 2 accuracy 0.779004
# Finish 10 testing epoch, Acc: 0.775128
# Finish 10 risk difference 0.171842
# **********
# epoch 1
# tensor(0.6752, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.776333
# Party 1 accuracy 0.778467
# Party 1 risk difference 0.170403
# Party 2 risk difference 0.154740
# global training risk dfference: 0.162583
# Finish 1 training epoch, Acc: 0.777400
# Finish party 1 test risk difference 0.163922
# Party 1 accuracy 0.771515
# Finish party 2 test risk difference 0.181253
# Party 2 accuracy 0.780318
# Finish 1 testing epoch, Acc: 0.775916
# Finish 1 risk difference 0.172588
# **********
# epoch 2
# tensor(0.6747, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.778067
# Party 1 accuracy 0.779600
# Party 1 risk difference 0.172416
# Party 2 risk difference 0.155323
# global training risk dfference: 0.163882
# Finish 2 training epoch, Acc: 0.778833
# Finish party 1 test risk difference 0.162952
# Party 1 accuracy 0.772566
# Finish party 2 test risk difference 0.181103
# Party 2 accuracy 0.781106
# Finish 2 testing epoch, Acc: 0.776836
# Finish 2 risk difference 0.172026
# **********
# epoch 3
# tensor(0.6742, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.779267
# Party 1 accuracy 0.780667
# Party 1 risk difference 0.173302
# Party 2 risk difference 0.155754
# global training risk dfference: 0.164539
# Finish 3 training epoch, Acc: 0.779967
# Finish party 1 test risk difference 0.166565
# Party 1 accuracy 0.774011
# Finish party 2 test risk difference 0.183782
# Party 2 accuracy 0.782026
# Finish 3 testing epoch, Acc: 0.778019
# Finish 3 risk difference 0.175172
# **********
# epoch 4
# tensor(0.6738, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.779800
# Party 1 accuracy 0.781733
# Party 1 risk difference 0.174583
# Party 2 risk difference 0.156256
# global training risk dfference: 0.165431
# Finish 4 training epoch, Acc: 0.780767
# Finish party 1 test risk difference 0.167194
# Party 1 accuracy 0.774537
# Finish party 2 test risk difference 0.184066
# Party 2 accuracy 0.783209
# Finish 4 testing epoch, Acc: 0.778873
# Finish 4 risk difference 0.175626
# **********
# epoch 5
# tensor(0.6734, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.780467
# Party 1 accuracy 0.782533
# Party 1 risk difference 0.174632
# Party 2 risk difference 0.156938
# global training risk dfference: 0.165795
# Finish 5 training epoch, Acc: 0.781500
# Finish party 1 test risk difference 0.167022
# Party 1 accuracy 0.774800
# Finish party 2 test risk difference 0.184515
# Party 2 accuracy 0.784260
# Finish 5 testing epoch, Acc: 0.779530
# Finish 5 risk difference 0.175764
# **********
# epoch 6
# tensor(0.6730, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.781133
# Party 1 accuracy 0.783267
# Party 1 risk difference 0.174985
# Party 2 risk difference 0.158022
# global training risk dfference: 0.166513
# Finish 6 training epoch, Acc: 0.782200
# Finish party 1 test risk difference 0.168842
# Party 1 accuracy 0.775588
# Finish party 2 test risk difference 0.186161
# Party 2 accuracy 0.785048
# Finish 6 testing epoch, Acc: 0.780318
# Finish 6 risk difference 0.177498
# **********
# epoch 7
# tensor(0.6726, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.781667
# Party 1 accuracy 0.783467
# Party 1 risk difference 0.176645
# Party 2 risk difference 0.158569
# global training risk dfference: 0.167617
# Finish 7 training epoch, Acc: 0.782567
# Finish party 1 test risk difference 0.168883
# Party 1 accuracy 0.776508
# Finish party 2 test risk difference 0.186415
# Party 2 accuracy 0.785968
# Finish 7 testing epoch, Acc: 0.781238
# Finish 7 risk difference 0.177648
# **********
# epoch 8
# tensor(0.6723, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.782200
# Party 1 accuracy 0.784000
# Party 1 risk difference 0.175476
# Party 2 risk difference 0.158121
# global training risk dfference: 0.166809
# Finish 8 training epoch, Acc: 0.783100
# Finish party 1 test risk difference 0.170302
# Party 1 accuracy 0.776902
# Finish party 2 test risk difference 0.186849
# Party 2 accuracy 0.786099
# Finish 8 testing epoch, Acc: 0.781500
# Finish 8 risk difference 0.178578
# **********
# epoch 9
# tensor(0.6720, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.782933
# Party 1 accuracy 0.784400
# Party 1 risk difference 0.176569
# Party 2 risk difference 0.157960
# global training risk dfference: 0.167276
# Finish 9 training epoch, Acc: 0.783667
# Finish party 1 test risk difference 0.172121
# Party 1 accuracy 0.777690
# Finish party 2 test risk difference 0.187089
# Party 2 accuracy 0.786099
# Finish 9 testing epoch, Acc: 0.781895
# Finish 9 risk difference 0.179612
# **********
# epoch 10
# tensor(0.6716, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.784400
# Party 1 accuracy 0.785067
# Party 1 risk difference 0.177759
# Party 2 risk difference 0.158946
# global training risk dfference: 0.168365
# Finish 10 training epoch, Acc: 0.784733
# Finish party 1 test risk difference 0.175523
# Party 1 accuracy 0.778216
# Finish party 2 test risk difference 0.187747
# Party 2 accuracy 0.786887
# Finish 10 testing epoch, Acc: 0.782552
# Finish 10 risk difference 0.181644
# **********
# epoch 1
# tensor(0.6713, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.784867
# Party 1 accuracy 0.785333
# Party 1 risk difference 0.177298
# Party 2 risk difference 0.159592
# global training risk dfference: 0.168457
# Finish 1 training epoch, Acc: 0.785100
# Finish party 1 test risk difference 0.176942
# Party 1 accuracy 0.779135
# Finish party 2 test risk difference 0.189154
# Party 2 accuracy 0.787150
# Finish 1 testing epoch, Acc: 0.783143
# Finish 1 risk difference 0.183063
# **********
# epoch 2
# tensor(0.6710, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.785600
# Party 1 accuracy 0.785933
# Party 1 risk difference 0.178267
# Party 2 risk difference 0.160139
# global training risk dfference: 0.169216
# Finish 2 training epoch, Acc: 0.785767
# Finish party 1 test risk difference 0.177758
# Party 1 accuracy 0.779661
# Finish party 2 test risk difference 0.190202
# Party 2 accuracy 0.788201
# Finish 2 testing epoch, Acc: 0.783931
# Finish 2 risk difference 0.183993
# **********
# epoch 3
# tensor(0.6708, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.786000
# Party 1 accuracy 0.786333
# Party 1 risk difference 0.179319
# Party 2 risk difference 0.160892
# global training risk dfference: 0.170118
# Finish 3 training epoch, Acc: 0.786167
# Finish party 1 test risk difference 0.177366
# Party 1 accuracy 0.779924
# Finish party 2 test risk difference 0.190052
# Party 2 accuracy 0.788990
# Finish 3 testing epoch, Acc: 0.784457
# Finish 3 risk difference 0.183718
# **********
# epoch 4
# tensor(0.6705, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.786600
# Party 1 accuracy 0.787133
# Party 1 risk difference 0.180165
# Party 2 risk difference 0.162971
# global training risk dfference: 0.171580
# Finish 4 training epoch, Acc: 0.786867
# Finish party 1 test risk difference 0.178190
# Party 1 accuracy 0.781369
# Finish party 2 test risk difference 0.191100
# Party 2 accuracy 0.789252
# Finish 4 testing epoch, Acc: 0.785311
# Finish 4 risk difference 0.184654
# **********
# epoch 5
# tensor(0.6703, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.787267
# Party 1 accuracy 0.787800
# Party 1 risk difference 0.181505
# Party 2 risk difference 0.163616
# global training risk dfference: 0.172572
# Finish 5 training epoch, Acc: 0.787533
# Finish party 1 test risk difference 0.178223
# Party 1 accuracy 0.782157
# Finish party 2 test risk difference 0.191114
# Party 2 accuracy 0.789384
# Finish 5 testing epoch, Acc: 0.785771
# Finish 5 risk difference 0.184682
# **********
# epoch 6
# tensor(0.6700, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.787400
# Party 1 accuracy 0.788733
# Party 1 risk difference 0.181340
# Party 2 risk difference 0.164476
# global training risk dfference: 0.172919
# Finish 6 training epoch, Acc: 0.788067
# Finish party 1 test risk difference 0.178027
# Party 1 accuracy 0.782026
# Finish party 2 test risk difference 0.191548
# Party 2 accuracy 0.790304
# Finish 6 testing epoch, Acc: 0.786165
# Finish 6 risk difference 0.184797
# **********
# epoch 7
# tensor(0.6698, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.788067
# Party 1 accuracy 0.789267
# Party 1 risk difference 0.181676
# Party 2 risk difference 0.165749
# global training risk dfference: 0.173723
# Finish 7 training epoch, Acc: 0.788667
# Finish party 1 test risk difference 0.178631
# Party 1 accuracy 0.782157
# Finish party 2 test risk difference 0.193195
# Party 2 accuracy 0.791355
# Finish 7 testing epoch, Acc: 0.786756
# Finish 7 risk difference 0.185917
# **********
# epoch 8
# tensor(0.6696, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.788533
# Party 1 accuracy 0.790000
# Party 1 risk difference 0.181610
# Party 2 risk difference 0.166511
# global training risk dfference: 0.174070
# Finish 8 training epoch, Acc: 0.789267
# Finish party 1 test risk difference 0.178656
# Party 1 accuracy 0.782814
# Finish party 2 test risk difference 0.193629
# Party 2 accuracy 0.791749
# Finish 8 testing epoch, Acc: 0.787282
# Finish 8 risk difference 0.186147
# **********
# epoch 9
# tensor(0.6693, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.789333
# Party 1 accuracy 0.790733
# Party 1 risk difference 0.181642
# Party 2 risk difference 0.167165
# global training risk dfference: 0.174413
# Finish 9 training epoch, Acc: 0.790033
# Finish party 1 test risk difference 0.181266
# Party 1 accuracy 0.783997
# Finish party 2 test risk difference 0.193254
# Party 2 accuracy 0.791617
# Finish 9 testing epoch, Acc: 0.787807
# Finish 9 risk difference 0.187272
# **********
# epoch 10
# tensor(0.6691, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.789867
# Party 1 accuracy 0.791333
# Party 1 risk difference 0.183804
# Party 2 risk difference 0.168411
# global training risk dfference: 0.176117
# Finish 10 training epoch, Acc: 0.790600
# Finish party 1 test risk difference 0.180695
# Party 1 accuracy 0.784917
# Finish party 2 test risk difference 0.195096
# Party 2 accuracy 0.792274
# Finish 10 testing epoch, Acc: 0.788595
# Finish 10 risk difference 0.187904
# **********
# epoch 1
# tensor(0.6689, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.790600
# Party 1 accuracy 0.791933
# Party 1 risk difference 0.184756
# Party 2 risk difference 0.168761
# global training risk dfference: 0.176769
# Finish 1 training epoch, Acc: 0.791267
# Finish party 1 test risk difference 0.180540
# Party 1 accuracy 0.785968
# Finish party 2 test risk difference 0.196533
# Party 2 accuracy 0.792800
# Finish 1 testing epoch, Acc: 0.789384
# Finish 1 risk difference 0.188547
# **********
# epoch 2
# tensor(0.6687, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.791933
# Party 1 accuracy 0.793000
# Party 1 risk difference 0.187148
# Party 2 risk difference 0.170858
# global training risk dfference: 0.179013
# Finish 2 training epoch, Acc: 0.792467
# Finish party 1 test risk difference 0.180957
# Party 1 accuracy 0.786625
# Finish party 2 test risk difference 0.196772
# Party 2 accuracy 0.793325
# Finish 2 testing epoch, Acc: 0.789975
# Finish 2 risk difference 0.188875
# **********
# epoch 3
# tensor(0.6686, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.792800
# Party 1 accuracy 0.793467
# Party 1 risk difference 0.188709
# Party 2 risk difference 0.171494
# global training risk dfference: 0.180113
# Finish 3 training epoch, Acc: 0.793133
# Finish party 1 test risk difference 0.181373
# Party 1 accuracy 0.787544
# Finish party 2 test risk difference 0.196188
# Party 2 accuracy 0.793194
# Finish 3 testing epoch, Acc: 0.790369
# Finish 3 risk difference 0.188794
# **********
# epoch 4
# tensor(0.6684, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.793467
# Party 1 accuracy 0.793733
# Party 1 risk difference 0.190278
# Party 2 risk difference 0.172229
# global training risk dfference: 0.181266
# Finish 4 training epoch, Acc: 0.793600
# Finish party 1 test risk difference 0.181193
# Party 1 accuracy 0.787939
# Finish party 2 test risk difference 0.197011
# Party 2 accuracy 0.793851
# Finish 4 testing epoch, Acc: 0.790895
# Finish 4 risk difference 0.189116
# **********
# epoch 5
# tensor(0.6682, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.794467
# Party 1 accuracy 0.794467
# Party 1 risk difference 0.191749
# Party 2 risk difference 0.172597
# global training risk dfference: 0.182186
# Finish 5 training epoch, Acc: 0.794467
# Finish party 1 test risk difference 0.181601
# Party 1 accuracy 0.788464
# Finish party 2 test risk difference 0.198059
# Party 2 accuracy 0.794639
# Finish 5 testing epoch, Acc: 0.791552
# Finish 5 risk difference 0.189840
# **********
# epoch 6
# tensor(0.6681, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.795133
# Party 1 accuracy 0.795400
# Party 1 risk difference 0.191888
# Party 2 risk difference 0.173959
# global training risk dfference: 0.182936
# Finish 6 training epoch, Acc: 0.795267
# Finish party 1 test risk difference 0.182213
# Party 1 accuracy 0.788990
# Finish party 2 test risk difference 0.199496
# Party 2 accuracy 0.795428
# Finish 6 testing epoch, Acc: 0.792209
# Finish 6 risk difference 0.190862
# **********
# epoch 7
# tensor(0.6679, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.796533
# Party 1 accuracy 0.796267
# Party 1 risk difference 0.193284
# Party 2 risk difference 0.174613
# global training risk dfference: 0.183962
# Finish 7 training epoch, Acc: 0.796400
# Finish party 1 test risk difference 0.181846
# Party 1 accuracy 0.790172
# Finish party 2 test risk difference 0.198523
# Party 2 accuracy 0.795822
# Finish 7 testing epoch, Acc: 0.792997
# Finish 7 risk difference 0.190196
# **********
# epoch 8
# tensor(0.6677, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.797800
# Party 1 accuracy 0.797000
# Party 1 risk difference 0.194648
# Party 2 risk difference 0.175178
# global training risk dfference: 0.184927
# Finish 8 training epoch, Acc: 0.797400
# Finish party 1 test risk difference 0.181871
# Party 1 accuracy 0.791092
# Finish party 2 test risk difference 0.196965
# Party 2 accuracy 0.796610
# Finish 8 testing epoch, Acc: 0.793851
# Finish 8 risk difference 0.189432
# **********
# epoch 9
# tensor(0.6676, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.798667
# Party 1 accuracy 0.798200
# Party 1 risk difference 0.195420
# Party 2 risk difference 0.177168
# global training risk dfference: 0.186307
# Finish 9 training epoch, Acc: 0.798433
# Finish party 1 test risk difference 0.183086
# Party 1 accuracy 0.792012
# Finish party 2 test risk difference 0.196621
# Party 2 accuracy 0.797530
# Finish 9 testing epoch, Acc: 0.794771
# Finish 9 risk difference 0.189869
# **********
# epoch 10
# tensor(0.6675, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.799200
# Party 1 accuracy 0.798667
# Party 1 risk difference 0.196364
# Party 2 risk difference 0.178127
# global training risk dfference: 0.187259
# Finish 10 training epoch, Acc: 0.798933
# Finish party 1 test risk difference 0.182524
# Party 1 accuracy 0.793063
# Finish party 2 test risk difference 0.198252
# Party 2 accuracy 0.797399
# Finish 10 testing epoch, Acc: 0.795231
# Finish 10 risk difference 0.190403
# **********
# epoch 1
# tensor(0.6673, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.800133
# Party 1 accuracy 0.799533
# Party 1 risk difference 0.196915
# Party 2 risk difference 0.179390
# global training risk dfference: 0.188166
# Finish 1 training epoch, Acc: 0.799833
# Finish party 1 test risk difference 0.182540
# Party 1 accuracy 0.793588
# Finish party 2 test risk difference 0.199509
# Party 2 accuracy 0.798187
# Finish 1 testing epoch, Acc: 0.795888
# Finish 1 risk difference 0.191035
# **********
# epoch 2
# tensor(0.6672, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.800800
# Party 1 accuracy 0.800400
# Party 1 risk difference 0.197448
# Party 2 risk difference 0.180116
# global training risk dfference: 0.188796
# Finish 2 training epoch, Acc: 0.800600
# Finish party 1 test risk difference 0.182761
# Party 1 accuracy 0.794114
# Finish party 2 test risk difference 0.199554
# Party 2 accuracy 0.798844
# Finish 2 testing epoch, Acc: 0.796479
# Finish 2 risk difference 0.191167
# **********
# epoch 3
# tensor(0.6671, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.801267
# Party 1 accuracy 0.801067
# Party 1 risk difference 0.197062
# Party 2 risk difference 0.180869
# global training risk dfference: 0.188978
# Finish 3 training epoch, Acc: 0.801167
# Finish party 1 test risk difference 0.184188
# Party 1 accuracy 0.795428
# Finish party 2 test risk difference 0.199180
# Party 2 accuracy 0.798450
# Finish 3 testing epoch, Acc: 0.796939
# Finish 3 risk difference 0.191701
# **********
# epoch 4
# tensor(0.6669, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.802733
# Party 1 accuracy 0.801867
# Party 1 risk difference 0.196716
# Party 2 risk difference 0.181819
# global training risk dfference: 0.189280
# Finish 4 training epoch, Acc: 0.802300
# Finish party 1 test risk difference 0.185999
# Party 1 accuracy 0.796873
# Finish party 2 test risk difference 0.199808
# Party 2 accuracy 0.798975
# Finish 4 testing epoch, Acc: 0.797924
# Finish 4 risk difference 0.192924
# **********
# epoch 5
# tensor(0.6668, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.802733
# Party 1 accuracy 0.802333
# Party 1 risk difference 0.197570
# Party 2 risk difference 0.182653
# global training risk dfference: 0.190124
# Finish 5 training epoch, Acc: 0.802533
# Finish party 1 test risk difference 0.187623
# Party 1 accuracy 0.798055
# Finish party 2 test risk difference 0.201036
# Party 2 accuracy 0.799501
# Finish 5 testing epoch, Acc: 0.798778
# Finish 5 risk difference 0.194354
# **********
# epoch 6
# tensor(0.6667, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.803200
# Party 1 accuracy 0.803200
# Party 1 risk difference 0.198202
# Party 2 risk difference 0.183612
# global training risk dfference: 0.190920
# Finish 6 training epoch, Acc: 0.803200
# Finish party 1 test risk difference 0.188047
# Party 1 accuracy 0.799369
# Finish party 2 test risk difference 0.201470
# Party 2 accuracy 0.800420
# Finish 6 testing epoch, Acc: 0.799895
# Finish 6 risk difference 0.194785
# **********
# epoch 7
# tensor(0.6666, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.803733
# Party 1 accuracy 0.803333
# Party 1 risk difference 0.199254
# Party 2 risk difference 0.184239
# global training risk dfference: 0.191760
# Finish 7 training epoch, Acc: 0.803533
# Finish party 1 test risk difference 0.187655
# Party 1 accuracy 0.799369
# Finish party 2 test risk difference 0.201918
# Party 2 accuracy 0.801472
# Finish 7 testing epoch, Acc: 0.800420
# Finish 7 risk difference 0.194808
# **********
# epoch 8
# tensor(0.6665, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.804267
# Party 1 accuracy 0.804333
# Party 1 risk difference 0.199772
# Party 2 risk difference 0.185395
# global training risk dfference: 0.192596
# Finish 8 training epoch, Acc: 0.804300
# Finish party 1 test risk difference 0.189058
# Party 1 accuracy 0.800026
# Finish party 2 test risk difference 0.201559
# Party 2 accuracy 0.801997
# Finish 8 testing epoch, Acc: 0.801012
# Finish 8 risk difference 0.195330
# **********
# epoch 9
# tensor(0.6664, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.805000
# Party 1 accuracy 0.805467
# Party 1 risk difference 0.201242
# Party 2 risk difference 0.187895
# global training risk dfference: 0.194581
# Finish 9 training epoch, Acc: 0.805233
# Finish party 1 test risk difference 0.188871
# Party 1 accuracy 0.800552
# Finish party 2 test risk difference 0.205586
# Party 2 accuracy 0.803180
# Finish 9 testing epoch, Acc: 0.801866
# Finish 9 risk difference 0.197242
# **********
# epoch 10
# tensor(0.6663, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.805733
# Party 1 accuracy 0.806333
# Party 1 risk difference 0.201480
# Party 2 risk difference 0.189069
# global training risk dfference: 0.195286
# Finish 10 training epoch, Acc: 0.806033
# Finish party 1 test risk difference 0.188887
# Party 1 accuracy 0.800552
# Finish party 2 test risk difference 0.204822
# Party 2 accuracy 0.803574
# Finish 10 testing epoch, Acc: 0.802063
# Finish 10 risk difference 0.196869
# **********
# epoch 1
# tensor(0.6662, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.806400
# Party 1 accuracy 0.806867
# Party 1 risk difference 0.202318
# Party 2 risk difference 0.190736
# global training risk dfference: 0.196538
# Finish 1 training epoch, Acc: 0.806633
# Finish party 1 test risk difference 0.192901
# Party 1 accuracy 0.802128
# Finish party 2 test risk difference 0.205047
# Party 2 accuracy 0.803968
# Finish 1 testing epoch, Acc: 0.803048
# Finish 1 risk difference 0.199000
# **********
# epoch 2
# tensor(0.6661, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.806667
# Party 1 accuracy 0.807467
# Party 1 risk difference 0.203049
# Party 2 risk difference 0.190781
# global training risk dfference: 0.196926
# Finish 2 training epoch, Acc: 0.807067
# Finish party 1 test risk difference 0.192713
# Party 1 accuracy 0.802391
# Finish party 2 test risk difference 0.205690
# Party 2 accuracy 0.804888
# Finish 2 testing epoch, Acc: 0.803639
# Finish 2 risk difference 0.199224
# **********
# epoch 3
# tensor(0.6660, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.807333
# Party 1 accuracy 0.808533
# Party 1 risk difference 0.203690
# Party 2 risk difference 0.191032
# global training risk dfference: 0.197371
# Finish 3 training epoch, Acc: 0.807933
# Finish party 1 test risk difference 0.193708
# Party 1 accuracy 0.802785
# Finish party 2 test risk difference 0.207097
# Party 2 accuracy 0.805150
# Finish 3 testing epoch, Acc: 0.803968
# Finish 3 risk difference 0.200424
# **********
# epoch 4
# tensor(0.6659, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.807733
# Party 1 accuracy 0.809533
# Party 1 risk difference 0.203418
# Party 2 risk difference 0.191597
# global training risk dfference: 0.197517
# Finish 4 training epoch, Acc: 0.808633
# Finish party 1 test risk difference 0.195119
# Party 1 accuracy 0.803837
# Finish party 2 test risk difference 0.208115
# Party 2 accuracy 0.805676
# Finish 4 testing epoch, Acc: 0.804756
# Finish 4 risk difference 0.201641
# **********
# epoch 5
# tensor(0.6658, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.808200
# Party 1 accuracy 0.810400
# Party 1 risk difference 0.203640
# Party 2 risk difference 0.192664
# global training risk dfference: 0.198160
# Finish 5 training epoch, Acc: 0.809300
# Finish party 1 test risk difference 0.195748
# Party 1 accuracy 0.804888
# Finish party 2 test risk difference 0.208175
# Party 2 accuracy 0.806464
# Finish 5 testing epoch, Acc: 0.805676
# Finish 5 risk difference 0.201986
# **********
# epoch 6
# tensor(0.6657, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.808667
# Party 1 accuracy 0.811467
# Party 1 risk difference 0.203771
# Party 2 risk difference 0.193632
# global training risk dfference: 0.198709
# Finish 6 training epoch, Acc: 0.810067
# Finish party 1 test risk difference 0.195952
# Party 1 accuracy 0.805413
# Finish party 2 test risk difference 0.209807
# Party 2 accuracy 0.806858
# Finish 6 testing epoch, Acc: 0.806136
# Finish 6 risk difference 0.202899
# **********
# epoch 7
# tensor(0.6656, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.809200
# Party 1 accuracy 0.812400
# Party 1 risk difference 0.204518
# Party 2 risk difference 0.194905
# global training risk dfference: 0.199718
# Finish 7 training epoch, Acc: 0.810800
# Finish party 1 test risk difference 0.196368
# Party 1 accuracy 0.806333
# Finish party 2 test risk difference 0.210240
# Party 2 accuracy 0.807253
# Finish 7 testing epoch, Acc: 0.806793
# Finish 7 risk difference 0.203324
# **********
# epoch 8
# tensor(0.6656, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.810133
# Party 1 accuracy 0.812933
# Party 1 risk difference 0.205373
# Party 2 risk difference 0.195442
# global training risk dfference: 0.200415
# Finish 8 training epoch, Acc: 0.811533
# Finish party 1 test risk difference 0.196979
# Party 1 accuracy 0.806858
# Finish party 2 test risk difference 0.211079
# Party 2 accuracy 0.808041
# Finish 8 testing epoch, Acc: 0.807450
# Finish 8 risk difference 0.204047
# **********
# epoch 9
# tensor(0.6655, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.810933
# Party 1 accuracy 0.812933
# Party 1 risk difference 0.205512
# Party 2 risk difference 0.196589
# global training risk dfference: 0.201058
# Finish 9 training epoch, Acc: 0.811933
# Finish party 1 test risk difference 0.197387
# Party 1 accuracy 0.807121
# Finish party 2 test risk difference 0.211707
# Party 2 accuracy 0.808304
# Finish 9 testing epoch, Acc: 0.807713
# Finish 9 risk difference 0.204564
# **********
# epoch 10
# tensor(0.6654, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.811267
# Party 1 accuracy 0.813200
# Party 1 risk difference 0.205947
# Party 2 risk difference 0.196303
# global training risk dfference: 0.201133
# Finish 10 training epoch, Acc: 0.812233
# Finish party 1 test risk difference 0.197591
# Party 1 accuracy 0.806858
# Finish party 2 test risk difference 0.212126
# Party 2 accuracy 0.808567
# Finish 10 testing epoch, Acc: 0.807713
# Finish 10 risk difference 0.204874
# **********
# epoch 1
# tensor(0.6653, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.811667
# Party 1 accuracy 0.813667
# Party 1 risk difference 0.205979
# Party 2 risk difference 0.196939
# global training risk dfference: 0.201467
# Finish 1 training epoch, Acc: 0.812667
# Finish party 1 test risk difference 0.197795
# Party 1 accuracy 0.806858
# Finish party 2 test risk difference 0.212755
# Party 2 accuracy 0.808829
# Finish 1 testing epoch, Acc: 0.807844
# Finish 1 risk difference 0.205288
# **********
# epoch 2
# tensor(0.6653, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.812267
# Party 1 accuracy 0.814200
# Party 1 risk difference 0.205502
# Party 2 risk difference 0.196868
# global training risk dfference: 0.201193
# Finish 2 training epoch, Acc: 0.813233
# Finish party 1 test risk difference 0.197428
# Party 1 accuracy 0.807515
# Finish party 2 test risk difference 0.213174
# Party 2 accuracy 0.809092
# Finish 2 testing epoch, Acc: 0.808304
# Finish 2 risk difference 0.205316
# **********
# epoch 3
# tensor(0.6652, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.812800
# Party 1 accuracy 0.814467
# Party 1 risk difference 0.206447
# Party 2 risk difference 0.197298
# global training risk dfference: 0.201881
# Finish 3 training epoch, Acc: 0.813633
# Finish party 1 test risk difference 0.198236
# Party 1 accuracy 0.808172
# Finish party 2 test risk difference 0.216632
# Party 2 accuracy 0.810275
# Finish 3 testing epoch, Acc: 0.809223
# Finish 3 risk difference 0.207441
# **********
# epoch 4
# tensor(0.6651, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.812933
# Party 1 accuracy 0.814933
# Party 1 risk difference 0.206250
# Party 2 risk difference 0.198239
# global training risk dfference: 0.202252
# Finish 4 training epoch, Acc: 0.813933
# Finish party 1 test risk difference 0.198856
# Party 1 accuracy 0.809092
# Finish party 2 test risk difference 0.215868
# Party 2 accuracy 0.810669
# Finish 4 testing epoch, Acc: 0.809880
# Finish 4 risk difference 0.207372
# **********
# epoch 5
# tensor(0.6651, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.813133
# Party 1 accuracy 0.814800
# Party 1 risk difference 0.205756
# Party 2 risk difference 0.198365
# global training risk dfference: 0.202067
# Finish 5 training epoch, Acc: 0.813967
# Finish party 1 test risk difference 0.199672
# Party 1 accuracy 0.809880
# Finish party 2 test risk difference 0.217290
# Party 2 accuracy 0.810537
# Finish 5 testing epoch, Acc: 0.810209
# Finish 5 risk difference 0.208492
# **********
# epoch 6
# tensor(0.6650, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.813533
# Party 1 accuracy 0.814533
# Party 1 risk difference 0.205879
# Party 2 risk difference 0.198508
# global training risk dfference: 0.202200
# Finish 6 training epoch, Acc: 0.814033
# Finish party 1 test risk difference 0.200675
# Party 1 accuracy 0.810669
# Finish party 2 test risk difference 0.217515
# Party 2 accuracy 0.810932
# Finish 6 testing epoch, Acc: 0.810800
# Finish 6 risk difference 0.209106
# **********
# epoch 7
# tensor(0.6650, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.813867
# Party 1 accuracy 0.814600
# Party 1 risk difference 0.206208
# Party 2 risk difference 0.199037
# global training risk dfference: 0.202629
# Finish 7 training epoch, Acc: 0.814233
# Finish party 1 test risk difference 0.200692
# Party 1 accuracy 0.810669
# Finish party 2 test risk difference 0.218952
# Party 2 accuracy 0.811194
# Finish 7 testing epoch, Acc: 0.810932
# Finish 7 risk difference 0.209830
# **********
# epoch 8
# tensor(0.6649, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.814467
# Party 1 accuracy 0.814867
# Party 1 risk difference 0.206339
# Party 2 risk difference 0.198750
# global training risk dfference: 0.202551
# Finish 8 training epoch, Acc: 0.814667
# Finish party 1 test risk difference 0.200700
# Party 1 accuracy 0.810800
# Finish party 2 test risk difference 0.218158
# Party 2 accuracy 0.811326
# Finish 8 testing epoch, Acc: 0.811063
# Finish 8 risk difference 0.209440
# **********
# epoch 9
# tensor(0.6648, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.814733
# Party 1 accuracy 0.815200
# Party 1 risk difference 0.206264
# Party 2 risk difference 0.198777
# global training risk dfference: 0.202528
# Finish 9 training epoch, Acc: 0.814967
# Finish party 1 test risk difference 0.201907
# Party 1 accuracy 0.811326
# Finish party 2 test risk difference 0.217964
# Party 2 accuracy 0.811194
# Finish 9 testing epoch, Acc: 0.811260
# Finish 9 risk difference 0.209951
# **********
# epoch 10
# tensor(0.6648, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.815333
# Party 1 accuracy 0.816067
# Party 1 risk difference 0.206288
# Party 2 risk difference 0.198912
# global training risk dfference: 0.202607
# Finish 10 training epoch, Acc: 0.815700
# Finish party 1 test risk difference 0.201923
# Party 1 accuracy 0.811851
# Finish party 2 test risk difference 0.218383
# Party 2 accuracy 0.811194
# Finish 10 testing epoch, Acc: 0.811523
# Finish 10 risk difference 0.210169
# **********
# epoch 1
# tensor(0.6647, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.815733
# Party 1 accuracy 0.816267
# Party 1 risk difference 0.206625
# Party 2 risk difference 0.199656
# global training risk dfference: 0.203147
# Finish 1 training epoch, Acc: 0.816000
# Finish party 1 test risk difference 0.201141
# Party 1 accuracy 0.812377
# Finish party 2 test risk difference 0.218188
# Party 2 accuracy 0.811326
# Finish 1 testing epoch, Acc: 0.811851
# Finish 1 risk difference 0.209681
# **********
# epoch 2
# tensor(0.6647, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.816000
# Party 1 accuracy 0.816667
# Party 1 risk difference 0.206641
# Party 2 risk difference 0.200194
# global training risk dfference: 0.203424
# Finish 2 training epoch, Acc: 0.816333
# Finish party 1 test risk difference 0.200570
# Party 1 accuracy 0.812245
# Finish party 2 test risk difference 0.218996
# Party 2 accuracy 0.811588
# Finish 2 testing epoch, Acc: 0.811917
# Finish 2 risk difference 0.209802
# **********
# epoch 3
# ...
# **********
# epoch 7
# tensor(0.6629, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.822600
# Party 1 accuracy 0.826667
# Party 1 risk difference 0.202000
# Party 2 risk difference 0.200056
# global training risk dfference: 0.201034
# Finish 7 training epoch, Acc: 0.824633
# Finish party 1 test risk difference 0.198754
# Party 1 accuracy 0.824070
# Finish party 2 test risk difference 0.204933
# Party 2 accuracy 0.824859
# Finish 7 testing epoch, Acc: 0.824465
# Finish 7 risk difference 0.201875
# **********
# epoch 8
# tensor(0.6629, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.822600
# Party 1 accuracy 0.826733
# Party 1 risk difference 0.202106
# Party 2 risk difference 0.199957
# global training risk dfference: 0.201038
# Finish 8 training epoch, Acc: 0.824667
# Finish party 1 test risk difference 0.198558
# Party 1 accuracy 0.824202
# Finish party 2 test risk difference 0.204933
# Party 2 accuracy 0.824859
# Finish 8 testing epoch, Acc: 0.824530
# Finish 8 risk difference 0.201777
# **********
# epoch 9
# tensor(0.6629, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.822667
# Party 1 accuracy 0.826800
# Party 1 risk difference 0.202115
# Party 2 risk difference 0.199662
# global training risk dfference: 0.200894
# Finish 9 training epoch, Acc: 0.824733
# Finish party 1 test risk difference 0.197971
# Party 1 accuracy 0.823808
# Finish party 2 test risk difference 0.204738
# Party 2 accuracy 0.824990
# Finish 9 testing epoch, Acc: 0.824399
# Finish 9 risk difference 0.201387
# **********
# epoch 10
# tensor(0.6629, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.822667
# Party 1 accuracy 0.827000
# Party 1 risk difference 0.202024
# Party 2 risk difference 0.199366
# global training risk dfference: 0.200701
# Finish 10 training epoch, Acc: 0.824833
# Finish party 1 test risk difference 0.197383
# Party 1 accuracy 0.823939
# Finish party 2 test risk difference 0.203960
# Party 2 accuracy 0.824990
# Finish 10 testing epoch, Acc: 0.824465
# Finish 10 risk difference 0.200703
# **********
# epoch 1
# tensor(0.6629, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.822733
# Party 1 accuracy 0.826933
# Party 1 risk difference 0.201621
# Party 2 risk difference 0.199268
# global training risk dfference: 0.200450
# Finish 1 training epoch, Acc: 0.824833
# Finish party 1 test risk difference 0.197979
# Party 1 accuracy 0.824202
# Finish party 2 test risk difference 0.203960
# Party 2 accuracy 0.824990
# Finish 1 testing epoch, Acc: 0.824596
# Finish 1 risk difference 0.201002
# **********
# epoch 2
# tensor(0.6629, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.822733
# Party 1 accuracy 0.826867
# Party 1 risk difference 0.201728
# Party 2 risk difference 0.199061
# global training risk dfference: 0.200401
# Finish 2 training epoch, Acc: 0.824800
# Finish party 1 test risk difference 0.197587
# Party 1 accuracy 0.824465
# Finish party 2 test risk difference 0.203960
# Party 2 accuracy 0.824990
# Finish 2 testing epoch, Acc: 0.824727
# Finish 2 risk difference 0.200807
# **********
# epoch 3
# tensor(0.6629, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.822733
# Party 1 accuracy 0.827067
# Party 1 risk difference 0.201531
# Party 2 risk difference 0.198981
# global training risk dfference: 0.200262
# Finish 3 training epoch, Acc: 0.824900
# Finish party 1 test risk difference 0.197392
# Party 1 accuracy 0.824596
# Finish party 2 test risk difference 0.203765
# Party 2 accuracy 0.824859
# Finish 3 testing epoch, Acc: 0.824727
# Finish 3 risk difference 0.200612
# **********
# epoch 4
# tensor(0.6629, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.823200
# Party 1 accuracy 0.826933
# Party 1 risk difference 0.201341
# Party 2 risk difference 0.198390
# global training risk dfference: 0.199872
# Finish 4 training epoch, Acc: 0.825067
# Finish party 1 test risk difference 0.197204
# Party 1 accuracy 0.824859
# Finish party 2 test risk difference 0.203765
# Party 2 accuracy 0.824859
# Finish 4 testing epoch, Acc: 0.824859
# Finish 4 risk difference 0.200520
# **********
# epoch 5
# tensor(0.6629, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.823267
# Party 1 accuracy 0.826933
# Party 1 risk difference 0.201045
# Party 2 risk difference 0.198193
# global training risk dfference: 0.199625
# Finish 5 training epoch, Acc: 0.825100
# Finish party 1 test risk difference 0.197204
# Party 1 accuracy 0.824859
# Finish party 2 test risk difference 0.203780
# Party 2 accuracy 0.824465
# Finish 5 testing epoch, Acc: 0.824662
# Finish 5 risk difference 0.200526
# **********
# epoch 6
# tensor(0.6628, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.823267
# Party 1 accuracy 0.827067
# Party 1 risk difference 0.201152
# Party 2 risk difference 0.198193
# global training risk dfference: 0.199679
# Finish 6 training epoch, Acc: 0.825167
# Finish party 1 test risk difference 0.197204
# Party 1 accuracy 0.824859
# Finish party 2 test risk difference 0.204184
# Party 2 accuracy 0.824333
# Finish 6 testing epoch, Acc: 0.824596
# Finish 6 risk difference 0.200727
# **********
# epoch 7
# tensor(0.6628, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.823000
# Party 1 accuracy 0.826867
# Party 1 risk difference 0.200757
# Party 2 risk difference 0.197897
# global training risk dfference: 0.199333
# Finish 7 training epoch, Acc: 0.824933
# Finish party 1 test risk difference 0.197204
# Party 1 accuracy 0.824859
# Finish party 2 test risk difference 0.204184
# Party 2 accuracy 0.824333
# Finish 7 testing epoch, Acc: 0.824596
# Finish 7 risk difference 0.200727
# **********
# epoch 8
# tensor(0.6628, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.823067
# Party 1 accuracy 0.827067
# Party 1 risk difference 0.200461
# Party 2 risk difference 0.197297
# global training risk dfference: 0.198885
# Finish 8 training epoch, Acc: 0.825067
# Finish party 1 test risk difference 0.197008
# Party 1 accuracy 0.824990
# Finish party 2 test risk difference 0.203406
# Party 2 accuracy 0.824596
# Finish 8 testing epoch, Acc: 0.824793
# Finish 8 risk difference 0.200239
# **********
# epoch 9
# tensor(0.6628, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.823200
# Party 1 accuracy 0.826867
# Party 1 risk difference 0.200066
# Party 2 risk difference 0.196786
# global training risk dfference: 0.198433
# Finish 9 training epoch, Acc: 0.825033
# Finish party 1 test risk difference 0.196813
# Party 1 accuracy 0.825122
# Finish party 2 test risk difference 0.203810
# Party 2 accuracy 0.824727
# Finish 9 testing epoch, Acc: 0.824924
# Finish 9 risk difference 0.200342
# **********
# epoch 10
# tensor(0.6628, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.823200
# Party 1 accuracy 0.826800
# Party 1 risk difference 0.199869
# Party 2 risk difference 0.196490
# global training risk dfference: 0.198187
# Finish 10 training epoch, Acc: 0.825000
# Finish party 1 test risk difference 0.197017
# Party 1 accuracy 0.825122
# Finish party 2 test risk difference 0.203810
# Party 2 accuracy 0.824727
# Finish 10 testing epoch, Acc: 0.824924
# Finish 10 risk difference 0.200445
# **********
# epoch 1
# tensor(0.6628, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.823067
# Party 1 accuracy 0.826867
# Party 1 risk difference 0.199672
# Party 2 risk difference 0.196195
# global training risk dfference: 0.197940
# Finish 1 training epoch, Acc: 0.824967
# Finish party 1 test risk difference 0.196429
# Party 1 accuracy 0.825253
# Finish party 2 test risk difference 0.203810
# Party 2 accuracy 0.824727
# Finish 1 testing epoch, Acc: 0.824990
# Finish 1 risk difference 0.200152
# **********
# epoch 2
# tensor(0.6628, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.823400
# Party 1 accuracy 0.826733
# Party 1 risk difference 0.199680
# Party 2 risk difference 0.195998
# global training risk dfference: 0.197846
# Finish 2 training epoch, Acc: 0.825067
# Finish party 1 test risk difference 0.196242
# Party 1 accuracy 0.825778
# Finish party 2 test risk difference 0.203420
# Party 2 accuracy 0.824990
# Finish 2 testing epoch, Acc: 0.825384
# Finish 2 risk difference 0.199865
# **********
# epoch 3
# tensor(0.6628, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.823267
# Party 1 accuracy 0.827067
# Party 1 risk difference 0.199376
# Party 2 risk difference 0.195702
# global training risk dfference: 0.197546
# Finish 3 training epoch, Acc: 0.825167
# Finish party 1 test risk difference 0.196242
# Party 1 accuracy 0.825778
# Finish party 2 test risk difference 0.202836
# Party 2 accuracy 0.825122
# Finish 3 testing epoch, Acc: 0.825450
# Finish 3 risk difference 0.199573
# **********
# epoch 4
# tensor(0.6628, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.823400
# Party 1 accuracy 0.827067
# Party 1 risk difference 0.199376
# Party 2 risk difference 0.195505
# global training risk dfference: 0.197447
# Finish 4 training epoch, Acc: 0.825233
# Finish party 1 test risk difference 0.195646
# Party 1 accuracy 0.825778
# Finish party 2 test risk difference 0.203241
# Party 2 accuracy 0.824990
# Finish 4 testing epoch, Acc: 0.825384
# Finish 4 risk difference 0.199475
# **********
# epoch 5
# tensor(0.6627, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.823333
# Party 1 accuracy 0.827133
# Party 1 risk difference 0.199277
# Party 2 risk difference 0.195317
# global training risk dfference: 0.197303
# Finish 5 training epoch, Acc: 0.825233
# Finish party 1 test risk difference 0.194847
# Party 1 accuracy 0.826041
# Finish party 2 test risk difference 0.203241
# Party 2 accuracy 0.824990
# Finish 5 testing epoch, Acc: 0.825516
# Finish 5 risk difference 0.199073
# **********
# epoch 6
# tensor(0.6627, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.823467
# Party 1 accuracy 0.827200
# Party 1 risk difference 0.198973
# Party 2 risk difference 0.195111
# global training risk dfference: 0.197048
# Finish 6 training epoch, Acc: 0.825333
# Finish party 1 test risk difference 0.195247
# Party 1 accuracy 0.826173
# Finish party 2 test risk difference 0.203256
# Party 2 accuracy 0.825647
# Finish 6 testing epoch, Acc: 0.825910
# Finish 6 risk difference 0.199280
# **********
# epoch 7
# tensor(0.6627, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.823733
# Party 1 accuracy 0.827133
# Party 1 risk difference 0.197879
# Party 2 risk difference 0.194815
# global training risk dfference: 0.196354
# Finish 7 training epoch, Acc: 0.825433
# Finish party 1 test risk difference 0.194651
# Party 1 accuracy 0.826173
# Finish party 2 test risk difference 0.202866
# Party 2 accuracy 0.825647
# Finish 7 testing epoch, Acc: 0.825910
# Finish 7 risk difference 0.198786
# **********
# epoch 8
# tensor(0.6627, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.823800
# Party 1 accuracy 0.827200
# Party 1 risk difference 0.197492
# Party 2 risk difference 0.194520
# global training risk dfference: 0.196013
# Finish 8 training epoch, Acc: 0.825500
# Finish party 1 test risk difference 0.194252
# Party 1 accuracy 0.826304
# Finish party 2 test risk difference 0.203270
# Party 2 accuracy 0.825778
# Finish 8 testing epoch, Acc: 0.826041
# Finish 8 risk difference 0.198786
# **********
# epoch 9
# tensor(0.6627, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.823733
# Party 1 accuracy 0.827267
# Party 1 risk difference 0.196983
# Party 2 risk difference 0.194116
# global training risk dfference: 0.195556
# Finish 9 training epoch, Acc: 0.825500
# Finish party 1 test risk difference 0.194456
# Party 1 accuracy 0.826567
# Finish party 2 test risk difference 0.203270
# Party 2 accuracy 0.825778
# Finish 9 testing epoch, Acc: 0.826173
# Finish 9 risk difference 0.198889
# **********
# epoch 10
# tensor(0.6627, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.823867
# Party 1 accuracy 0.827467
# Party 1 risk difference 0.196284
# Party 2 risk difference 0.193821
# global training risk dfference: 0.195059
# Finish 10 training epoch, Acc: 0.825667
# Finish party 1 test risk difference 0.194064
# Party 1 accuracy 0.826830
# Finish party 2 test risk difference 0.203076
# Party 2 accuracy 0.825910
# Finish 10 testing epoch, Acc: 0.826370
# Finish 10 risk difference 0.198597
# **********
# epoch 1
# tensor(0.6627, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.824000
# Party 1 accuracy 0.827600
# Party 1 risk difference 0.195889
# Party 2 risk difference 0.194036
# global training risk dfference: 0.194969
# Finish 1 training epoch, Acc: 0.825800
# Finish party 1 test risk difference 0.194064
# Party 1 accuracy 0.826830
# Finish party 2 test risk difference 0.203076
# Party 2 accuracy 0.825910
# Finish 1 testing epoch, Acc: 0.826370
# Finish 1 risk difference 0.198597
# **********
# epoch 2
# tensor(0.6627, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.824067
# Party 1 accuracy 0.827867
# Party 1 risk difference 0.195486
# Party 2 risk difference 0.193839
# global training risk dfference: 0.194669
# Finish 2 training epoch, Acc: 0.825967
# Finish party 1 test risk difference 0.194260
# Party 1 accuracy 0.826961
# Finish party 2 test risk difference 0.203076
# Party 2 accuracy 0.825910
# Finish 2 testing epoch, Acc: 0.826435
# Finish 2 risk difference 0.198694
# **********
# epoch 3
# tensor(0.6627, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.824000
# Party 1 accuracy 0.827733
# Party 1 risk difference 0.195190
# Party 2 risk difference 0.193445
# global training risk dfference: 0.194323
# Finish 3 training epoch, Acc: 0.825867
# Finish party 1 test risk difference 0.194064
# Party 1 accuracy 0.826830
# Finish party 2 test risk difference 0.202492
# Party 2 accuracy 0.826041
# Finish 3 testing epoch, Acc: 0.826435
# Finish 3 risk difference 0.198304
# **********
# epoch 4
# tensor(0.6627, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.824200
# Party 1 accuracy 0.827867
# Party 1 risk difference 0.194376
# Party 2 risk difference 0.192943
# global training risk dfference: 0.193665
# Finish 4 training epoch, Acc: 0.826033
# Finish party 1 test risk difference 0.194668
# Party 1 accuracy 0.826698
# Finish party 2 test risk difference 0.202297
# Party 2 accuracy 0.825910
# Finish 4 testing epoch, Acc: 0.826304
# Finish 4 risk difference 0.198511
# **********
# epoch 5
# tensor(0.6627, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.824200
# Party 1 accuracy 0.827733
# Party 1 risk difference 0.193875
# Party 2 risk difference 0.193050
# global training risk dfference: 0.193468
# Finish 5 training epoch, Acc: 0.825967
# Finish party 1 test risk difference 0.194472
# Party 1 accuracy 0.826830
# Finish party 2 test risk difference 0.202297
# Party 2 accuracy 0.825910
# Finish 5 testing epoch, Acc: 0.826370
# Finish 5 risk difference 0.198413
# **********
# epoch 6
# tensor(0.6626, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.824400
# Party 1 accuracy 0.827533
# Party 1 risk difference 0.193275
# Party 2 risk difference 0.192755
# global training risk dfference: 0.193020
# Finish 6 training epoch, Acc: 0.825967
# Finish party 1 test risk difference 0.194081
# Party 1 accuracy 0.826567
# Finish party 2 test risk difference 0.202297
# Party 2 accuracy 0.825910
# Finish 6 testing epoch, Acc: 0.826238
# Finish 6 risk difference 0.198218
# **********
# epoch 7
# tensor(0.6626, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.824667
# Party 1 accuracy 0.827333
# Party 1 risk difference 0.192987
# Party 2 risk difference 0.192656
# global training risk dfference: 0.192827
# Finish 7 training epoch, Acc: 0.826000
# Finish party 1 test risk difference 0.193689
# Party 1 accuracy 0.826567
# Finish party 2 test risk difference 0.202102
# Party 2 accuracy 0.826041
# Finish 7 testing epoch, Acc: 0.826304
# Finish 7 risk difference 0.197925
# **********
# epoch 8
# tensor(0.6626, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.824667
# Party 1 accuracy 0.827267
# Party 1 risk difference 0.193398
# Party 2 risk difference 0.192361
# global training risk dfference: 0.192885
# Finish 8 training epoch, Acc: 0.825967
# Finish party 1 test risk difference 0.193298
# Party 1 accuracy 0.826567
# Finish party 2 test risk difference 0.201114
# Party 2 accuracy 0.826304
# Finish 8 testing epoch, Acc: 0.826435
# Finish 8 risk difference 0.197236
# **********
# epoch 9
# tensor(0.6626, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.824533
# Party 1 accuracy 0.827533
# Party 1 risk difference 0.193200
# Party 2 risk difference 0.191662
# global training risk dfference: 0.192437
# Finish 9 training epoch, Acc: 0.826033
# Finish party 1 test risk difference 0.193697
# Party 1 accuracy 0.826698
# Finish party 2 test risk difference 0.201114
# Party 2 accuracy 0.826304
# Finish 9 testing epoch, Acc: 0.826501
# Finish 9 risk difference 0.197437
# **********
# epoch 10
# tensor(0.6626, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.824600
# Party 1 accuracy 0.827667
# Party 1 risk difference 0.193406
# Party 2 risk difference 0.191769
# global training risk dfference: 0.192593
# Finish 10 training epoch, Acc: 0.826133
# Finish party 1 test risk difference 0.194097
# Party 1 accuracy 0.826830
# Finish party 2 test risk difference 0.200530
# Party 2 accuracy 0.826435
# Finish 10 testing epoch, Acc: 0.826633
# Finish 10 risk difference 0.197345

# %%
# agnostic fair
for i in range(Iteration):
    # compute with the option "with fair" => Zafar et al.
    theta, bias = compute_model_parameter_fairness(weight, Sen_torch, ratio_fair, options[2], k)
# Out:
# **********
# epoch 1
# tensor(0.6478, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.824733
# Party 1 accuracy 0.827533
# Party 1 risk difference 0.193513
# Party 2 risk difference 0.191465
# global training risk dfference: 0.192495
# Finish 1 training epoch, Acc: 0.826133
# Finish party 1 test risk difference 0.165486
# Party 1 accuracy 0.829457
# Finish party 2 test risk difference 0.173220
# Party 2 accuracy 0.829457
# Finish 1 testing epoch, Acc: 0.829457
# Finish 1 risk difference 0.169386
# **********
# epoch 2
# tensor(0.6437, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.829667
# Party 1 accuracy 0.831467
# Party 1 risk difference 0.165084
# Party 2 risk difference 0.164379
# global training risk dfference: 0.164738
# Finish 2 training epoch, Acc: 0.830567
# Finish party 1 test risk difference 0.148736
# Party 1 accuracy 0.826961
# Finish party 2 test risk difference 0.151534
# Party 2 accuracy 0.826041
# Finish 2 testing epoch, Acc: 0.826501
# Finish 2 risk difference 0.150161
# **********
# epoch 3
# tensor(0.6425, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.825467
# Party 1 accuracy 0.825600
# Party 1 risk difference 0.146843
# Party 2 risk difference 0.145249
# global training risk dfference: 0.146049
# Finish 3 training epoch, Acc: 0.825533
# Finish party 1 test risk difference 0.140002
# Party 1 accuracy 0.822494
# Finish party 2 test risk difference 0.143611
# Party 2 accuracy 0.820917
# Finish 3 testing epoch, Acc: 0.821705
# Finish 3 risk difference 0.141820
# **********
# epoch 4
# tensor(0.6420, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.822467
# Party 1 accuracy 0.820667
# Party 1 risk difference 0.139801
# Party 2 risk difference 0.138819
# global training risk dfference: 0.139311
# Finish 4 training epoch, Acc: 0.821567
# Finish party 1 test risk difference 0.135117
# Party 1 accuracy 0.821443
# Finish party 2 test risk difference 0.138744
# Party 2 accuracy 0.821311
# Finish 4 testing epoch, Acc: 0.821377
# Finish 4 risk difference 0.136945
# **********
# epoch 5
# tensor(0.6418, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.822267
# Party 1 accuracy 0.819600
# Party 1 risk difference 0.137276
# Party 2 risk difference 0.136257
# global training risk dfference: 0.136766
# Finish 5 training epoch, Acc: 0.820933
# Finish party 1 test risk difference 0.135509
# Party 1 accuracy 0.821180
# Finish party 2 test risk difference 0.139538
# Party 2 accuracy 0.821443
# Finish 5 testing epoch, Acc: 0.821311
# Finish 5 risk difference 0.137537
# **********
# epoch 6
# tensor(0.6416, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.822333
# Party 1 accuracy 0.820133
# Party 1 risk difference 0.136051
# Party 2 risk difference 0.134985
# global training risk dfference: 0.135519
# Finish 6 training epoch, Acc: 0.821233
# Finish party 1 test risk difference 0.137841
# Party 1 accuracy 0.822231
# Finish party 2 test risk difference 0.142039
# Party 2 accuracy 0.821837
# Finish 6 testing epoch, Acc: 0.822034
# Finish 6 risk difference 0.139954
# **********
# epoch 7
# tensor(0.6415, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.823133
# Party 1 accuracy 0.820800
# Party 1 risk difference 0.137080
# Party 2 risk difference 0.135217
# global training risk dfference: 0.136149
# Finish 7 training epoch, Acc: 0.821967
# Finish party 1 test risk difference 0.139358
# Party 1 accuracy 0.823808
# Finish party 2 test risk difference 0.144525
# Party 2 accuracy 0.822625
# Finish 7 testing epoch, Acc: 0.823216
# Finish 7 risk difference 0.141951
# **********
# epoch 8
# tensor(0.6414, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.824200
# Party 1 accuracy 0.822800
# Party 1 risk difference 0.138701
# Party 2 risk difference 0.136811
# global training risk dfference: 0.137757
# Finish 8 training epoch, Acc: 0.823500
# Finish party 1 test risk difference 0.142269
# Party 1 accuracy 0.824859
# Finish party 2 test risk difference 0.144825
# Party 2 accuracy 0.823676
# Finish 8 testing epoch, Acc: 0.824268
# Finish 8 risk difference 0.143559
# **********
# epoch 9
# tensor(0.6412, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.824600
# Party 1 accuracy 0.823400
# Party 1 risk difference 0.140018
# Party 2 risk difference 0.138898
# global training risk dfference: 0.139459
# Finish 9 training epoch, Acc: 0.824000
# Finish party 1 test risk difference 0.143606
# Party 1 accuracy 0.825516
# Finish party 2 test risk difference 0.147476
# Party 2 accuracy 0.825384
# Finish 9 testing epoch, Acc: 0.825450
# Finish 9 risk difference 0.145556
# **********
# epoch 10
# tensor(0.6411, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.825133
# Party 1 accuracy 0.823733
# Party 1 risk difference 0.140726
# Party 2 risk difference 0.140286
# global training risk dfference: 0.140508
# Finish 10 training epoch, Acc: 0.824433
# Finish party 1 test risk difference 0.144356
# Party 1 accuracy 0.826830
# Finish party 2 test risk difference 0.150156
# Party 2 accuracy 0.826041
# Finish 10 testing epoch, Acc: 0.826435
# Finish 10 risk difference 0.147273
# **********
# epoch 1
# tensor(0.6410, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.825800
# Party 1 accuracy 0.824467
# Party 1 risk difference 0.143046
# Party 2 risk difference 0.143071
# global training risk dfference: 0.143061
# Finish 1 training epoch, Acc: 0.825133
# Finish party 1 test risk difference 0.145302
# Party 1 accuracy 0.828012
# Finish party 2 test risk difference 0.151819
# Party 2 accuracy 0.827224
# Finish 1 testing epoch, Acc: 0.827618
# Finish 1 risk difference 0.148581
# **********
# epoch 2
# tensor(0.6409, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.826533
# Party 1 accuracy 0.824267
# Party 1 risk difference 0.143459
# Party 2 risk difference 0.145051
# global training risk dfference: 0.144258
# Finish 2 training epoch, Acc: 0.825400
# Finish party 1 test risk difference 0.147431
# Party 1 accuracy 0.828275
# Finish party 2 test risk difference 0.152479
# Party 2 accuracy 0.827487
# Finish 2 testing epoch, Acc: 0.827881
# Finish 2 risk difference 0.149982
# **********
# epoch 3
# tensor(0.6408, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.827467
# Party 1 accuracy 0.824800
# Party 1 risk difference 0.144685
# Party 2 risk difference 0.145336
# global training risk dfference: 0.145015
# Finish 3 training epoch, Acc: 0.826133
# Finish party 1 test risk difference 0.148564
# Party 1 accuracy 0.828932
# Finish party 2 test risk difference 0.154351
# Party 2 accuracy 0.828406
# Finish 3 testing epoch, Acc: 0.828669
# Finish 3 risk difference 0.151486
# **********
# epoch 4
# tensor(0.6408, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828400
# Party 1 accuracy 0.826067
# Party 1 risk difference 0.146717
# Party 2 risk difference 0.147244
# global training risk dfference: 0.146985
# Finish 4 training epoch, Acc: 0.827233
# Finish party 1 test risk difference 0.148099
# Party 1 accuracy 0.829589
# Finish party 2 test risk difference 0.157646
# Party 2 accuracy 0.828669
# Finish 4 testing epoch, Acc: 0.829129
# Finish 4 risk difference 0.152892
# **********
# epoch 5
# tensor(0.6407, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.829200
# Party 1 accuracy 0.825667
# Party 1 risk difference 0.147714
# Party 2 risk difference 0.148749
# global training risk dfference: 0.148235
# Finish 5 training epoch, Acc: 0.827433
# Finish party 1 test risk difference 0.150219
# Party 1 accuracy 0.828932
# Finish party 2 test risk difference 0.161150
# Party 2 accuracy 0.828669
# Finish 5 testing epoch, Acc: 0.828800
# Finish 5 risk difference 0.155699
# **********
# epoch 6
# tensor(0.6406, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.830333
# Party 1 accuracy 0.826933
# Party 1 risk difference 0.149327
# Party 2 risk difference 0.150477
# global training risk dfference: 0.149905
# Finish 6 training epoch, Acc: 0.828633
# Finish party 1 test risk difference 0.151548
# Party 1 accuracy 0.828406
# Finish party 2 test risk difference 0.161839
# Party 2 accuracy 0.829720
# Finish 6 testing epoch, Acc: 0.829063
# Finish 6 risk difference 0.156710
# **********
# epoch 7
# tensor(0.6406, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.830600
# Party 1 accuracy 0.827133
# Party 1 risk difference 0.150372
# Party 2 risk difference 0.150790
# global training risk dfference: 0.150585
# Finish 7 training epoch, Acc: 0.828867
# Finish party 1 test risk difference 0.154867
# Party 1 accuracy 0.828932
# Finish party 2 test risk difference 0.163561
# Party 2 accuracy 0.830377
# Finish 7 testing epoch, Acc: 0.829654
# Finish 7 risk difference 0.159230
# **********
# epoch 8
# tensor(0.6405, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.831133
# Party 1 accuracy 0.827733
# Party 1 risk difference 0.151705
# Party 2 risk difference 0.151032
# global training risk dfference: 0.151372
# Finish 8 training epoch, Acc: 0.829433
# Finish party 1 test risk difference 0.154834
# Party 1 accuracy 0.828932
# Finish party 2 test risk difference 0.164295
# Party 2 accuracy 0.830771
# Finish 8 testing epoch, Acc: 0.829852
# Finish 8 risk difference 0.159580
# **********
# epoch 9
# tensor(0.6404, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.831333
# Party 1 accuracy 0.828067
# Party 1 risk difference 0.153852
# Party 2 risk difference 0.152582
# global training risk dfference: 0.153220
# Finish 9 training epoch, Acc: 0.829700
# Finish party 1 test risk difference 0.156009
# Party 1 accuracy 0.829195
# Finish party 2 test risk difference 0.164251
# Party 2 accuracy 0.830377
# Finish 9 testing epoch, Acc: 0.829786
# Finish 9 risk difference 0.160148
# **********
# epoch 10
# tensor(0.6404, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.831667
# Party 1 accuracy 0.828333
# Party 1 risk difference 0.153688
# Party 2 risk difference 0.155287
# global training risk dfference: 0.154491
# Finish 10 training epoch, Acc: 0.830000
# Finish party 1 test risk difference 0.156775
# Party 1 accuracy 0.829457
# Finish party 2 test risk difference 0.164746
# Party 2 accuracy 0.830246
# Finish 10 testing epoch, Acc: 0.829852
# Finish 10 risk difference 0.160785
# **********
# epoch 1
# tensor(0.6403, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.831733
# Party 1 accuracy 0.828667
# Party 1 risk difference 0.154865
# Party 2 risk difference 0.156836
# global training risk dfference: 0.155855
# Finish 1 training epoch, Acc: 0.830200
# Finish party 1 test risk difference 0.157933
# Party 1 accuracy 0.831034
# Finish party 2 test risk difference 0.165689
# Party 2 accuracy 0.830114
# Finish 1 testing epoch, Acc: 0.830574
# Finish 1 risk difference 0.161836
# **********
# epoch 2
# tensor(0.6403, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.832267
# Party 1 accuracy 0.828333
# Party 1 risk difference 0.156987
# Party 2 risk difference 0.158063
# global training risk dfference: 0.157529
# Finish 2 training epoch, Acc: 0.830300
# Finish party 1 test risk difference 0.160078
# Party 1 accuracy 0.831560
# Finish party 2 test risk difference 0.165809
# Party 2 accuracy 0.829589
# Finish 2 testing epoch, Acc: 0.830574
# Finish 2 risk difference 0.162972
# **********
# epoch 3
# tensor(0.6402, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.832467
# Party 1 accuracy 0.828533
# Party 1 risk difference 0.157736
# Party 2 risk difference 0.159237
# global training risk dfference: 0.158490
# Finish 3 training epoch, Acc: 0.830500
# Finish party 1 test risk difference 0.161228
# Party 1 accuracy 0.831954
# Finish party 2 test risk difference 0.166169
# Party 2 accuracy 0.829852
# Finish 3 testing epoch, Acc: 0.830903
# Finish 3 risk difference 0.163724
# **********
# epoch 4
# tensor(0.6402, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.831933
# Party 1 accuracy 0.829333
# Party 1 risk difference 0.159373
# Party 2 risk difference 0.160491
# global training risk dfference: 0.159935
# Finish 4 training epoch, Acc: 0.830633
# Finish party 1 test risk difference 0.162989
# Party 1 accuracy 0.831822
# Finish party 2 test risk difference 0.169044
# Party 2 accuracy 0.829589
# Finish 4 testing epoch, Acc: 0.830706
# Finish 4 risk difference 0.166049
# **********
# epoch 5
# tensor(0.6402, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.831800
# Party 1 accuracy 0.829467
# Party 1 risk difference 0.160541
# Party 2 risk difference 0.162228
# global training risk dfference: 0.161388
# Finish 5 training epoch, Acc: 0.830633
# Finish party 1 test risk difference 0.163943
# Party 1 accuracy 0.831560
# Finish party 2 test risk difference 0.168985
# Party 2 accuracy 0.830640
# Finish 5 testing epoch, Acc: 0.831100
# Finish 5 risk difference 0.166497
# **********
# epoch 6
# tensor(0.6401, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.832200
# Party 1 accuracy 0.829933
# Party 1 risk difference 0.161693
# Party 2 risk difference 0.164387
# global training risk dfference: 0.163043
# Finish 6 training epoch, Acc: 0.831067
# Finish party 1 test risk difference 0.163715
# Party 1 accuracy 0.832217
# Finish party 2 test risk difference 0.168746
# Party 2 accuracy 0.830640
# Finish 6 testing epoch, Acc: 0.831428
# Finish 6 risk difference 0.166262
# **********
# epoch 7
# tensor(0.6401, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.832333
# Party 1 accuracy 0.830200
# Party 1 risk difference 0.163256
# Party 2 risk difference 0.165462
# global training risk dfference: 0.164362
# Finish 7 training epoch, Acc: 0.831267
# Finish party 1 test risk difference 0.163878
# Party 1 accuracy 0.832611
# Finish party 2 test risk difference 0.169300
# Party 2 accuracy 0.831034
# Finish 7 testing epoch, Acc: 0.831822
# Finish 7 risk difference 0.166617
# **********
# epoch 8
# tensor(0.6401, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.832333
# Party 1 accuracy 0.830400
# Party 1 risk difference 0.163528
# Party 2 risk difference 0.166313
# global training risk dfference: 0.164924
# Finish 8 training epoch, Acc: 0.831367
# Finish party 1 test risk difference 0.164049
# Party 1 accuracy 0.833136
# Finish party 2 test risk difference 0.170468
# Party 2 accuracy 0.830771
# Finish 8 testing epoch, Acc: 0.831954
# Finish 8 risk difference 0.167283
# **********
# epoch 9
# tensor(0.6400, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.832000
# Party 1 accuracy 0.830867
# Party 1 risk difference 0.165494
# Party 2 risk difference 0.165443
# global training risk dfference: 0.165472
# Finish 9 training epoch, Acc: 0.831433
# Finish party 1 test risk difference 0.165027
# Party 1 accuracy 0.833268
# Finish party 2 test risk difference 0.170633
# Party 2 accuracy 0.830640
# Finish 9 testing epoch, Acc: 0.831954
# Finish 9 risk difference 0.167857
# **********
# epoch 10
# tensor(0.6400, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.832000
# Party 1 accuracy 0.831000
# Party 1 risk difference 0.166160
# Party 2 risk difference 0.165909
# global training risk dfference: 0.166039
# Finish 10 training epoch, Acc: 0.831500
# Finish party 1 test risk difference 0.166593
# Party 1 accuracy 0.833268
# Finish party 2 test risk difference 0.169405
# Party 2 accuracy 0.831165
# Finish 10 testing epoch, Acc: 0.832217
# Finish 10 risk difference 0.168029
# **********
# epoch 1
# tensor(0.6400, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.831533
# Party 1 accuracy 0.831200
# Party 1 risk difference 0.166514
# Party 2 risk difference 0.166169
# global training risk dfference: 0.166345
# Finish 1 training epoch, Acc: 0.831367
# Finish party 1 test risk difference 0.166177
# Party 1 accuracy 0.833662
# Finish party 2 test risk difference 0.170768
# Party 2 accuracy 0.831297
# Finish 1 testing epoch, Acc: 0.832479
# Finish 1 risk difference 0.168500
# **********
# epoch 2
# tensor(0.6400, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.831133
# Party 1 accuracy 0.831400
# Party 1 risk difference 0.167288
# Party 2 risk difference 0.166625
# global training risk dfference: 0.166961
# Finish 2 training epoch, Acc: 0.831267
# Finish party 1 test risk difference 0.167743
# Party 1 accuracy 0.833136
# Finish party 2 test risk difference 0.169735
# Party 2 accuracy 0.831691
# Finish 2 testing epoch, Acc: 0.832414
# Finish 2 risk difference 0.168770
# **********
# epoch 3
# tensor(0.6399, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.830867
# Party 1 accuracy 0.831333
# Party 1 risk difference 0.168456
# Party 2 risk difference 0.168300
# global training risk dfference: 0.168382
# Finish 3 training epoch, Acc: 0.831100
# Finish party 1 test risk difference 0.168722
# Party 1 accuracy 0.833005
# Finish party 2 test risk difference 0.169496
# Party 2 accuracy 0.831691
# Finish 3 testing epoch, Acc: 0.832348
# Finish 3 risk difference 0.169143
# **********
# epoch 4
# tensor(0.6399, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.831000
# Party 1 accuracy 0.831800
# Party 1 risk difference 0.169517
# Party 2 risk difference 0.169474
# global training risk dfference: 0.169499
# Finish 4 training epoch, Acc: 0.831400
# Finish party 1 test risk difference 0.169496
# Party 1 accuracy 0.832873
# Finish party 2 test risk difference 0.169676
# Party 2 accuracy 0.832217
# Finish 4 testing epoch, Acc: 0.832545
# Finish 4 risk difference 0.169619
# **********
# epoch 5
# tensor(0.6399, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.831067
# Party 1 accuracy 0.832133
# Party 1 risk difference 0.169477
# Party 2 risk difference 0.170038
# global training risk dfference: 0.169760
# Finish 5 training epoch, Acc: 0.831600
# Finish party 1 test risk difference 0.170858
# Party 1 accuracy 0.832873
# Finish party 2 test risk difference 0.169646
# Party 2 accuracy 0.832742
# Finish 5 testing epoch, Acc: 0.832808
# Finish 5 risk difference 0.170285
# **********
# epoch 6
# tensor(0.6399, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.830933
# Party 1 accuracy 0.832133
# Party 1 risk difference 0.169732
# Party 2 risk difference 0.170790
# global training risk dfference: 0.170264
# Finish 6 training epoch, Acc: 0.831533
# Finish party 1 test risk difference 0.171445
# Party 1 accuracy 0.833268
# Finish party 2 test risk difference 0.170814
# Party 2 accuracy 0.832742
# Finish 6 testing epoch, Acc: 0.833005
# Finish 6 risk difference 0.171164
# **********
# epoch 7
# tensor(0.6398, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.831200
# Party 1 accuracy 0.832400
# Party 1 risk difference 0.169700
# Party 2 risk difference 0.171579
# global training risk dfference: 0.170642
# Finish 7 training epoch, Acc: 0.831800
# Finish party 1 test risk difference 0.171837
# Party 1 accuracy 0.833268
# Finish party 2 test risk difference 0.171009
# Party 2 accuracy 0.832873
# Finish 7 testing epoch, Acc: 0.833071
# Finish 7 risk difference 0.171456
# **********
# epoch 8
# tensor(0.6398, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.831333
# Party 1 accuracy 0.832333
# Party 1 risk difference 0.169363
# Party 2 risk difference 0.171856
# global training risk dfference: 0.170612
# Finish 8 training epoch, Acc: 0.831833
# Finish party 1 test risk difference 0.172416
# Party 1 accuracy 0.833005
# Finish party 2 test risk difference 0.170979
# Party 2 accuracy 0.832611
# Finish 8 testing epoch, Acc: 0.832808
# Finish 8 risk difference 0.171732
# **********
# epoch 9
# tensor(0.6398, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.831200
# Party 1 accuracy 0.832333
# Party 1 risk difference 0.170441
# Party 2 risk difference 0.172322
# global training risk dfference: 0.171384
# Finish 9 training epoch, Acc: 0.831767
# Finish party 1 test risk difference 0.173191
# Party 1 accuracy 0.832873
# Finish party 2 test risk difference 0.170964
# Party 2 accuracy 0.832742
# Finish 9 testing epoch, Acc: 0.832808
# Finish 9 risk difference 0.172111
# **********
# epoch 10
# tensor(0.6398, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.831067
# Party 1 accuracy 0.832067
# Party 1 risk difference 0.171230
# Party 2 risk difference 0.173003
# global training risk dfference: 0.172119
# Finish 10 training epoch, Acc: 0.831567
# Finish party 1 test risk difference 0.173574
# Party 1 accuracy 0.833268
# Finish party 2 test risk difference 0.170515
# Party 2 accuracy 0.832479
# Finish 10 testing epoch, Acc: 0.832873
# Finish 10 risk difference 0.172082
# **********
# epoch 1
# tensor(0.6398, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.831067
# Party 1 accuracy 0.832200
# Party 1 risk difference 0.172020
# Party 2 risk difference 0.173970
# global training risk dfference: 0.172998
# Finish 1 training epoch, Acc: 0.831633
# Finish party 1 test risk difference 0.174944
# Party 1 accuracy 0.833136
# Finish party 2 test risk difference 0.170875
# Party 2 accuracy 0.833268
# Finish 1 testing epoch, Acc: 0.833202
# Finish 1 risk difference 0.172949
# **********
# epoch 2
# tensor(0.6397, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.831200
# Party 1 accuracy 0.832267
# Party 1 risk difference 0.172201
# Party 2 risk difference 0.174140
# global training risk dfference: 0.173174
# Finish 2 training epoch, Acc: 0.831733
# Finish party 1 test risk difference 0.175123
# Party 1 accuracy 0.832479
# Finish party 2 test risk difference 0.171264
# Party 2 accuracy 0.833005
# Finish 2 testing epoch, Acc: 0.832742
# Finish 2 risk difference 0.173230
# **********
# epoch 3
# tensor(0.6397, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.831000
# Party 1 accuracy 0.832267
# Party 1 risk difference 0.172177
# Party 2 risk difference 0.174427
# global training risk dfference: 0.173305
# Finish 3 training epoch, Acc: 0.831633
# Finish party 1 test risk difference 0.174715
# Party 1 accuracy 0.832742
# Finish party 2 test risk difference 0.171653
# Party 2 accuracy 0.833005
# Finish 3 testing epoch, Acc: 0.832873
# Finish 3 risk difference 0.173219
# **********
# epoch 4
# tensor(0.6397, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.831067
# Party 1 accuracy 0.832333
# Party 1 risk difference 0.172670
# Party 2 risk difference 0.174812
# global training risk dfference: 0.173744
# Finish 4 training epoch, Acc: 0.831700
# Finish party 1 test risk difference 0.174511
# Party 1 accuracy 0.832742
# Finish party 2 test risk difference 0.172237
# Party 2 accuracy 0.833399
# Finish 4 testing epoch, Acc: 0.833071
# Finish 4 risk difference 0.173408
# **********
# epoch 5
# tensor(0.6397, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.831133
# Party 1 accuracy 0.832267
# Party 1 risk difference 0.173361
# Party 2 risk difference 0.174176
# global training risk dfference: 0.173772
# Finish 5 training epoch, Acc: 0.831700
# Finish party 1 test risk difference 0.174511
# Party 1 accuracy 0.832742
# Finish party 2 test risk difference 0.172821
# Party 2 accuracy 0.833530
# Finish 5 testing epoch, Acc: 0.833136
# Finish 5 risk difference 0.173701
# **********
# epoch 6
# tensor(0.6397, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.831267
# Party 1 accuracy 0.832267
# Party 1 risk difference 0.173148
# Party 2 risk difference 0.174355
# global training risk dfference: 0.173755
# Finish 6 training epoch, Acc: 0.831767
# Finish party 1 test risk difference 0.174104
# Party 1 accuracy 0.832479
# Finish party 2 test risk difference 0.172597
# Party 2 accuracy 0.833662
# Finish 6 testing epoch, Acc: 0.833071
# Finish 6 risk difference 0.173385
# **********
# epoch 7
# tensor(0.6397, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.831200
# Party 1 accuracy 0.831933
# Party 1 risk difference 0.173641
# Party 2 risk difference 0.174847
# global training risk dfference: 0.174248
# Finish 7 training epoch, Acc: 0.831567
# Finish party 1 test risk difference 0.174095
# Party 1 accuracy 0.832611
# Finish party 2 test risk difference 0.173376
# Party 2 accuracy 0.833925
# Finish 7 testing epoch, Acc: 0.833268
# Finish 7 risk difference 0.173770
# **********
# epoch 8
# tensor(0.6396, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.831133
# Party 1 accuracy 0.831800
# Party 1 risk difference 0.173115
# Party 2 risk difference 0.174829
# global training risk dfference: 0.173976
# Finish 8 training epoch, Acc: 0.831467
# Finish party 1 test risk difference 0.175457
# Party 1 accuracy 0.832348
# Finish party 2 test risk difference 0.173166
# Party 2 accuracy 0.833925
# Finish 8 testing epoch, Acc: 0.833136
# Finish 8 risk difference 0.174344
# **********
# epoch 9
# tensor(0.6396, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.831533
# Party 1 accuracy 0.832133
# Party 1 risk difference 0.174193
# Party 2 risk difference 0.175214
# global training risk dfference: 0.174707
# Finish 9 training epoch, Acc: 0.831833
# Finish party 1 test risk difference 0.175449
# Party 1 accuracy 0.832217
# Finish party 2 test risk difference 0.173555
# Party 2 accuracy 0.833925
# Finish 9 testing epoch, Acc: 0.833071
# Finish 9 risk difference 0.174533
# **********
# epoch 10
# tensor(0.6396, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.831400
# Party 1 accuracy 0.832200
# Party 1 risk difference 0.174283
# Party 2 risk difference 0.175600
# global training risk dfference: 0.174945
# Finish 10 training epoch, Acc: 0.831800
# Finish party 1 test risk difference 0.175628
# Party 1 accuracy 0.831560
# Finish party 2 test risk difference 0.174139
# Party 2 accuracy 0.834319
# Finish 10 testing epoch, Acc: 0.832939
# Finish 10 risk difference 0.174912
# **********
# epoch 1
# tensor(0.6396, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.831267
# Party 1 accuracy 0.832267
# Party 1 risk difference 0.174464
# Party 2 risk difference 0.176092
# global training risk dfference: 0.175281
# Finish 1 training epoch, Acc: 0.831767
# Finish party 1 test risk difference 0.175424
# Party 1 accuracy 0.831560
# Finish party 2 test risk difference 0.174723
# Party 2 accuracy 0.834187
# Finish 1 testing epoch, Acc: 0.832873
# Finish 1 risk difference 0.175101
# **********
# epoch 2
# tensor(0.6396, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.831200
# Party 1 accuracy 0.832333
# Party 1 risk difference 0.174045
# Party 2 risk difference 0.176083
# global training risk dfference: 0.175067
# Finish 2 training epoch, Acc: 0.831767
# Finish party 1 test risk difference 0.175416
# Party 1 accuracy 0.831428
# Finish party 2 test risk difference 0.174709
# Party 2 accuracy 0.834319
# Finish 2 testing epoch, Acc: 0.832873
# Finish 2 risk difference 0.175090
# **********
# epoch 3
# tensor(0.6396, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.831200
# Party 1 accuracy 0.832733
# Party 1 risk difference 0.174440
# Party 2 risk difference 0.176370
# global training risk dfference: 0.175408
# Finish 3 training epoch, Acc: 0.831967
# Finish party 1 test risk difference 0.176003
# Party 1 accuracy 0.831297
# Finish party 2 test risk difference 0.174888
# Party 2 accuracy 0.834319
# Finish 3 testing epoch, Acc: 0.832808
# Finish 3 risk difference 0.175474
# **********
# epoch 4
# tensor(0.6396, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.831333
# Party 1 accuracy 0.832867
# Party 1 risk difference 0.174728
# Party 2 risk difference 0.176854
# global training risk dfference: 0.175794
# Finish 4 training epoch, Acc: 0.832100
# Finish party 1 test risk difference 0.176591
# Party 1 accuracy 0.830903
# Finish party 2 test risk difference 0.175667
# Party 2 accuracy 0.834582
# Finish 4 testing epoch, Acc: 0.832742
# Finish 4 risk difference 0.176158
# **********
# epoch 5
# tensor(0.6396, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.830867
# Party 1 accuracy 0.833000
# Party 1 risk difference 0.175008
# Party 2 risk difference 0.177140
# global training risk dfference: 0.176077
# Finish 5 training epoch, Acc: 0.831933
# Finish party 1 test risk difference 0.175987
# Party 1 accuracy 0.831034
# Finish party 2 test risk difference 0.175847
# Party 2 accuracy 0.834844
# Finish 5 testing epoch, Acc: 0.832939
# Finish 5 risk difference 0.175945
# **********
# epoch 6
# tensor(0.6395, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.830800
# Party 1 accuracy 0.832800
# Party 1 risk difference 0.174893
# Party 2 risk difference 0.176719
# global training risk dfference: 0.175809
# Finish 6 training epoch, Acc: 0.831800
# Finish party 1 test risk difference 0.176183
# Party 1 accuracy 0.831165
# Finish party 2 test risk difference 0.175443
# Party 2 accuracy 0.834976
# Finish 6 testing epoch, Acc: 0.833071
# Finish 6 risk difference 0.175842
# **********
# epoch 7
# tensor(0.6395, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.830600
# Party 1 accuracy 0.833000
# Party 1 risk difference 0.175082
# Party 2 risk difference 0.176387
# global training risk dfference: 0.175738
# Finish 7 training epoch, Acc: 0.831800
# Finish party 1 test risk difference 0.175971
# Party 1 accuracy 0.831297
# Finish party 2 test risk difference 0.175637
# Party 2 accuracy 0.835107
# Finish 7 testing epoch, Acc: 0.833202
# Finish 7 risk difference 0.175830
# **********
# epoch 8
# tensor(0.6395, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.830533
# Party 1 accuracy 0.833200
# Party 1 risk difference 0.175272
# Party 2 risk difference 0.176683
# global training risk dfference: 0.175980
# Finish 8 training epoch, Acc: 0.831867
# Finish party 1 test risk difference 0.175571
# Party 1 accuracy 0.831165
# Finish party 2 test risk difference 0.175832
# Party 2 accuracy 0.834976
# Finish 8 testing epoch, Acc: 0.833071
# Finish 8 risk difference 0.175727
# **********
# epoch 9
# tensor(0.6395, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.830733
# Party 1 accuracy 0.833133
# Party 1 risk difference 0.175461
# Party 2 risk difference 0.176781
# global training risk dfference: 0.176124
# Finish 9 training epoch, Acc: 0.831933
# Finish party 1 test risk difference 0.175571
# Party 1 accuracy 0.831165
# Finish party 2 test risk difference 0.176416
# Party 2 accuracy 0.834844
# Finish 9 testing epoch, Acc: 0.833005
# Finish 9 risk difference 0.176020
# **********
# epoch 10
# tensor(0.6395, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.830600
# Party 1 accuracy 0.833333
# Party 1 risk difference 0.175749
# Party 2 risk difference 0.176665
# global training risk dfference: 0.176210
# Finish 10 training epoch, Acc: 0.831967
# Finish party 1 test risk difference 0.175954
# Party 1 accuracy 0.831034
# Finish party 2 test risk difference 0.177000
# Party 2 accuracy 0.834976
# Finish 10 testing epoch, Acc: 0.833005
# Finish 10 risk difference 0.176502
# **********
# epoch 1
# tensor(0.6395, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.830533
# Party 1 accuracy 0.833200
# Party 1 risk difference 0.175848
# Party 2 risk difference 0.176665
# global training risk dfference: 0.176259
# Finish 1 training epoch, Acc: 0.831867
# Finish party 1 test risk difference 0.176541
# Party 1 accuracy 0.830903
# Finish party 2 test risk difference 0.177374
# Party 2 accuracy 0.834582
# Finish 1 testing epoch, Acc: 0.832742
# Finish 1 risk difference 0.176984
# **********
# epoch 2
# tensor(0.6395, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.830333
# Party 1 accuracy 0.833200
# Party 1 risk difference 0.176341
# Party 2 risk difference 0.176647
# global training risk dfference: 0.176497
# Finish 2 training epoch, Acc: 0.831767
# Finish party 1 test risk difference 0.176737
# Party 1 accuracy 0.831034
# Finish party 2 test risk difference 0.177764
# Party 2 accuracy 0.834582
# Finish 2 testing epoch, Acc: 0.832808
# Finish 2 risk difference 0.177277
# **********
# epoch 3
# tensor(0.6395, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.830267
# Party 1 accuracy 0.833133
# Party 1 risk difference 0.176226
# Party 2 risk difference 0.176333
# global training risk dfference: 0.176283
# Finish 3 training epoch, Acc: 0.831700
# Finish party 1 test risk difference 0.176933
# Party 1 accuracy 0.831165
# Finish party 2 test risk difference 0.178348
# Party 2 accuracy 0.834450
# Finish 3 testing epoch, Acc: 0.832808
# Finish 3 risk difference 0.177667
# **********
# epoch 4
# tensor(0.6395, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.830200
# Party 1 accuracy 0.833067
# Party 1 risk difference 0.176325
# Party 2 risk difference 0.176217
# global training risk dfference: 0.176274
# Finish 4 training epoch, Acc: 0.831633
# Finish party 1 test risk difference 0.177520
# Party 1 accuracy 0.831297
# Finish party 2 test risk difference 0.177929
# Party 2 accuracy 0.834450
# Finish 4 testing epoch, Acc: 0.832873
# Finish 4 risk difference 0.177753
# **********
# epoch 5
# tensor(0.6394, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.830000
# Party 1 accuracy 0.832933
# Party 1 risk difference 0.176317
# Party 2 risk difference 0.176808
# global training risk dfference: 0.176566
# Finish 5 training epoch, Acc: 0.831467
# Finish party 1 test risk difference 0.177120
# Party 1 accuracy 0.831165
# Finish party 2 test risk difference 0.177929
# Party 2 accuracy 0.834450
# Finish 5 testing epoch, Acc: 0.832808
# Finish 5 risk difference 0.177552
# **********
# epoch 6
# tensor(0.6394, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.829867
# Party 1 accuracy 0.832733
# Party 1 risk difference 0.176407
# Party 2 risk difference 0.177193
# global training risk dfference: 0.176804
# Finish 6 training epoch, Acc: 0.831300
# Finish party 1 test risk difference 0.177120
# Party 1 accuracy 0.831165
# Finish party 2 test risk difference 0.177719
# Party 2 accuracy 0.834713
# Finish 6 testing epoch, Acc: 0.832939
# Finish 6 risk difference 0.177449
# **********
# epoch 7
# tensor(0.6394, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.829867
# Party 1 accuracy 0.832733
# Party 1 risk difference 0.176407
# Party 2 risk difference 0.177193
# global training risk dfference: 0.176804
# Finish 7 training epoch, Acc: 0.831300
# Finish party 1 test risk difference 0.176916
# Party 1 accuracy 0.830903
# Finish party 2 test risk difference 0.177914
# Party 2 accuracy 0.834582
# Finish 7 testing epoch, Acc: 0.832742
# Finish 7 risk difference 0.177443
# **********
# epoch 8
# tensor(0.6394, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.830067
# Party 1 accuracy 0.832667
# Party 1 risk difference 0.176399
# Party 2 risk difference 0.177292
# global training risk dfference: 0.176849
# Finish 8 training epoch, Acc: 0.831367
# Finish party 1 test risk difference 0.176916
# Party 1 accuracy 0.830903
# Finish party 2 test risk difference 0.177704
# Party 2 accuracy 0.834844
# Finish 8 testing epoch, Acc: 0.832873
# Finish 8 risk difference 0.177340
# **********
# epoch 9
# tensor(0.6394, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.830067
# Party 1 accuracy 0.832733
# Party 1 risk difference 0.176597
# Party 2 risk difference 0.177390
# global training risk dfference: 0.176997
# Finish 9 training epoch, Acc: 0.831400
# Finish party 1 test risk difference 0.177112
# Party 1 accuracy 0.830771
# Finish party 2 test risk difference 0.178288
# Party 2 accuracy 0.834976
# Finish 9 testing epoch, Acc: 0.832873
# Finish 9 risk difference 0.177730
# **********
# epoch 10
# tensor(0.6394, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.830000
# Party 1 accuracy 0.832667
# Party 1 risk difference 0.176695
# Party 2 risk difference 0.177489
# global training risk dfference: 0.177095
# Finish 10 training epoch, Acc: 0.831333
# Finish party 1 test risk difference 0.177308
# Party 1 accuracy 0.830903
# Finish party 2 test risk difference 0.178483
# Party 2 accuracy 0.835107
# Finish 10 testing epoch, Acc: 0.833005
# Finish 10 risk difference 0.177926
# **********
# epoch 1
# tensor(0.6394, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.830000
# Party 1 accuracy 0.832733
# Party 1 risk difference 0.176695
# Party 2 risk difference 0.177175
# global training risk dfference: 0.176939
# Finish 1 training epoch, Acc: 0.831367
# Finish party 1 test risk difference 0.177504
# Party 1 accuracy 0.830771
# Finish party 2 test risk difference 0.178483
# Party 2 accuracy 0.835107
# Finish 1 testing epoch, Acc: 0.832939
# Finish 1 risk difference 0.178023
# **********
# epoch 2
# tensor(0.6394, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.830000
# Party 1 accuracy 0.832600
# Party 1 risk difference 0.176589
# Party 2 risk difference 0.177265
# global training risk dfference: 0.176930
# Finish 2 training epoch, Acc: 0.831300
# Finish party 1 test risk difference 0.177699
# Party 1 accuracy 0.830903
# Finish party 2 test risk difference 0.178483
# Party 2 accuracy 0.835107
# Finish 2 testing epoch, Acc: 0.833005
# Finish 2 risk difference 0.178121
# **********
# epoch 3
# tensor(0.6394, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.830000
# Party 1 accuracy 0.832533
# Party 1 risk difference 0.176375
# Party 2 risk difference 0.177256
# global training risk dfference: 0.176819
# Finish 3 training epoch, Acc: 0.831267
# Finish party 1 test risk difference 0.177495
# Party 1 accuracy 0.830903
# Finish party 2 test risk difference 0.178678
# Party 2 accuracy 0.834976
# Finish 3 testing epoch, Acc: 0.832939
# Finish 3 risk difference 0.178115
# **********
# epoch 4
# tensor(0.6394, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.830000
# Party 1 accuracy 0.832333
# Party 1 risk difference 0.176572
# Party 2 risk difference 0.177049
# global training risk dfference: 0.176815
# Finish 4 training epoch, Acc: 0.831167
# Finish party 1 test risk difference 0.177691
# Party 1 accuracy 0.830771
# Finish party 2 test risk difference 0.178678
# Party 2 accuracy 0.834976
# Finish 4 testing epoch, Acc: 0.832873
# Finish 4 risk difference 0.178213
# **********
# epoch 5
# tensor(0.6394, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.829933
# Party 1 accuracy 0.832333
# Party 1 risk difference 0.176671
# Party 2 risk difference 0.177139
# global training risk dfference: 0.176909
# Finish 5 training epoch, Acc: 0.831133
# Finish party 1 test risk difference 0.178083
# Party 1 accuracy 0.830508
# Finish party 2 test risk difference 0.178872
# Party 2 accuracy 0.834844
# Finish 5 testing epoch, Acc: 0.832676
# Finish 5 risk difference 0.178505
# **********
# epoch 6
# tensor(0.6393, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.829933
# Party 1 accuracy 0.832267
# Party 1 risk difference 0.176564
# Party 2 risk difference 0.177237
# global training risk dfference: 0.176905
# Finish 6 training epoch, Acc: 0.831100
# Finish party 1 test risk difference 0.178074
# Party 1 accuracy 0.830377
# Finish party 2 test risk difference 0.179067
# Party 2 accuracy 0.834713
# Finish 6 testing epoch, Acc: 0.832545
# Finish 6 risk difference 0.178597
# **********
# epoch 7
# tensor(0.6393, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.830000
# Party 1 accuracy 0.832200
# Party 1 risk difference 0.176359
# Party 2 risk difference 0.177031
# global training risk dfference: 0.176699
# Finish 7 training epoch, Acc: 0.831100
# Finish party 1 test risk difference 0.177275
# Party 1 accuracy 0.830114
# Finish party 2 test risk difference 0.178259
# Party 2 accuracy 0.834713
# Finish 7 testing epoch, Acc: 0.832414
# Finish 7 risk difference 0.177793
# **********
# epoch 8
# tensor(0.6393, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.829800
# Party 1 accuracy 0.832067
# Party 1 risk difference 0.176351
# Party 2 risk difference 0.176924
# global training risk dfference: 0.176641
# Finish 8 training epoch, Acc: 0.830933
# Finish party 1 test risk difference 0.176875
# Party 1 accuracy 0.830246
# Finish party 2 test risk difference 0.178453
# Party 2 accuracy 0.834582
# Finish 8 testing epoch, Acc: 0.832414
# Finish 8 risk difference 0.177690
# **********
# epoch 9
# tensor(0.6393, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.829600
# Party 1 accuracy 0.832200
# Party 1 risk difference 0.176844
# Party 2 risk difference 0.176512
# global training risk dfference: 0.176682
# Finish 9 training epoch, Acc: 0.830900
# Finish party 1 test risk difference 0.177267
# Party 1 accuracy 0.830246
# Finish party 2 test risk difference 0.177839
# Party 2 accuracy 0.834187
# Finish 9 testing epoch, Acc: 0.832217
# Finish 9 risk difference 0.177581
# **********
# epoch 10
# tensor(0.6393, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.829467
# Party 1 accuracy 0.832200
# Party 1 risk difference 0.177042
# Party 2 risk difference 0.176512
# global training risk dfference: 0.176780
# Finish 10 training epoch, Acc: 0.830833
# Finish party 1 test risk difference 0.177267
# Party 1 accuracy 0.830246
# Finish party 2 test risk difference 0.177420
# Party 2 accuracy 0.834713
# Finish 10 testing epoch, Acc: 0.832479
# Finish 10 risk difference 0.177374
# **********
# epoch 1
# tensor(0.6393, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.829400
# Party 1 accuracy 0.832200
# Party 1 risk difference 0.177140
# Party 2 risk difference 0.176512
# global training risk dfference: 0.176830
# Finish 1 training epoch, Acc: 0.830800
# Finish party 1 test risk difference 0.177463
# Party 1 accuracy 0.830114
# Finish party 2 test risk difference 0.177615
# Party 2 accuracy 0.834582
# Finish 1 testing epoch, Acc: 0.832348
# Finish 1 risk difference 0.177569
# **********
# epoch 2
# tensor(0.6393, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.829267
# Party 1 accuracy 0.831933
# Party 1 risk difference 0.177231
# Party 2 risk difference 0.175795
# global training risk dfference: 0.176517
# Finish 2 training epoch, Acc: 0.830600
# Finish party 1 test risk difference 0.177267
# Party 1 accuracy 0.829983
# Finish party 2 test risk difference 0.177211
# Party 2 accuracy 0.834713
# Finish 2 testing epoch, Acc: 0.832348
# Finish 2 risk difference 0.177271
# **********
# epoch 3
# tensor(0.6393, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.829133
# Party 1 accuracy 0.831867
# Party 1 risk difference 0.177124
# Party 2 risk difference 0.175893
# global training risk dfference: 0.176513
# Finish 3 training epoch, Acc: 0.830500
# Finish party 1 test risk difference 0.176867
# Party 1 accuracy 0.829852
# Finish party 2 test risk difference 0.176807
# Party 2 accuracy 0.834844
# Finish 3 testing epoch, Acc: 0.832348
# Finish 3 risk difference 0.176869
# **********
# epoch 4
# tensor(0.6393, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.829067
# Party 1 accuracy 0.832000
# Party 1 risk difference 0.177025
# Party 2 risk difference 0.175786
# global training risk dfference: 0.176410
# Finish 4 training epoch, Acc: 0.830533
# Finish party 1 test risk difference 0.176867
# Party 1 accuracy 0.829852
# Finish party 2 test risk difference 0.177001
# Party 2 accuracy 0.834713
# Finish 4 testing epoch, Acc: 0.832282
# Finish 4 risk difference 0.176966
# **********
# epoch 5
# tensor(0.6393, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.829133
# Party 1 accuracy 0.832000
# Party 1 risk difference 0.177321
# Party 2 risk difference 0.175786
# global training risk dfference: 0.176558
# Finish 5 training epoch, Acc: 0.830567
# Finish party 1 test risk difference 0.176459
# Party 1 accuracy 0.830114
# Finish party 2 test risk difference 0.177196
# Party 2 accuracy 0.834582
# Finish 5 testing epoch, Acc: 0.832348
# Finish 5 risk difference 0.176857
# **********
# epoch 6
# tensor(0.6393, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.829000
# Party 1 accuracy 0.831733
# Party 1 risk difference 0.177519
# Party 2 risk difference 0.175768
# global training risk dfference: 0.176648
# Finish 6 training epoch, Acc: 0.830367
# Finish party 1 test risk difference 0.176459
# Party 1 accuracy 0.830114
# Finish party 2 test risk difference 0.177196
# Party 2 accuracy 0.834582
# Finish 6 testing epoch, Acc: 0.832348
# Finish 6 risk difference 0.176857
# **********
# epoch 7
# tensor(0.6393, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828867
# Party 1 accuracy 0.831867
# Party 1 risk difference 0.177519
# Party 2 risk difference 0.175965
# global training risk dfference: 0.176746
# Finish 7 training epoch, Acc: 0.830367
# Finish party 1 test risk difference 0.176655
# Party 1 accuracy 0.830246
# Finish party 2 test risk difference 0.177196
# Party 2 accuracy 0.834582
# Finish 7 testing epoch, Acc: 0.832414
# Finish 7 risk difference 0.176955
# **********
# epoch 8
# tensor(0.6393, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828867
# Party 1 accuracy 0.831667
# Party 1 risk difference 0.177519
# Party 2 risk difference 0.175346
# global training risk dfference: 0.176438
# Finish 8 training epoch, Acc: 0.830267
# Finish party 1 test risk difference 0.176451
# Party 1 accuracy 0.830246
# Finish party 2 test risk difference 0.177196
# Party 2 accuracy 0.834582
# Finish 8 testing epoch, Acc: 0.832414
# Finish 8 risk difference 0.176852
# **********
# epoch 9
# tensor(0.6392, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828933
# Party 1 accuracy 0.831533
# Party 1 risk difference 0.177618
# Party 2 risk difference 0.175436
# global training risk dfference: 0.176532
# Finish 9 training epoch, Acc: 0.830233
# Finish party 1 test risk difference 0.176647
# Party 1 accuracy 0.830114
# Finish party 2 test risk difference 0.177391
# Party 2 accuracy 0.834713
# Finish 9 testing epoch, Acc: 0.832414
# Finish 9 risk difference 0.177047
# **********
# epoch 10
# tensor(0.6392, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.829000
# Party 1 accuracy 0.831333
# Party 1 risk difference 0.177914
# Party 2 risk difference 0.175122
# global training risk dfference: 0.176523
# Finish 10 training epoch, Acc: 0.830167
# Finish party 1 test risk difference 0.176647
# Party 1 accuracy 0.830114
# Finish party 2 test risk difference 0.177585
# Party 2 accuracy 0.834844
# Finish 10 testing epoch, Acc: 0.832479
# Finish 10 risk difference 0.177144
# **********
# epoch 1
# tensor(0.6392, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.829000
# Party 1 accuracy 0.831267
# Party 1 risk difference 0.177914
# Party 2 risk difference 0.175024
# global training risk dfference: 0.176474
# Finish 1 training epoch, Acc: 0.830133
# Finish party 1 test risk difference 0.176842
# Party 1 accuracy 0.829983
# Finish party 2 test risk difference 0.177585
# Party 2 accuracy 0.834844
# Finish 1 testing epoch, Acc: 0.832414
# Finish 1 risk difference 0.177242
# **********
# epoch 2
# tensor(0.6392, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.829000
# Party 1 accuracy 0.831333
# Party 1 risk difference 0.178111
# Party 2 risk difference 0.174710
# global training risk dfference: 0.176416
# Finish 2 training epoch, Acc: 0.830167
# Finish party 1 test risk difference 0.176842
# Party 1 accuracy 0.829983
# Finish party 2 test risk difference 0.177975
# Party 2 accuracy 0.834582
# Finish 2 testing epoch, Acc: 0.832282
# Finish 2 risk difference 0.177437
# **********
# epoch 3
# tensor(0.6392, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.829000
# Party 1 accuracy 0.831467
# Party 1 risk difference 0.177897
# Party 2 risk difference 0.174603
# global training risk dfference: 0.176255
# Finish 3 training epoch, Acc: 0.830233
# Finish party 1 test risk difference 0.176842
# Party 1 accuracy 0.829983
# Finish party 2 test risk difference 0.177780
# Party 2 accuracy 0.834713
# Finish 3 testing epoch, Acc: 0.832348
# Finish 3 risk difference 0.177340
# **********
# epoch 4
# tensor(0.6392, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.829000
# Party 1 accuracy 0.831533
# Party 1 risk difference 0.177791
# Party 2 risk difference 0.174701
# global training risk dfference: 0.176251
# Finish 4 training epoch, Acc: 0.830267
# Finish party 1 test risk difference 0.176443
# Party 1 accuracy 0.830114
# Finish party 2 test risk difference 0.177780
# Party 2 accuracy 0.834713
# Finish 4 testing epoch, Acc: 0.832414
# Finish 4 risk difference 0.177139
# **********
# epoch 5
# tensor(0.6392, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.829067
# Party 1 accuracy 0.831600
# Party 1 risk difference 0.177585
# Party 2 risk difference 0.174298
# global training risk dfference: 0.175947
# Finish 5 training epoch, Acc: 0.830333
# Finish party 1 test risk difference 0.176247
# Party 1 accuracy 0.830246
# Finish party 2 test risk difference 0.176986
# Party 2 accuracy 0.834582
# Finish 5 testing epoch, Acc: 0.832414
# Finish 5 risk difference 0.176645
# **********
# epoch 6
# tensor(0.6392, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.829067
# Party 1 accuracy 0.831600
# Party 1 risk difference 0.177585
# Party 2 risk difference 0.174298
# global training risk dfference: 0.175947
# Finish 6 training epoch, Acc: 0.830333
# Finish party 1 test risk difference 0.176051
# Party 1 accuracy 0.830114
# Finish party 2 test risk difference 0.176986
# Party 2 accuracy 0.834582
# Finish 6 testing epoch, Acc: 0.832348
# Finish 6 risk difference 0.176547
# **********
# epoch 7
# tensor(0.6392, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.829200
# Party 1 accuracy 0.831667
# Party 1 risk difference 0.177478
# Party 2 risk difference 0.174397
# global training risk dfference: 0.175942
# Finish 7 training epoch, Acc: 0.830433
# Finish party 1 test risk difference 0.175847
# Party 1 accuracy 0.830114
# Finish party 2 test risk difference 0.176986
# Party 2 accuracy 0.834582
# Finish 7 testing epoch, Acc: 0.832348
# Finish 7 risk difference 0.176444
# **********
# epoch 8
# tensor(0.6392, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.829067
# Party 1 accuracy 0.831800
# Party 1 risk difference 0.177372
# Party 2 risk difference 0.174594
# global training risk dfference: 0.175988
# Finish 8 training epoch, Acc: 0.830433
# Finish party 1 test risk difference 0.175847
# Party 1 accuracy 0.830114
# Finish party 2 test risk difference 0.176986
# Party 2 accuracy 0.834582
# Finish 8 testing epoch, Acc: 0.832348
# Finish 8 risk difference 0.176444
# **********
# epoch 9
# tensor(0.6392, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.829067
# Party 1 accuracy 0.831800
# Party 1 risk difference 0.177372
# Party 2 risk difference 0.174594
# global training risk dfference: 0.175988
# Finish 9 training epoch, Acc: 0.830433
# Finish party 1 test risk difference 0.176435
# Party 1 accuracy 0.829720
# Finish party 2 test risk difference 0.176986
# Party 2 accuracy 0.834582
# Finish 9 testing epoch, Acc: 0.832151
# Finish 9 risk difference 0.176737
# **********
# epoch 10
# tensor(0.6392, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.829133
# Party 1 accuracy 0.831733
# Party 1 risk difference 0.177668
# Party 2 risk difference 0.174585
# global training risk dfference: 0.176131
# Finish 10 training epoch, Acc: 0.830433
# Finish party 1 test risk difference 0.176239
# Party 1 accuracy 0.829852
# Finish party 2 test risk difference 0.176582
# Party 2 accuracy 0.834713
# Finish 10 testing epoch, Acc: 0.832282
# Finish 10 risk difference 0.176438
# **********
# epoch 1
# tensor(0.6392, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.829000
# Party 1 accuracy 0.831733
# Party 1 risk difference 0.177454
# Party 2 risk difference 0.174585
# global training risk dfference: 0.176024
# Finish 1 training epoch, Acc: 0.830367
# Finish party 1 test risk difference 0.176435
# Party 1 accuracy 0.829720
# Finish party 2 test risk difference 0.176777
# Party 2 accuracy 0.834844
# Finish 1 testing epoch, Acc: 0.832282
# Finish 1 risk difference 0.176633
# **********
# epoch 2
# tensor(0.6392, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828933
# Party 1 accuracy 0.831533
# Party 1 risk difference 0.177249
# Party 2 risk difference 0.174576
# global training risk dfference: 0.175917
# Finish 2 training epoch, Acc: 0.830233
# Finish party 1 test risk difference 0.176435
# Party 1 accuracy 0.829720
# Finish party 2 test risk difference 0.176972
# Party 2 accuracy 0.834713
# Finish 2 testing epoch, Acc: 0.832217
# Finish 2 risk difference 0.176731
# **********
# epoch 3
# ...
# **********
# epoch 7
# tensor(0.6389, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828467
# Party 1 accuracy 0.832200
# Party 1 risk difference 0.178467
# Party 2 risk difference 0.174127
# global training risk dfference: 0.176303
# Finish 7 training epoch, Acc: 0.830333
# Finish party 1 test risk difference 0.176393
# Party 1 accuracy 0.830114
# Finish party 2 test risk difference 0.172675
# Party 2 accuracy 0.836158
# Finish 7 testing epoch, Acc: 0.833136
# Finish 7 risk difference 0.174572
# **********
# epoch 8
# tensor(0.6389, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828333
# Party 1 accuracy 0.832200
# Party 1 risk difference 0.178664
# Party 2 risk difference 0.174127
# global training risk dfference: 0.176402
# Finish 8 training epoch, Acc: 0.830267
# Finish party 1 test risk difference 0.176393
# Party 1 accuracy 0.830114
# Finish party 2 test risk difference 0.172675
# Party 2 accuracy 0.836158
# Finish 8 testing epoch, Acc: 0.833136
# Finish 8 risk difference 0.174572
# **********
# epoch 9
# tensor(0.6389, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828333
# Party 1 accuracy 0.832267
# Party 1 risk difference 0.178664
# Party 2 risk difference 0.174225
# global training risk dfference: 0.176451
# Finish 9 training epoch, Acc: 0.830300
# Finish party 1 test risk difference 0.176393
# Party 1 accuracy 0.830114
# Finish party 2 test risk difference 0.172675
# Party 2 accuracy 0.836158
# Finish 9 testing epoch, Acc: 0.833136
# Finish 9 risk difference 0.174572
# **********
# epoch 10
# tensor(0.6389, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828400
# Party 1 accuracy 0.832267
# Party 1 risk difference 0.178656
# Party 2 risk difference 0.174225
# global training risk dfference: 0.176447
# Finish 10 training epoch, Acc: 0.830333
# Finish party 1 test risk difference 0.176393
# Party 1 accuracy 0.830114
# Finish party 2 test risk difference 0.172675
# Party 2 accuracy 0.836158
# Finish 10 testing epoch, Acc: 0.833136
# Finish 10 risk difference 0.174572
# **********
# epoch 1
# tensor(0.6389, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828400
# Party 1 accuracy 0.832200
# Party 1 risk difference 0.178656
# Party 2 risk difference 0.174324
# global training risk dfference: 0.176496
# Finish 1 training epoch, Acc: 0.830300
# Finish party 1 test risk difference 0.176393
# Party 1 accuracy 0.830114
# Finish party 2 test risk difference 0.172675
# Party 2 accuracy 0.836158
# Finish 1 testing epoch, Acc: 0.833136
# Finish 1 risk difference 0.174572
# **********
# epoch 2
# tensor(0.6389, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828400
# Party 1 accuracy 0.832200
# Party 1 risk difference 0.178656
# Party 2 risk difference 0.174324
# global training risk dfference: 0.176496
# Finish 2 training epoch, Acc: 0.830300
# Finish party 1 test risk difference 0.176393
# Party 1 accuracy 0.830114
# Finish party 2 test risk difference 0.172271
# Party 2 accuracy 0.836027
# Finish 2 testing epoch, Acc: 0.833071
# Finish 2 risk difference 0.174371
# **********
# epoch 3
# tensor(0.6389, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828400
# Party 1 accuracy 0.832133
# Party 1 risk difference 0.178656
# Party 2 risk difference 0.174118
# global training risk dfference: 0.176393
# Finish 3 training epoch, Acc: 0.830267
# Finish party 1 test risk difference 0.176393
# Party 1 accuracy 0.830114
# Finish party 2 test risk difference 0.172271
# Party 2 accuracy 0.836027
# Finish 3 testing epoch, Acc: 0.833071
# Finish 3 risk difference 0.174371
# **********
# epoch 4
# tensor(0.6389, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828400
# Party 1 accuracy 0.832200
# Party 1 risk difference 0.178656
# Party 2 risk difference 0.173912
# global training risk dfference: 0.176290
# Finish 4 training epoch, Acc: 0.830300
# Finish party 1 test risk difference 0.176393
# Party 1 accuracy 0.830114
# Finish party 2 test risk difference 0.171867
# Party 2 accuracy 0.836158
# Finish 4 testing epoch, Acc: 0.833136
# Finish 4 risk difference 0.174170
# **********
# epoch 5
# tensor(0.6389, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828400
# Party 1 accuracy 0.832067
# Party 1 risk difference 0.178656
# Party 2 risk difference 0.173714
# global training risk dfference: 0.176191
# Finish 5 training epoch, Acc: 0.830233
# Finish party 1 test risk difference 0.176393
# Party 1 accuracy 0.830114
# Finish party 2 test risk difference 0.171867
# Party 2 accuracy 0.836158
# Finish 5 testing epoch, Acc: 0.833136
# Finish 5 risk difference 0.174170
# **********
# epoch 6
# tensor(0.6389, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828467
# Party 1 accuracy 0.832067
# Party 1 risk difference 0.178755
# Party 2 risk difference 0.173714
# global training risk dfference: 0.176241
# Finish 6 training epoch, Acc: 0.830267
# Finish party 1 test risk difference 0.176589
# Party 1 accuracy 0.829983
# Finish party 2 test risk difference 0.171867
# Party 2 accuracy 0.836158
# Finish 6 testing epoch, Acc: 0.833071
# Finish 6 risk difference 0.174267
# **********
# epoch 7
# tensor(0.6389, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828467
# Party 1 accuracy 0.832067
# Party 1 risk difference 0.178755
# Party 2 risk difference 0.173714
# global training risk dfference: 0.176241
# Finish 7 training epoch, Acc: 0.830267
# Finish party 1 test risk difference 0.176589
# Party 1 accuracy 0.829983
# Finish party 2 test risk difference 0.171867
# Party 2 accuracy 0.836158
# Finish 7 testing epoch, Acc: 0.833071
# Finish 7 risk difference 0.174267
# **********
# epoch 8
# tensor(0.6389, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828533
# Party 1 accuracy 0.832067
# Party 1 risk difference 0.178549
# Party 2 risk difference 0.173714
# global training risk dfference: 0.176138
# Finish 8 training epoch, Acc: 0.830300
# Finish party 1 test risk difference 0.176589
# Party 1 accuracy 0.829983
# Finish party 2 test risk difference 0.171672
# Party 2 accuracy 0.836027
# Finish 8 testing epoch, Acc: 0.833005
# Finish 8 risk difference 0.174170
# **********
# epoch 9
# tensor(0.6389, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828533
# Party 1 accuracy 0.832000
# Party 1 risk difference 0.178549
# Party 2 risk difference 0.173813
# global training risk dfference: 0.176187
# Finish 9 training epoch, Acc: 0.830267
# Finish party 1 test risk difference 0.176589
# Party 1 accuracy 0.829983
# Finish party 2 test risk difference 0.171867
# Party 2 accuracy 0.835895
# Finish 9 testing epoch, Acc: 0.832939
# Finish 9 risk difference 0.174267
# **********
# epoch 10
# tensor(0.6389, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828533
# Party 1 accuracy 0.832000
# Party 1 risk difference 0.178549
# Party 2 risk difference 0.173813
# global training risk dfference: 0.176187
# Finish 10 training epoch, Acc: 0.830267
# Finish party 1 test risk difference 0.176190
# Party 1 accuracy 0.830114
# Finish party 2 test risk difference 0.172062
# Party 2 accuracy 0.835764
# Finish 10 testing epoch, Acc: 0.832939
# Finish 10 risk difference 0.174164
# **********
# epoch 1
# tensor(0.6389, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828533
# Party 1 accuracy 0.831867
# Party 1 risk difference 0.178549
# Party 2 risk difference 0.174118
# global training risk dfference: 0.176339
# Finish 1 training epoch, Acc: 0.830200
# Finish party 1 test risk difference 0.176385
# Party 1 accuracy 0.830246
# Finish party 2 test risk difference 0.172062
# Party 2 accuracy 0.835764
# Finish 1 testing epoch, Acc: 0.833005
# Finish 1 risk difference 0.174262
# **********
# epoch 2
# tensor(0.6389, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828467
# Party 1 accuracy 0.831733
# Party 1 risk difference 0.178344
# Party 2 risk difference 0.174118
# global training risk dfference: 0.176237
# Finish 2 training epoch, Acc: 0.830100
# Finish party 1 test risk difference 0.176385
# Party 1 accuracy 0.830246
# Finish party 2 test risk difference 0.172062
# Party 2 accuracy 0.835764
# Finish 2 testing epoch, Acc: 0.833005
# Finish 2 risk difference 0.174262
# **********
# epoch 3
# tensor(0.6389, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828467
# Party 1 accuracy 0.831733
# Party 1 risk difference 0.178541
# Party 2 risk difference 0.174118
# global training risk dfference: 0.176335
# Finish 3 training epoch, Acc: 0.830100
# Finish party 1 test risk difference 0.176385
# Party 1 accuracy 0.830246
# Finish party 2 test risk difference 0.172062
# Party 2 accuracy 0.835764
# Finish 3 testing epoch, Acc: 0.833005
# Finish 3 risk difference 0.174262
# **********
# epoch 4
# tensor(0.6389, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828400
# Party 1 accuracy 0.831800
# Party 1 risk difference 0.178640
# Party 2 risk difference 0.174216
# global training risk dfference: 0.176434
# Finish 4 training epoch, Acc: 0.830100
# Finish party 1 test risk difference 0.176385
# Party 1 accuracy 0.830246
# Finish party 2 test risk difference 0.172256
# Party 2 accuracy 0.835633
# Finish 4 testing epoch, Acc: 0.832939
# Finish 4 risk difference 0.174359
# **********
# epoch 5
# tensor(0.6389, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828400
# Party 1 accuracy 0.831867
# Party 1 risk difference 0.178640
# Party 2 risk difference 0.174010
# global training risk dfference: 0.176331
# Finish 5 training epoch, Acc: 0.830133
# Finish party 1 test risk difference 0.176385
# Party 1 accuracy 0.830246
# Finish party 2 test risk difference 0.172256
# Party 2 accuracy 0.835633
# Finish 5 testing epoch, Acc: 0.832939
# Finish 5 risk difference 0.174359
# **********
# epoch 6
# tensor(0.6389, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828400
# Party 1 accuracy 0.831867
# Party 1 risk difference 0.178640
# Party 2 risk difference 0.174010
# global training risk dfference: 0.176331
# Finish 6 training epoch, Acc: 0.830133
# Finish party 1 test risk difference 0.176385
# Party 1 accuracy 0.830246
# Finish party 2 test risk difference 0.172256
# Party 2 accuracy 0.835633
# Finish 6 testing epoch, Acc: 0.832939
# Finish 6 risk difference 0.174359
# **********
# epoch 7
# tensor(0.6388, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828400
# Party 1 accuracy 0.831867
# Party 1 risk difference 0.178640
# Party 2 risk difference 0.174010
# global training risk dfference: 0.176331
# Finish 7 training epoch, Acc: 0.830133
# Finish party 1 test risk difference 0.176385
# Party 1 accuracy 0.830246
# Finish party 2 test risk difference 0.172256
# Party 2 accuracy 0.835633
# Finish 7 testing epoch, Acc: 0.832939
# Finish 7 risk difference 0.174359
# **********
# epoch 8
# tensor(0.6388, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828400
# Party 1 accuracy 0.831867
# Party 1 risk difference 0.178533
# Party 2 risk difference 0.174010
# global training risk dfference: 0.176277
# Finish 8 training epoch, Acc: 0.830133
# Finish party 1 test risk difference 0.176581
# Party 1 accuracy 0.830377
# Finish party 2 test risk difference 0.172256
# Party 2 accuracy 0.835633
# Finish 8 testing epoch, Acc: 0.833005
# Finish 8 risk difference 0.174457
# **********
# epoch 9
# tensor(0.6388, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828400
# Party 1 accuracy 0.831867
# Party 1 risk difference 0.178533
# Party 2 risk difference 0.174010
# global training risk dfference: 0.176277
# Finish 9 training epoch, Acc: 0.830133
# Finish party 1 test risk difference 0.176581
# Party 1 accuracy 0.830377
# Finish party 2 test risk difference 0.172256
# Party 2 accuracy 0.835633
# Finish 9 testing epoch, Acc: 0.833005
# Finish 9 risk difference 0.174457
# **********
# epoch 10
# tensor(0.6388, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828400
# Party 1 accuracy 0.831800
# Party 1 risk difference 0.178533
# Party 2 risk difference 0.174109
# global training risk dfference: 0.176327
# Finish 10 training epoch, Acc: 0.830100
# Finish party 1 test risk difference 0.176581
# Party 1 accuracy 0.830377
# Finish party 2 test risk difference 0.172256
# Party 2 accuracy 0.835633
# Finish 10 testing epoch, Acc: 0.833005
# Finish 10 risk difference 0.174457
# **********
# epoch 1
# tensor(0.6388, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828400
# Party 1 accuracy 0.831867
# Party 1 risk difference 0.178533
# Party 2 risk difference 0.174207
# global training risk dfference: 0.176376
# Finish 1 training epoch, Acc: 0.830133
# Finish party 1 test risk difference 0.176581
# Party 1 accuracy 0.830377
# Finish party 2 test risk difference 0.172256
# Party 2 accuracy 0.835633
# Finish 1 testing epoch, Acc: 0.833005
# Finish 1 risk difference 0.174457
# **********
# epoch 2
# tensor(0.6388, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828467
# Party 1 accuracy 0.831800
# Party 1 risk difference 0.178632
# Party 2 risk difference 0.174306
# global training risk dfference: 0.176475
# Finish 2 training epoch, Acc: 0.830133
# Finish party 1 test risk difference 0.176777
# Party 1 accuracy 0.830246
# Finish party 2 test risk difference 0.172256
# Party 2 accuracy 0.835633
# Finish 2 testing epoch, Acc: 0.832939
# Finish 2 risk difference 0.174554
# **********
# epoch 3
# tensor(0.6388, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828533
# Party 1 accuracy 0.831800
# Party 1 risk difference 0.178731
# Party 2 risk difference 0.174306
# global training risk dfference: 0.176524
# Finish 3 training epoch, Acc: 0.830167
# Finish party 1 test risk difference 0.176777
# Party 1 accuracy 0.830246
# Finish party 2 test risk difference 0.172256
# Party 2 accuracy 0.835633
# Finish 3 testing epoch, Acc: 0.832939
# Finish 3 risk difference 0.174554
# **********
# epoch 4
# tensor(0.6388, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828533
# Party 1 accuracy 0.831733
# Party 1 risk difference 0.178731
# Party 2 risk difference 0.174207
# global training risk dfference: 0.176475
# Finish 4 training epoch, Acc: 0.830133
# Finish party 1 test risk difference 0.176777
# Party 1 accuracy 0.830246
# Finish party 2 test risk difference 0.172256
# Party 2 accuracy 0.835633
# Finish 4 testing epoch, Acc: 0.832939
# Finish 4 risk difference 0.174554
# **********
# epoch 5
# tensor(0.6388, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828533
# Party 1 accuracy 0.831733
# Party 1 risk difference 0.178731
# Party 2 risk difference 0.174207
# global training risk dfference: 0.176475
# Finish 5 training epoch, Acc: 0.830133
# Finish party 1 test risk difference 0.176777
# Party 1 accuracy 0.830246
# Finish party 2 test risk difference 0.172256
# Party 2 accuracy 0.835633
# Finish 5 testing epoch, Acc: 0.832939
# Finish 5 risk difference 0.174554
# **********
# epoch 6
# tensor(0.6388, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828533
# Party 1 accuracy 0.831733
# Party 1 risk difference 0.178731
# Party 2 risk difference 0.174512
# global training risk dfference: 0.176627
# Finish 6 training epoch, Acc: 0.830133
# Finish party 1 test risk difference 0.176777
# Party 1 accuracy 0.830246
# Finish party 2 test risk difference 0.172256
# Party 2 accuracy 0.835633
# Finish 6 testing epoch, Acc: 0.832939
# Finish 6 risk difference 0.174554
# **********
# epoch 7
# tensor(0.6388, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828533
# Party 1 accuracy 0.831733
# Party 1 risk difference 0.178731
# Party 2 risk difference 0.174512
# global training risk dfference: 0.176627
# Finish 7 training epoch, Acc: 0.830133
# Finish party 1 test risk difference 0.176777
# Party 1 accuracy 0.830246
# Finish party 2 test risk difference 0.172256
# Party 2 accuracy 0.835633
# Finish 7 testing epoch, Acc: 0.832939
# Finish 7 risk difference 0.174554
# **********
# epoch 8
# tensor(0.6388, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828533
# Party 1 accuracy 0.831733
# Party 1 risk difference 0.178731
# Party 2 risk difference 0.174512
# global training risk dfference: 0.176627
# Finish 8 training epoch, Acc: 0.830133
# Finish party 1 test risk difference 0.176777
# Party 1 accuracy 0.830246
# Finish party 2 test risk difference 0.172256
# Party 2 accuracy 0.835633
# Finish 8 testing epoch, Acc: 0.832939
# Finish 8 risk difference 0.174554
# **********
# epoch 9
# tensor(0.6388, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828467
# Party 1 accuracy 0.831733
# Party 1 risk difference 0.178829
# Party 2 risk difference 0.174512
# global training risk dfference: 0.176676
# Finish 9 training epoch, Acc: 0.830100
# Finish party 1 test risk difference 0.176777
# Party 1 accuracy 0.830246
# Finish party 2 test risk difference 0.172256
# Party 2 accuracy 0.835633
# Finish 9 testing epoch, Acc: 0.832939
# Finish 9 risk difference 0.174554
# **********
# epoch 10
# tensor(0.6388, grad_fn=<AddBackward0>)
# Party 1 accuracy 0.828467
# Party 1 accuracy 0.831667
# Party 1 risk difference 0.178829
# Party 2 risk difference 0.174413
# global training risk dfference: 0.176627
# Finish 10 training epoch, Acc: 0.830067
# Finish party 1 test risk difference 0.176777
# Party 1 accuracy 0.830246
# Finish party 2 test risk difference 0.172256
# Party 2 accuracy 0.835633
# Finish 10 testing epoch, Acc: 0.832939
# Finish 10 risk difference 0.174554
