# %%
from sims import *

# %%
# F-Train 100
runSim(num_sim = 100, train_samples = 3000, test_samples = 300, num_rounds = 10, option = 'ftrain',
          local_epochs = 30, metric = "Demographic disparity", init_epochs = 50, lr_g = 0.005, lr_d = 0.01, lambda_d = 0.8)
# Out:
# |  Simulation : 1 |
#       seed : 864 -----
# 100%|██████████| 10/10 [00:21<00:00,  2.11s/it]
#       Accuracy: 74.33%  Demographic disparity: 0.10
# |  Simulation : 2 |
#       seed : 887 -----
# 100%|██████████| 10/10 [00:21<00:00,  2.18s/it]
#       Accuracy: 64.33%  Demographic disparity: 0.12
# |  Simulation : 3 |
#       seed : 911 -----
# 100%|██████████| 10/10 [00:22<00:00,  2.24s/it]
#       Accuracy: 72.33%  Demographic disparity: 0.12
# |  Simulation : 4 |
#       seed : 935 -----
# 100%|██████████| 10/10 [00:22<00:00,  2.23s/it]
#       Accuracy: 77.00%  Demographic disparity: 0.13
# |  Simulation : 5 |
#       seed : 959 -----
# 100%|██████████| 10/10 [00:23<00:00,  2.31s/it]
#       Accuracy: 82.67%  Demographic disparity: 0.15
# |  Simulation : 6 |
#       seed : 984 -----
# 100%|██████████| 10/10 [00:24<00:00,  2.46s/it]
#       Accuracy: 80.67%  Demographic disparity: 0.15
# |  Simulation : 7 |
#       seed : 10 -----
# ...

# %%
# FairBatch-Variant1 100
runSim(num_sim = 100, train_samples = 3000, test_samples = 300, learning_rate = 0.004, num_rounds = 10, option = 'fb-variant1',
          local_epochs = 30, alpha = 0.2, metric = "Demographic disparity", optimizer = 'adam')
# Out:
# |  Simulation : 1 |
#       seed : 267 -----
# 100%|██████████| 10/10 [00:23<00:00,  2.34s/it]
#       Accuracy: 76.00%  Demographic disparity: 0.06
# |  Simulation : 2 |
#       seed : 293 -----
# 100%|██████████| 10/10 [00:24<00:00,  2.50s/it]
#       Accuracy: 76.67%  Demographic disparity: 0.04
# |  Simulation : 3 |
#       seed : 319 -----
# 100%|██████████| 10/10 [00:22<00:00,  2.25s/it]
#       Accuracy: 73.67%  Demographic disparity: 0.04
# |  Simulation : 4 |
#       seed : 343 -----
# 100%|██████████| 10/10 [00:21<00:00,  2.20s/it]
#       Accuracy: 67.00%  Demographic disparity: 0.06
# |  Simulation : 5 |
#       seed : 367 -----
# 100%|██████████| 10/10 [00:22<00:00,  2.21s/it]
#       Accuracy: 74.33%  Demographic disparity: 0.02
# |  Simulation : 6 |
#       seed : 391 -----
# 100%|██████████| 10/10 [00:24<00:00,  2.48s/it]
#       Accuracy: 74.33%  Demographic disparity: 0.03
# |  Simulation : 7 |
#       seed : 417 -----
# ...

# %%
# bias correcting 100
runSim(num_sim = 100, train_samples = 3000, test_samples = 300, learning_rate = 0.005, num_rounds = 10, 
          local_epochs = 30, metric = "Demographic disparity", option = "bias correcting", alpha = 5, epsilon = None, optimizer = 'adam')
# Out:
# |  Simulation : 1 |
#       seed : 82 -----
# 100%|██████████| 10/10 [00:22<00:00,  2.25s/it]
#       Accuracy: 71.67%  Demographic disparity: 0.04
# |  Simulation : 2 |
#       seed : 106 -----
# 100%|██████████| 10/10 [00:21<00:00,  2.17s/it]
#       Accuracy: 77.00%  Demographic disparity: 0.01
# |  Simulation : 3 |
#       seed : 129 -----
# 100%|██████████| 10/10 [00:23<00:00,  2.31s/it]
#       Accuracy: 75.00%  Demographic disparity: 0.02
# |  Simulation : 4 |
#       seed : 154 -----
# 100%|██████████| 10/10 [00:22<00:00,  2.26s/it]
#       Accuracy: 74.33%  Demographic disparity: 0.05
# |  Simulation : 5 |
#       seed : 180 -----
# 100%|██████████| 10/10 [00:21<00:00,  2.17s/it]
#       Accuracy: 71.00%  Demographic disparity: 0.06
# |  Simulation : 6 |
#       seed : 203 -----
# 100%|██████████| 10/10 [00:21<00:00,  2.17s/it]
#       Accuracy: 74.00%  Demographic disparity: 0.12
# |  Simulation : 7 |
#       seed : 226 -----
# ...

# %%
# unconstrained 100
runSim(num_sim = 100, train_samples = 3000, test_samples = 300, learning_rate = 0.001, num_rounds = 10, 
          local_epochs = 30, metric = "Demographic disparity", option = "unconstrained")
# Out:
# |  Simulation : 1 |
#       seed : 663 -----
# 100%|██████████| 10/10 [00:24<00:00,  2.42s/it]
#       Accuracy: 89.33%  Demographic disparity: 0.40
# |  Simulation : 2 |
#       seed : 690 -----
# 100%|██████████| 10/10 [00:22<00:00,  2.23s/it]
#       Accuracy: 86.33%  Demographic disparity: 0.43
# |  Simulation : 3 |
#       seed : 713 -----
# 100%|██████████| 10/10 [00:23<00:00,  2.32s/it]
#       Accuracy: 88.67%  Demographic disparity: 0.35
# |  Simulation : 4 |
#       seed : 738 -----
# 100%|██████████| 10/10 [00:24<00:00,  2.41s/it]
#       Accuracy: 90.33%  Demographic disparity: 0.32
# |  Simulation : 5 |
#       seed : 764 -----
# 100%|██████████| 10/10 [00:22<00:00,  2.24s/it]
#       Accuracy: 91.33%  Demographic disparity: 0.40
# |  Simulation : 6 |
#       seed : 788 -----
# 100%|██████████| 10/10 [00:24<00:00,  2.47s/it]
#       Accuracy: 89.67%  Demographic disparity: 0.42
# |  Simulation : 7 |
#       seed : 815 -----
# ...

# %%
# local Zafar 100
runSim(num_sim = 100, train_samples = 3000, test_samples = 300, learning_rate = 0.001, num_rounds = 10, 
          local_epochs = 30, metric = "Demographic disparity", option = "local zafar", penalty = 500, optimizer = 'adam',
      epsilon = None)
# Out:
# |  Simulation : 1 |
#       seed : 256 -----
# 100%|██████████| 10/10 [00:25<00:00,  2.55s/it]
#       Accuracy: 61.67%  Demographic disparity: 0.00
# |  Simulation : 2 |
#       seed : 283 -----
# 100%|██████████| 10/10 [00:26<00:00,  2.65s/it]
#       Accuracy: 64.00%  Demographic disparity: 0.03
# |  Simulation : 3 |
#       seed : 312 -----
# 100%|██████████| 10/10 [00:28<00:00,  2.80s/it]
#       Accuracy: 58.67%  Demographic disparity: 0.04
# |  Simulation : 4 |
#       seed : 341 -----
# 100%|██████████| 10/10 [00:28<00:00,  2.86s/it]
#       Accuracy: 66.33%  Demographic disparity: 0.25
# |  Simulation : 5 |
#       seed : 371 -----
# 100%|██████████| 10/10 [00:23<00:00,  2.37s/it]
#       Accuracy: 80.67%  Demographic disparity: 0.34
# |  Simulation : 6 |
#       seed : 397 -----
# 100%|██████████| 10/10 [00:28<00:00,  2.89s/it]
#       Accuracy: 69.00%  Demographic disparity: 0.11
# |  Simulation : 7 |
#       seed : 428 -----
# ...

# %%
# threshold adjusting 100
runSim(num_sim = 100, train_samples = 3000, test_samples = 300, option = "threshold adjusting", learning_rate = 0.008,
      num_rounds = 2, local_epochs = 10, metric = "Demographic disparity", adjusting_rounds = 8, adjusting_epochs = 30,
      adjusting_alpha = 0.005, epsilon = 0.02, optimizer = 'adam')
# Out:
# |  Simulation : 1 |
#       seed : 165 -----
# ...
#  75%|███████▌  | 6/8 [00:16<00:05,  2.72s/it]
#       Accuracy: 68.33%  Demographic disparity: 0.02
# |  Simulation : 2 |
#       seed : 187 -----
# ...
# 100%|██████████| 2/2 [00:01<00:00,  1.39it/s]
#
# ...
#  62%|██████▎   | 5/8 [00:13<00:08,  2.69s/it]
#       Accuracy: 66.67%  Demographic disparity: 0.03
# |  Simulation : 3 |
#       seed : 206 -----
#   0%|          | 0/2 [00:00<?, ?it/s]
#
#  50%|█████     | 1/2 [00:00<00:00,  1.34it/s]
#
# 100%|██████████| 2/2 [00:01<00:00,  1.35it/s]
#
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#
#  12%|█▎        | 1/8 [00:02<00:19,  2.72s/it]
#
#  25%|██▌       | 2/8 [00:05<00:16,  2.73s/it]
#
#  38%|███▊      | 3/8 [00:08<00:13,  2.72s/it]
#
#  50%|█████     | 4/8 [00:11<00:11,  2.76s/it]
#
#  62%|██████▎   | 5/8 [00:13<00:08,  2.75s/it]
#       Accuracy: 73.00%  Demographic disparity: 0.02
# |  Simulation : 4 |
#       seed : 226 -----
#   0%|          | 0/2 [00:00<?, ?it/s]
#
#
# ...

# %%
# adversarial learning 100
runSim(num_sim = 100, train_samples = 3000, test_samples = 300, learning_rate = 0.005, num_rounds = 10, adaptive_lr = True,
          local_epochs = 30, metric = "Demographic disparity", option = "adversarial learning", alpha = 0.5, epsilon = None, optimizer = 'sgd')
# Out:
# |  Simulation : 1 |
#       seed : 706 -----
# ...
# 100%|██████████| 9/9 [00:21<00:00,  2.41s/it]
#       Accuracy: 65.00%  Demographic disparity: 0.05
# |  Simulation : 2 |
#       seed : 731 -----
# ...
# 100%|██████████| 9/9 [00:21<00:00,  2.34s/it]
#       Accuracy: 67.67%  Demographic disparity: 0.05
# |  Simulation : 3 |
#       seed : 756 -----
# ...
# 100%|██████████| 9/9 [00:21<00:00,  2.34s/it]
#       Accuracy: 69.67%  Demographic disparity: 0.07
# |  Simulation : 4 |
#       seed : 780 -----
# ...
# 100%|██████████| 9/9 [00:21<00:00,  2.42s/it]
#       Accuracy: 65.67%  Demographic disparity: 0.10
# |  Simulation : 5 |
#       seed : 806 -----
# ...
# 100%|██████████| 9/9 [00:21<00:00,  2.34s/it]
#       Accuracy: 71.67%  Demographic disparity: 0.09
# |  Simulation : 6 |
#       seed : 831 -----
# ...
# 100%|██████████| 9/9 [00:22<00:00,  2.51s/it]
#       Accuracy: 63.33%  Demographic disparity: 0.03
# |  Simulation : 7 |
#       seed : 857 -----
# ...
# 100%|██████████| 9/9 [00:21<00:00,  2.39s/it]
# ...

# %%
# Zafar 100
runSim(num_sim = 100, train_samples = 3000, test_samples = 300, learning_rate = 0.0004, num_rounds = 4, 
          local_epochs = 30, metric = "Demographic disparity", optimizer = 'adam',
          test_rounds = 3, test_lr = 0.005, option = 'zafar', penalty = 100)
# Out:
# |  Simulation : 1 |
#       seed : 682 -----
# ...
# 100%|██████████| 4/4 [00:09<00:00,  2.45s/it]
#       Accuracy: 61.33%  Demographic disparity: 0.17
# |  Simulation : 2 |
#       seed : 714 -----
# ...
# 100%|██████████| 4/4 [00:09<00:00,  2.46s/it]
#       Accuracy: 54.33%  Demographic disparity: 0.01
# |  Simulation : 3 |
#       seed : 740 -----
# ...
# 100%|██████████| 4/4 [00:09<00:00,  2.48s/it]
#       Accuracy: 58.67%  Demographic disparity: 0.07
# |  Simulation : 4 |
#       seed : 766 -----
# ...
# 100%|██████████| 4/4 [00:09<00:00,  2.45s/it]
#       Accuracy: 54.00%  Demographic disparity: 0.07
# |  Simulation : 5 |
#       seed : 793 -----
# ...
# 100%|██████████| 4/4 [00:09<00:00,  2.44s/it]
#       Accuracy: 60.67%  Demographic disparity: 0.05
# |  Simulation : 6 |
#       seed : 820 -----
# ...
# 100%|██████████| 4/4 [00:09<00:00,  2.49s/it]
#       Accuracy: 57.00%  Demographic disparity: 0.05
# |  Simulation : 7 |
#       seed : 847 -----
# ...
# 100%|██████████| 4/4 [00:09<00:00,  2.46s/it]
# ...
